# %% [markdown]
# # AI Model Notebook

# %% [markdown]
# ## Imports

# %%
import numpy as np
from spacy.lang.en import English
import pandas as pd
import os
os.chdir('../')

# %% [markdown]
# ## Data Processing

# %%
data = "./data/main_data.csv"
read_csv = pd.read_csv(data)
read_csv
# Out:
#                    code                                            display
# 0       303921000119109  Chronic tophaceous gout of hand due to renal i...
# 1             450309001  Major systemic to pulmonary collateral artery ...
# 2             428799009         Rotatory subluxation of atlantoaxial joint
# 3              93936002        Primary malignant neoplasm of palatine bone
# 4             164510000                         O/E - elbow joint abnormal
# 5             200370007  Obstetric nipple infection with postnatal comp...
# 6             247002006       Anterior chamber pseudo-exfoliation deposits
# 7             280948003                           Normal sense of identity
# 8             288642003                         Does initiate conversation
# 9             783619003  DYRK1A-related intellectual disability syndrom...
# 10             95469008                           Abnormal plantar creases
# 11            173599005     Acute necrotising ulcerative gingivostomatitis
# 12             75697004      Term birth of identical twins, both stillborn
# 13            237138004                          Menopause ovarian failure
# 14            170561004                     Chronic disease - poor control
# 15            294695007                                  Cortisone allergy
# 16            282626003                            Able to roll on to side
# 17             64787009  Displacement of thoracic intervertebral disc w...
# 18            424629004  Transportation barrier impedes ability to use ...
# 19            239826001  Chronic infantile neurological, cutaneous and ...
# 20            253595004                           Pulmonary valve prolapse
# 21            240022008                        Posterior ankle impingement
# 22      135001000119100  Acute deep venous thrombosis of internal jugul...
# 23              6224002                      Decreased hormonal resistance
# 24            263170006                       Fracture of supraorbital rim
# 25            277850002                                  Diogenes syndrome
# 26            164641005                            O/E - sign - ankle/foot
# 27            447777009  Spontaneous closure of ventricular component o...
# 28            719254001                     Spinocerebellar ataxia type 32
# 29            161818003                                  Vulval irritation
# ...                 ...                                                ...
# 221402        234119001                         Congenital anomaly artery
# 221403        359557001                                   Disorder artery
# 221404        762250009                   Congenital anomaly great vessel
# 221405        400159008                  Congenital vascular malformation
# 221406        399982001                      Congenital vascular disorder
# 221407          9904008          Congenital anomaly cardiovascular system
# 221408        762228008                Congenital cardiovascular disorder
# 221409         39785005                    Disorder pulmonary circulation
# 221410        373434004                     Disorder blood vessels thorax
# 221411         27550009                                 Vascular disorder
# 221412         19660004                              Disorder soft tissue
# 221413         49601007                            Cardiovascular disease
# 221414         49483002                              Disorder mediastinum
# 221415        702612001                           Congenital aplasia lung
# 221416         47147007                           Congenital anomaly lung
# 221417        123654008       Congenital anomaly lower respiratory system
# 221418        275260000             Congenital anomaly respiratory system
# 221419         19829001                                 Pulmonary disease
# 221420        128272009                 Disorder lower respiratory system
# 221421         50043002                               Respiratory disease
# 221422        362965005                              Disorder body system
# 221423        363035006                         Congenital anomaly thorax
# 221424        363037003                    Congenital anomaly upper trunk
# 221425         78626001                          Congenital anomaly trunk
# 221426        276654001                                Congenital anomaly
# 221427         66091009                                Congenital disease
# 221428          5294002                            Developmental disorder
# 221429        118946009                                   Disorder thorax
# 221430        609622007                           Disorder thoracic trunk
# 221431        128121009                                    Disorder trunk
#
# [221432 rows x 2 columns]

# %%
data_frame = pd.DataFrame(read_csv)
data_frame.head()
# Out:
#               code                                            display
# 0  303921000119109  Chronic tophaceous gout of hand due to renal i...
# 1        450309001  Major systemic to pulmonary collateral artery ...
# 2        428799009         Rotatory subluxation of atlantoaxial joint
# 3         93936002        Primary malignant neoplasm of palatine bone
# 4        164510000                         O/E - elbow joint abnormal

# %%
feature = data_frame["display"]
feature.head()
# Out:
# 0    Chronic tophaceous gout of hand due to renal i...
# 1    Major systemic to pulmonary collateral artery ...
# 2           Rotatory subluxation of atlantoaxial joint
# 3          Primary malignant neoplasm of palatine bone
# 4                           O/E - elbow joint abnormal
# Name: display, dtype: object

# %%
X_train = data_frame["display"]
Y_train = data_frame["code"]

# %% [markdown]
# ## NLP Imports

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import nltk
from nltk.tokenize import word_tokenize

# %% [markdown]
# ## Word Tokenizing

# %%
tokenized_doc = []
doc = X_train.values.tolist()
for d in doc:
    d = str(d)
    tokenized_doc.append(word_tokenize(d.lower()))
print(tokenized_doc[:10])
# Out:
# [['chronic', 'tophaceous', 'gout', 'of', 'hand', 'due', 'to', 'renal', 'impairment'], ['major', 'systemic', 'to', 'pulmonary', 'collateral', 'artery', 'supplying', 'part', 'of', 'right', 'lung'], ['rotatory', 'subluxation', 'of', 'atlantoaxial', 'joint'], ['primary', 'malignant', 'neoplasm', 'of', 'palatine', 'bone'], ['o/e', '-', 'elbow', 'joint', 'abnormal'], ['obstetric', 'nipple', 'infection', 'with', 'postnatal', 'complication'], ['anterior', 'chamber', 'pseudo-exfoliation', 'deposits'], ['normal', 'sense', 'of', 'identity'], ['does', 'initiate', 'conversation'], ['dyrk1a-related', 'intellectual', 'disability', 'syndrome', 'due', 'to', '21q22.13q22.2', 'microdeletion']]

# %% [markdown]
# ## Converting to Tagged Documents

# %%
features = Y_train.values.tolist()
tagged_data = []
for value in range(len(doc)):
    feature = features[value]
    tokenized_sent = tokenized_doc[value]
    aj = TaggedDocument(tokenized_sent, [str(feature)])
    tagged_data.append(aj)
print(tagged_data[:100])
tagged_data_mini = tagged_data[3:5]
print(len(tagged_data_mini))
# Out:
# [TaggedDocument(words=['chronic', 'tophaceous', 'gout', 'of', 'hand', 'due', 'to', 'renal', 'impairment'], tags=['303921000119109']), TaggedDocument(words=['major', 'systemic', 'to', 'pulmonary', 'collateral', 'artery', 'supplying', 'part', 'of', 'right', 'lung'], tags=['450309001']), TaggedDocument(words=['rotatory', 'subluxation', 'of', 'atlantoaxial', 'joint'], tags=['428799009']), TaggedDocument(words=['primary', 'malignant', 'neoplasm', 'of', 'palatine', 'bone'], tags=['93936002']), TaggedDocument(words=['o/e', '-', 'elbow', 'joint', 'abnormal'], tags=['164510000']), TaggedDocument(words=['obstetric', 'nipple', 'infection', 'with', 'postnatal', 'complication'], tags=['200370007']), TaggedDocument(words=['anterior', 'chamber', 'pseudo-exfoliation', 'deposits'], tags=['247002006']), TaggedDocument(words=['normal', 'sense', 'of', 'identity'], tags=['280948003']), TaggedDocument(words=['does', 'initiate', 'conversation'], tags=['288642003']), TaggedDocument(words=['dyrk1a-related', 'intellectual', 'disability', 'syndrome', 'due', 'to', '21q22.13q22.2', 'microdeletion'], tags=['783619003']), TaggedDocument(words=['abnormal', 'plantar', 'creases'], tags=['95469008']), TaggedDocument(words=['acute', 'necrotising', 'ulcerative', 'gingivostomatitis'], tags=['173599005']), TaggedDocument(words=['term', 'birth', 'of', 'identical', 'twins', ',', 'both', 'stillborn'], tags=['75697004']), TaggedDocument(words=['menopause', 'ovarian', 'failure'], tags=['237138004']), TaggedDocument(words=['chronic', 'disease', '-', 'poor', 'control'], tags=['170561004']), TaggedDocument(words=['cortisone', 'allergy'], tags=['294695007']), TaggedDocument(words=['able', 'to', 'roll', 'on', 'to', 'side'], tags=['282626003']), TaggedDocument(words=['displacement', 'of', 'thoracic', 'intervertebral', 'disc', 'without', 'myelopathy'], tags=['64787009']), TaggedDocument(words=['transportation', 'barrier', 'impedes', 'ability', 'to', 'use', 'community', 'resources'], tags=['424629004']), TaggedDocument(words=['chronic', 'infantile', 'neurological', ',', 'cutaneous', 'and', 'articular', 'syndrome'], tags=['239826001']), TaggedDocument(words=['pulmonary', 'valve', 'prolapse'], tags=['253595004']), TaggedDocument(words=['posterior', 'ankle', 'impingement'], tags=['240022008']), TaggedDocument(words=['acute', 'deep', 'venous', 'thrombosis', 'of', 'internal', 'jugular', 'vein'], tags=['135001000119100']), TaggedDocument(words=['decreased', 'hormonal', 'resistance'], tags=['6224002']), TaggedDocument(words=['fracture', 'of', 'supraorbital', 'rim'], tags=['263170006']), TaggedDocument(words=['diogenes', 'syndrome'], tags=['277850002']), TaggedDocument(words=['o/e', '-', 'sign', '-', 'ankle/foot'], tags=['164641005']), TaggedDocument(words=['spontaneous', 'closure', 'of', 'ventricular', 'component', 'of', 'atrioventricular', 'septal', 'defect'], tags=['447777009']), TaggedDocument(words=['spinocerebellar', 'ataxia', 'type', '32'], tags=['719254001']), TaggedDocument(words=['vulval', 'irritation'], tags=['161818003']), TaggedDocument(words=['medial', 'epicondylitis'], tags=['53286005']), TaggedDocument(words=['injury', 'in', 'water', 'transport', 'caused', 'by', 'galley', 'machinery', ',', 'swimmer', 'injured'], tags=['215713006']), TaggedDocument(words=['intentional', 'cyclosporin', 'poisoning'], tags=['290776004']), TaggedDocument(words=['hypoplastic', 'lymph', 'node'], tags=['234089008']), TaggedDocument(words=['cervical', 'spine', 'crepitus', 'audible'], tags=['298481006']), TaggedDocument(words=['congenital', 'talipes', 'calcaneovalgus'], tags=['205083002']), TaggedDocument(words=['complex', 'burn', 'of', 'hip'], tags=['762488008']), TaggedDocument(words=['severely', 'compromised', 'location', 'and', 'extent', 'of', 'edentulous', 'area'], tags=['709849005']), TaggedDocument(words=['sodium', 'fluoride', 'adverse', 'reaction'], tags=['293415007']), TaggedDocument(words=['carbuncle', 'of', 'tunica', 'vaginalis'], tags=['28004004']), TaggedDocument(words=['autoimmune', ...
# 2

# %% [markdown]
# ## Building The Model

# %%
max_epochs = 30
vec_size = 20
alpha = 0.025

model = Doc2Vec(vec_size=vec_size,
                alpha=alpha, 
                min_alpha=0.00025,
                min_count=1,
                dm =1)
print("trainings started")
model.build_vocab(tagged_data)
print("build end")
for epoch in range(max_epochs):
    print('iteration {0}'.format(epoch))
    model.train(tagged_data,
                total_examples=model.corpus_count,
                epochs=model.iter)
    # decrease the learning rate
    model.alpha -= 0.0002
    # fix the learning rate, no decay
    model.min_alpha = model.alpha

model.save("test_doc2vec.model")
print("Model Saved")
# Out:
# trainings started
# build end
# iteration 0
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# Model Saved

# %% [markdown]
# ## Loading the Model

# %%
model= Doc2Vec.load("./storage/doc2vec.model")
## Print model vocabulary
model.wv.vocab
# Out:
# {'chronic': <gensim.models.keyedvectors.Vocab at 0x1bcdd073198>,
#  'tophaceous': <gensim.models.keyedvectors.Vocab at 0x1bcdd073240>,
#  'gout': <gensim.models.keyedvectors.Vocab at 0x1bcdd0732b0>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x1bcdd073320>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x1bcdd073390>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x1bcdd073400>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x1bcdd073470>,
#  'renal': <gensim.models.keyedvectors.Vocab at 0x1bcdd0734e0>,
#  'impairment': <gensim.models.keyedvectors.Vocab at 0x1bcdd073518>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x1bcdd073588>,
#  'systemic': <gensim.models.keyedvectors.Vocab at 0x1bcdd0735c0>,
#  'pulmonary': <gensim.models.keyedvectors.Vocab at 0x1bcdd0735f8>,
#  'collateral': <gensim.models.keyedvectors.Vocab at 0x1bcdd073630>,
#  'artery': <gensim.models.keyedvectors.Vocab at 0x1bcdd0736a0>,
#  'supplying': <gensim.models.keyedvectors.Vocab at 0x1bcdd0736d8>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x1bcdd073748>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x1bcdd0737b8>,
#  'lung': <gensim.models.keyedvectors.Vocab at 0x1bcdd073828>,
#  'rotatory': <gensim.models.keyedvectors.Vocab at 0x1bcdd073860>,
#  'subluxation': <gensim.models.keyedvectors.Vocab at 0x1bcdd073898>,
#  'atlantoaxial': <gensim.models.keyedvectors.Vocab at 0x1bcdd0738d0>,
#  'joint': <gensim.models.keyedvectors.Vocab at 0x1bcdd073940>,
#  'primary': <gensim.models.keyedvectors.Vocab at 0x1bcdd0739b0>,
#  'malignant': <gensim.models.keyedvectors.Vocab at 0x1bcdd0739e8>,
#  'neoplasm': <gensim.models.keyedvectors.Vocab at 0x1bcdd073a20>,
#  'palatine': <gensim.models.keyedvectors.Vocab at 0x1bcdd073a58>,
#  'bone': <gensim.models.keyedvectors.Vocab at 0x1bcdd073ac8>,
#  'o/e': <gensim.models.keyedvectors.Vocab at 0x1bcdd073b38>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x1bcdd073b70>,
#  'elbow': <gensim.models.keyedvectors.Vocab at 0x1bcdd073be0>,
#  'abnormal': <gensim.models.keyedvectors.Vocab at 0x1bcdd073c18>,
#  'obstetric': <gensim.models.keyedvectors.Vocab at 0x1bcdd073c50>,
#  'nipple': <gensim.models.keyedvectors.Vocab at 0x1bcdd073cc0>,
#  'infection': <gensim.models.keyedvectors.Vocab at 0x1bcdd073cf8>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x1bcdd073d68>,
#  'postnatal': <gensim.models.keyedvectors.Vocab at 0x1bcdd073da0>,
#  'complication': <gensim.models.keyedvectors.Vocab at 0x1bcdd073dd8>,
#  'anterior': <gensim.models.keyedvectors.Vocab at 0x1bcdd073e10>,
#  'chamber': <gensim.models.keyedvectors.Vocab at 0x1bcdd073e80>,
#  'pseudo-exfoliation': <gensim.models.keyedvectors.Vocab at 0x1bcdd073eb8>,
#  'deposits': <gensim.models.keyedvectors.Vocab at 0x1bcdd073ef0>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x1bcdd073f60>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x1bcdd073fd0>,
#  'identity': <gensim.models.keyedvectors.Vocab at 0x1bcdd078048>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x1bcdd0780b8>,
#  'initiate': <gensim.models.keyedvectors.Vocab at 0x1bcdd0780f0>,
#  'conversation': <gensim.models.keyedvectors.Vocab at 0x1bcdd078128>,
#  'dyrk1a-related': <gensim.models.keyedvectors.Vocab at 0x1bcdd078160>,
#  'intellectual': <gensim.models.keyedvectors.Vocab at 0x1bcdd078198>,
#  'disability': <gensim.models.keyedvectors.Vocab at 0x1bcdd0781d0>,
#  'syndrome': <gensim.models.keyedvectors.Vocab at 0x1bcdd078208>,
#  '21q22.13q22.2': <gensim.models.keyedvectors.Vocab at 0x1bcdd078240>,
#  'microdeletion': <gensim.models.keyedvectors.Vocab at 0x1bcdd078278>,
#  'plantar': <gensim.models.keyedvectors.Vocab at 0x1bcdd0782e8>,
#  'creases': <gensim.models.keyedvectors.Vocab at 0x1bcdd078358>,
#  'acute': <gensim.models.keyedvectors.Vocab at 0x1bcdd0783c8>,
#  'necrotising': <gensim.models.keyedvectors.Vocab at 0x1bcdd078400>,
#  'ulcerative': <gensim.models.keyedvectors.Vocab at 0x1bcdd078438>,
#  'gingivostomatitis': <gensim.models.keyedvectors.Vocab at 0x1bcdd078470>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x1bcdd0784e0>,
#  'birth': <gensim.models.keyedvectors.Vocab at 0x1bcdd078550>,
#  'identical': <gensim.models.keyedvectors.Vocab at 0x1bcdd078588>,
#  'twins': <gensim.models.keyedvectors.Vocab at 0x1bcdd0785f8>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x1bcdd078630>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x1bcdd0786a0>,
#  'stillborn': <gensim.models.keyedvectors.Vocab at 0x1bcdd0786d8>,
#  'menopause': <gensim.models.keyedvectors.Vocab at 0x1bcdd078710>,
#  'ovarian': <gensim.models.keyedvectors.Vocab at 0x1bcdd078780>,
#  'failure': <gensim.models.keyedvectors.Vocab at 0x1bcdd0787f0>,
#  'disease': <gensim.models.keyedvectors.Vocab at 0x1bcdd078860>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x1bcdd0788d0>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x1bcdd078940>,
#  'cortisone': <gensim.models.keyedvectors.Vocab at 0x1bcdd078978>,
#  'allergy': <gensim.models.keyedvectors.Vocab at 0x1bcdd0789e8>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x1bcdd078a58>,
#  'roll': <gensim.models.keyedvectors.Vocab at 0x1bcdd078ac8>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x1bcdd078b38>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x1bcdd078ba8>,
#  'displacement': <gensim.models.keyedvectors.Vocab at 0x1bcdd078be0>,
#  'thoracic': <gensim.models.keyedvectors.Vocab at 0x1bcdd078c18>,
#  'intervertebral': <gensim.models.keyedvectors.Vocab at 0x1bcdd078c50>,
#  'disc': <gensim.models.keyedvectors.Vocab at 0x1bcdd078cc0>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x1bcdd078d30>,
#  'myelopathy': <gensim.models.keyedvectors.Vocab at 0x1bcdd078d68>,
#  'transportation': <gensim.models.keyedvectors.Vocab at 0x1bcdd078da0>,
#  'barrier': <gensim.models.keyedvectors.Vocab at 0x1bcdd078e10>,
#  'impedes': <gensim.models.keyedvectors.Vocab at 0x1bcdd078e80>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x1bcdd078ef0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x1bcdd078f60>,
#  'community': <gensim.models.keyedvectors.Vocab at 0x1bcdd078f98>,
#  'resources': <gensim.models.keyedvectors.Vocab at 0x1bcdd078fd0>,
#  'infantile': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e048>,
#  'neurological': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e080>,
#  'cutaneous': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e0b8>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e128>,
#  'articular': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e160>,
#  'valve': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e1d0>,
#  'prolapse': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e208>,
#  'posterior': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e240>,
#  'ankle': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e2b0>,
#  'impingement': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e2e8>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e358>,
#  'venous': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e3c8>,
#  'thrombosis': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e400>,
#  'internal': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e438>,
#  'jugular': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e4a8>,
#  'vein': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e518>,
#  'decreased': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e550>,
#  'hormonal': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e588>,
#  'resistance': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e5c0>,
#  'fracture': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e5f8>,
#  'supraorbital': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e630>,
#  'rim': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e6a0>,
#  'diogenes': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e6d8>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e748>,
#  'ankle/foot': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e780>,
#  'spontaneous': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e7b8>,
#  'closure': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e828>,
#  'ventricular': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e860>,
#  'component': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e898>,
#  'atrioventricular': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e8d0>,
#  'septal': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e940>,
#  'defect': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e9b0>,
#  'spinocerebellar': <gensim.models.keyedvectors.Vocab at 0x1bcdd07e9e8>,
#  'ataxia': <gensim.models.keyedvectors.Vocab at 0x1bcdd07ea58>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x1bcdd07eac8>,
#  '32': <gensim.models.keyedvectors.Vocab at 0x1bcdd07eb38>,
#  'vulval': <gensim.models.keyedvectors.Vocab at 0x1bcdd07eba8>,
#  'irritation': <gensim.models.keyedvectors.Vocab at 0x1bcdd07ebe0>,
#  'medial': <gensim.models.keyedvectors.Vocab at 0x1bcdd07ec50>,
#  'epicondylitis': <gensim.models.keyedvectors.Vocab at 0x1bcdd07ec88>,
#  'injury': <gensim.models.keyedvectors.Vocab at 0x1bcdd07ecf8>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x1bcdd07ed68>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x1bcdd07edd8>,
#  'transport': <gensim.models.keyedvectors.Vocab at 0x1bcdd07ee10>,
#  'caused': <gensim.models.keyedvectors.Vocab at 0x1bcdd07ee80>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x1bcdd07eef0>,
#  'galley': <gensim.models.keyedvectors.Vocab at 0x1bcdd07ef60>,
#  'machinery': <gensim.models.keyedvectors.Vocab at 0x1bcdd07ef98>,
#  'swimmer': <gensim.models.keyedvectors.Vocab at 0x1bcde626048>,
#  'injured': <gensim.models.keyedvectors.Vocab at 0x1bcde6260b8>,
#  'intentional': <gensim.models.keyedvectors.Vocab at 0x1bcde6260f0>,
#  'cyclosporin': <gensim.models.keyedvectors.Vocab at 0x1bcde626128>,
#  'poisoning': <gensim.models.keyedvectors.Vocab at 0x1bcde626160>,
#  'hypoplastic': <gensim.models.keyedvectors.Vocab at 0x1bcde626198>,
#  'lymph': <gensim.models.keyedvectors.Vocab at 0x1bcde626208>,
#  'node': <gensim.models.keyedvectors.Vocab at 0x1bcde626278>,
#  'cervical': <gensim.models.keyedvectors.Vocab at 0x1bcde6262b0>,
#  'spine': <gensim.models.keyedvectors.Vocab at 0x1bcde626320>,
#  'crepitus': <gensim.models.keyedvectors.Vocab at 0x1bcde626358>,
#  'audible': <gensim.models.keyedvectors.Vocab at 0x1bcde6263c8>,
#  'congenital': <gensim.models.keyedvectors.Vocab at 0x1bcde626400>,
#  'talipes': <gensim.models.keyedvectors.Vocab at 0x1bcde626470>,
#  'calcaneovalgus': <gensim.models.keyedvectors.Vocab at 0x1bcde6264a8>,
#  'complex': <gensim.models.keyedvectors.Vocab at 0x1bcde626518>,
#  'burn': <gensim.models.keyedvectors.Vocab at 0x1bcde626588>,
#  'hip': <gensim.models.keyedvectors.Vocab at 0x1bcde6265f8>,
#  'severely': <gensim.models.keyedvectors.Vocab at 0x1bcde626630>,
#  'compromised': <gensim.models.keyedvectors.Vocab at 0x1bcde626668>,
#  'location': <gensim.models.keyedvectors.Vocab at 0x1bcde6266a0>,
#  'extent': <gensim.models.keyedvectors.Vocab at 0x1bcde626710>,
#  'edentulous': <gensim.models.keyedvectors.Vocab at 0x1bcde626748>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x1bcde6267b8>,
#  'sodium': <gensim.models.keyedvectors.Vocab at 0x1bcde626828>,
#  'fluoride': <gensim.models.keyedvectors.Vocab at 0x1bcde626860>,
#  'adverse': <gensim.models.keyedvectors.Vocab at 0x1bcde6268d0>,
#  'reaction': <gensim.models.keyedvectors.Vocab at 0x1bcde626908>,
#  'carbuncle': <gensim.models.keyedvectors.Vocab at 0x1bcde626940>,
#  'tunica': <gensim.models.keyedvectors.Vocab at 0x1bcde6269b0>,
#  'vaginalis': <gensim.models.keyedvectors.Vocab at 0x1bcde6269e8>,
#  'autoimmune': <gensim.models.keyedvectors.Vocab at 0x1bcde626a20>,
#  'polyendocrine': <gensim.models.keyedvectors.Vocab at 0x1bcde626a58>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x1bcde626a90>,
#  'genetic': <gensim.models.keyedvectors.Vocab at 0x1bcde626b00>,
#  'linkage': <gensim.models.keyedvectors.Vocab at 0x1bcde626b70>,
#  'disequilibrium': <gensim.models.keyedvectors.Vocab at 0x1bcde626ba8>,
#  'contusion': <gensim.models.keyedvectors.Vocab at 0x1bcde626be0>,
#  'caecum': <gensim.models.keyedvectors.Vocab at 0x1bcde626c50>,
#  'placenta': <gensim.models.keyedvectors.Vocab at 0x1bcde626c88>,
#  'mycobacterium': <gensim.models.keyedvectors.Vocab at 0x1bcde626cc0>,
#  'tuberculosis': <gensim.models.keyedvectors.Vocab at 0x1bcde626cf8>,
#  'adult-onset': <gensim.models.keyedvectors.Vocab at 0x1bcde626d30>,
#  'progressive': <gensim.models.keyedvectors.Vocab at 0x1bcde626d68>,
#  'external': <gensim.models.keyedvectors.Vocab at 0x1bcde626da0>,
#  'ophthalmoplegia': <gensim.models.keyedvectors.Vocab at 0x1bcde626dd8>,
#  'mitochondrial': <gensim.models.keyedvectors.Vocab at 0x1bcde626e10>,
#  'myopathy': <gensim.models.keyedvectors.Vocab at 0x1bcde626e48>,
#  'inequality': <gensim.models.keyedvectors.Vocab at 0x1bcde626e80>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x1bcde626ef0>,
#  'kidneys': <gensim.models.keyedvectors.Vocab at 0x1bcde626f60>,
#  'haemoglobin': <gensim.models.keyedvectors.Vocab at 0x1bcde626f98>,
#  'sc': <gensim.models.keyedvectors.Vocab at 0x1bcde62d048>,
#  'crystals': <gensim.models.keyedvectors.Vocab at 0x1bcde62d080>,
#  'cortical': <gensim.models.keyedvectors.Vocab at 0x1bcde62d0b8>,
#  'dysgenesis': <gensim.models.keyedvectors.Vocab at 0x1bcde62d0f0>,
#  'pontocerebellar': <gensim.models.keyedvectors.Vocab at 0x1bcde62d128>,
#  'hypoplasia': <gensim.models.keyedvectors.Vocab at 0x1bcde62d160>,
#  'tubb3': <gensim.models.keyedvectors.Vocab at 0x1bcde62d1d0>,
#  'mutation': <gensim.models.keyedvectors.Vocab at 0x1bcde62d208>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x1bcde62d278>,
#  'myoclonus': <gensim.models.keyedvectors.Vocab at 0x1bcde62d2b0>,
#  'pigmented': <gensim.models.keyedvectors.Vocab at 0x1bcde62d2e8>,
#  'melanocytic': <gensim.models.keyedvectors.Vocab at 0x1bcde62d320>,
#  'naevus': <gensim.models.keyedvectors.Vocab at 0x1bcde62d390>,
#  'skin': <gensim.models.keyedvectors.Vocab at 0x1bcde62d400>,
#  'lower': <gensim.models.keyedvectors.Vocab at 0x1bcde62d470>,
#  'limb': <gensim.models.keyedvectors.Vocab at 0x1bcde62d4e0>,
#  'partial': <gensim.models.keyedvectors.Vocab at 0x1bcde62d550>,
#  'thickness': <gensim.models.keyedvectors.Vocab at 0x1bcde62d588>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x1bcde62d5f8>,
#  'lip': <gensim.models.keyedvectors.Vocab at 0x1bcde62d668>,
#  'dysexecutive': <gensim.models.keyedvectors.Vocab at 0x1bcde62d6a0>,
#  'facial': <gensim.models.keyedvectors.Vocab at 0x1bcde62d710>,
#  'milia': <gensim.models.keyedvectors.Vocab at 0x1bcde62d780>,
#  'lobate': <gensim.models.keyedvectors.Vocab at 0x1bcde62d7f0>,
#  'tongue': <gensim.models.keyedvectors.Vocab at 0x1bcde62d860>,
#  'lingual': <gensim.models.keyedvectors.Vocab at 0x1bcde62d8d0>,
#  'labial': <gensim.models.keyedvectors.Vocab at 0x1bcde62d940>,
#  'frenula': <gensim.models.keyedvectors.Vocab at 0x1bcde62d9b0>,
#  'hiccups': <gensim.models.keyedvectors.Vocab at 0x1bcde62da20>,
#  'subneopulmonary': <gensim.models.keyedvectors.Vocab at 0x1bcde62da58>,
#  'stenosis': <gensim.models.keyedvectors.Vocab at 0x1bcde62da90>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x1bcde62db00>,
#  'attorney': <gensim.models.keyedvectors.Vocab at 0x1bcde62db38>,
#  'held': <gensim.models.keyedvectors.Vocab at 0x1bcde62dba8>,
#  'follicular': <gensim.models.keyedvectors.Vocab at 0x1bcde62dbe0>,
#  'conjunctivitis': <gensim.models.keyedvectors.Vocab at 0x1bcde62dc18>,
#  'drug': <gensim.models.keyedvectors.Vocab at 0x1bcde62dc88>,
#  'gait': <gensim.models.keyedvectors.Vocab at 0x1bcde62dcf8>,
#  'exhaustion': <gensim.models.keyedvectors.Vocab at 0x1bcde62dd30>,
#  'exposure': <gensim.models.keyedvectors.Vocab at 0x1bcde62dd68>,
#  'difficulty': <gensim.models.keyedvectors.Vocab at 0x1bcde62dda0>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x1bcde62de10>,
#  'illegal': <gensim.models.keyedvectors.Vocab at 0x1bcde62de80>,
#  'termination': <gensim.models.keyedvectors.Vocab at 0x1bcde62deb8>,
#  'pregnancy': <gensim.models.keyedvectors.Vocab at 0x1bcde62def0>,
#  'perforation': <gensim.models.keyedvectors.Vocab at 0x1bcde62df28>,
#  'broad': <gensim.models.keyedvectors.Vocab at 0x1bcde62df98>,
#  'ligament': <gensim.models.keyedvectors.Vocab at 0x1bcde62dfd0>,
#  'unable': <gensim.models.keyedvectors.Vocab at 0x1bcde633080>,
#  'grip': <gensim.models.keyedvectors.Vocab at 0x1bcde6330f0>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x1bcde633160>,
#  'opposition': <gensim.models.keyedvectors.Vocab at 0x1bcde633198>,
#  'thumb': <gensim.models.keyedvectors.Vocab at 0x1bcde633208>,
#  'lobulated': <gensim.models.keyedvectors.Vocab at 0x1bcde633240>,
#  'accidental': <gensim.models.keyedvectors.Vocab at 0x1bcde633278>,
#  'alfentanil': <gensim.models.keyedvectors.Vocab at 0x1bcde6332b0>,
#  'pityriasiform': <gensim.models.keyedvectors.Vocab at 0x1bcde6332e8>,
#  'seborrhoeic': <gensim.models.keyedvectors.Vocab at 0x1bcde633320>,
#  'dermatitis': <gensim.models.keyedvectors.Vocab at 0x1bcde633358>,
#  'cellulitis': <gensim.models.keyedvectors.Vocab at 0x1bcde633390>,
#  'scalp': <gensim.models.keyedvectors.Vocab at 0x1bcde633400>,
#  'drug-related': <gensim.models.keyedvectors.Vocab at 0x1bcde633438>,
#  'myocardial': <gensim.models.keyedvectors.Vocab at 0x1bcde633470>,
#  'necrosis': <gensim.models.keyedvectors.Vocab at 0x1bcde6334a8>,
#  'extension': <gensim.models.keyedvectors.Vocab at 0x1bcde6334e0>,
#  'stroke': <gensim.models.keyedvectors.Vocab at 0x1bcde633550>,
#  'granulomatous': <gensim.models.keyedvectors.Vocab at 0x1bcde633588>,
#  'iii': <gensim.models.keyedvectors.Vocab at 0x1bcde6335f8>,
#  'manic': <gensim.models.keyedvectors.Vocab at 0x1bcde633668>,
#  'mental': <gensim.models.keyedvectors.Vocab at 0x1bcde6336d8>,
#  'defence': <gensim.models.keyedvectors.Vocab at 0x1bcde633748>,
#  'mechanism': <gensim.models.keyedvectors.Vocab at 0x1bcde633780>,
#  'cord': <gensim.models.keyedvectors.Vocab at 0x1bcde6337f0>,
#  'spinal': <gensim.models.keyedvectors.Vocab at 0x1bcde633860>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x1bcde6338d0>,
#  'c8': <gensim.models.keyedvectors.Vocab at 0x1bcde633940>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x1bcde6339b0>,
#  'modified': <gensim.models.keyedvectors.Vocab at 0x1bcde6339e8>,
#  'dukes': <gensim.models.keyedvectors.Vocab at 0x1bcde633a58>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x1bcde633ac8>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x1bcde633b00>,
#  'phlegmonous': <gensim.models.keyedvectors.Vocab at 0x1bcde633b38>,
#  'stomatitis': <gensim.models.keyedvectors.Vocab at 0x1bcde633b70>,
#  'methane/propane': <gensim.models.keyedvectors.Vocab at 0x1bcde633ba8>,
#  'synthetic': <gensim.models.keyedvectors.Vocab at 0x1bcde633be0>,
#  'cannabinoid': <gensim.models.keyedvectors.Vocab at 0x1bcde633c18>,
#  'withdrawal': <gensim.models.keyedvectors.Vocab at 0x1bcde633c50>,
#  'tumour': <gensim.models.keyedvectors.Vocab at 0x1bcde633cc0>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x1bcde633cf8>,
#  'uterine': <gensim.models.keyedvectors.Vocab at 0x1bcde633d68>,
#  'corpus': <gensim.models.keyedvectors.Vocab at 0x1bcde633dd8>,
#  'separate': <gensim.models.keyedvectors.Vocab at 0x1bcde633e10>,
#  'metastasis': <gensim.models.keyedvectors.Vocab at 0x1bcde633e48>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x1bcde633eb8>,
#  'cervix': <gensim.models.keyedvectors.Vocab at 0x1bcde633f28>,
#  'sepsis-related': <gensim.models.keyedvectors.Vocab at 0x1bcde633f60>,
#  'gastrointestinal': <gensim.models.keyedvectors.Vocab at 0x1bcde633f98>,
#  'ulceration': <gensim.models.keyedvectors.Vocab at 0x1bcde633fd0>,
#  'tends': <gensim.models.keyedvectors.Vocab at 0x1bcde639080>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x1bcde6390f0>,
#  'excessively': <gensim.models.keyedvectors.Vocab at 0x1bcde639128>,
#  'self-sufficient': <gensim.models.keyedvectors.Vocab at 0x1bcde639160>,
#  'blunted': <gensim.models.keyedvectors.Vocab at 0x1bcde6391d0>,
#  'hypoxic': <gensim.models.keyedvectors.Vocab at 0x1bcde639240>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x1bcde6392b0>,
#  'juvenile': <gensim.models.keyedvectors.Vocab at 0x1bcde6392e8>,
#  'aponeurotic': <gensim.models.keyedvectors.Vocab at 0x1bcde639320>,
#  'fibroma': <gensim.models.keyedvectors.Vocab at 0x1bcde639390>,
#  'medullary': <gensim.models.keyedvectors.Vocab at 0x1bcde6393c8>,
#  'sponge': <gensim.models.keyedvectors.Vocab at 0x1bcde639438>,
#  'kidney': <gensim.models.keyedvectors.Vocab at 0x1bcde6394a8>,
#  'nephrocalcinosis': <gensim.models.keyedvectors.Vocab at 0x1bcde6394e0>,
#  'divergence': <gensim.models.keyedvectors.Vocab at 0x1bcde639518>,
#  'retraction': <gensim.models.keyedvectors.Vocab at 0x1bcde639550>,
#  'nystagmus': <gensim.models.keyedvectors.Vocab at 0x1bcde639588>,
#  'isthmic': <gensim.models.keyedvectors.Vocab at 0x1bcde6395f8>,
#  'spondylolisthesis': <gensim.models.keyedvectors.Vocab at 0x1bcde639630>,
#  'stopped': <gensim.models.keyedvectors.Vocab at 0x1bcde6396a0>,
#  'drinking': <gensim.models.keyedvectors.Vocab at 0x1bcde6396d8>,
#  'alcohol': <gensim.models.keyedvectors.Vocab at 0x1bcde639748>,
#  'klumpke-dã©jerine': <gensim.models.keyedvectors.Vocab at 0x1bcde639780>,
#  'paralysis': <gensim.models.keyedvectors.Vocab at 0x1bcde6397b8>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x1bcde639828>,
#  'trauma': <gensim.models.keyedvectors.Vocab at 0x1bcde639898>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x1bcde639908>,
#  'traumatic': <gensim.models.keyedvectors.Vocab at 0x1bcde639940>,
#  'costochondral': <gensim.models.keyedvectors.Vocab at 0x1bcde639978>,
#  'asymptomatic': <gensim.models.keyedvectors.Vocab at 0x1bcde6399b0>,
#  'west': <gensim.models.keyedvectors.Vocab at 0x1bcde639a20>,
#  'nile': <gensim.models.keyedvectors.Vocab at 0x1bcde639a90>,
#  'virus': <gensim.models.keyedvectors.Vocab at 0x1bcde639b00>,
#  'mild': <gensim.models.keyedvectors.Vocab at 0x1bcde639b70>,
#  'hypokinesis': <gensim.models.keyedvectors.Vocab at 0x1bcde639ba8>,
#  'cardiac': <gensim.models.keyedvectors.Vocab at 0x1bcde639c18>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x1bcde639c88>,
#  'thigh': <gensim.models.keyedvectors.Vocab at 0x1bcde639cf8>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x1bcde639d68>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x1bcde639da0>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x1bcde639e10>,
#  'exam': <gensim.models.keyedvectors.Vocab at 0x1bcde639e80>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x1bcde639ef0>,
#  'observation': <gensim.models.keyedvectors.Vocab at 0x1bcde639f28>,
#  'stab': <gensim.models.keyedvectors.Vocab at 0x1bcde639f98>,
#  'wound': <gensim.models.keyedvectors.Vocab at 0x1bcde640048>,
#  'varicocele': <gensim.models.keyedvectors.Vocab at 0x1bcde640080>,
#  'palpable': <gensim.models.keyedvectors.Vocab at 0x1bcde6400b8>,
#  'valsalva': <gensim.models.keyedvectors.Vocab at 0x1bcde6400f0>,
#  'manoeuvre': <gensim.models.keyedvectors.Vocab at 0x1bcde640128>,
#  'plain': <gensim.models.keyedvectors.Vocab at 0x1bcde640198>,
#  'x-ray': <gensim.models.keyedvectors.Vocab at 0x1bcde640208>,
#  'toes': <gensim.models.keyedvectors.Vocab at 0x1bcde640278>,
#  'forearm': <gensim.models.keyedvectors.Vocab at 0x1bcde6402e8>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x1bcde640358>,
#  'foot': <gensim.models.keyedvectors.Vocab at 0x1bcde6403c8>,
#  'involuntary': <gensim.models.keyedvectors.Vocab at 0x1bcde640400>,
#  'movement': <gensim.models.keyedvectors.Vocab at 0x1bcde640438>,
#  'kinaesthetic': <gensim.models.keyedvectors.Vocab at 0x1bcde640470>,
#  'alteration': <gensim.models.keyedvectors.Vocab at 0x1bcde6404a8>,
#  'retained': <gensim.models.keyedvectors.Vocab at 0x1bcde6404e0>,
#  'nuclear': <gensim.models.keyedvectors.Vocab at 0x1bcde640550>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x1bcde640588>,
#  'vitreous': <gensim.models.keyedvectors.Vocab at 0x1bcde6405c0>,
#  'post-mastectomy': <gensim.models.keyedvectors.Vocab at 0x1bcde6405f8>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x1bcde640668>,
#  'cholecystitis': <gensim.models.keyedvectors.Vocab at 0x1bcde6406a0>,
#  'calculus': <gensim.models.keyedvectors.Vocab at 0x1bcde6406d8>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x1bcde640748>,
#  'corpuscular': <gensim.models.keyedvectors.Vocab at 0x1bcde640780>,
#  'concentration': <gensim.models.keyedvectors.Vocab at 0x1bcde6407b8>,
#  'borderline': <gensim.models.keyedvectors.Vocab at 0x1bcde6407f0>,
#  'raised': <gensim.models.keyedvectors.Vocab at 0x1bcde640860>,
#  'kussmaul': <gensim.models.keyedvectors.Vocab at 0x1bcde640898>,
#  "'s": <gensim.models.keyedvectors.Vocab at 0x1bcde640908>,
#  'respiration': <gensim.models.keyedvectors.Vocab at 0x1bcde640940>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x1bcde640978>,
#  'sites': <gensim.models.keyedvectors.Vocab at 0x1bcde6409e8>,
#  'arm': <gensim.models.keyedvectors.Vocab at 0x1bcde640a58>,
#  'uvular': <gensim.models.keyedvectors.Vocab at 0x1bcde640ac8>,
#  'hypertrophy': <gensim.models.keyedvectors.Vocab at 0x1bcde640b00>,
#  'wood': <gensim.models.keyedvectors.Vocab at 0x1bcde640b70>,
#  'splinter': <gensim.models.keyedvectors.Vocab at 0x1bcde640ba8>,
#  'confluent': <gensim.models.keyedvectors.Vocab at 0x1bcde640be0>,
#  'retinal': <gensim.models.keyedvectors.Vocab at 0x1bcde640c50>,
#  'haemorrhage': <gensim.models.keyedvectors.Vocab at 0x1bcde640c88>,
#  'rheumatology': <gensim.models.keyedvectors.Vocab at 0x1bcde640cc0>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x1bcde640d30>,
#  'dementia': <gensim.models.keyedvectors.Vocab at 0x1bcde640d68>,
#  'multifocal': <gensim.models.keyedvectors.Vocab at 0x1bcde640da0>,
#  'leukoencephalopathy': <gensim.models.keyedvectors.Vocab at 0x1bcde640dd8>,
#  'ignition': <gensim.models.keyedvectors.Vocab at 0x1bcde640e10>,
#  'clothing': <gensim.models.keyedvectors.Vocab at 0x1bcde640e48>,
#  'burning': <gensim.models.keyedvectors.Vocab at 0x1bcde640eb8>,
#  'bedding': <gensim.models.keyedvectors.Vocab at 0x1bcde640f28>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x1bcde640f98>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x1bcde647048>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x1bcde6470b8>,
#  'flexion': <gensim.models.keyedvectors.Vocab at 0x1bcde647128>,
#  'dens': <gensim.models.keyedvectors.Vocab at 0x1bcde647198>,
#  'evaginatus': <gensim.models.keyedvectors.Vocab at 0x1bcde6471d0>,
#  'female': <gensim.models.keyedvectors.Vocab at 0x1bcde647240>,
#  'sterility': <gensim.models.keyedvectors.Vocab at 0x1bcde647278>,
#  'retrusion': <gensim.models.keyedvectors.Vocab at 0x1bcde6472b0>,
#  'superficial': <gensim.models.keyedvectors.Vocab at 0x1bcde6472e8>,
#  'foreign': <gensim.models.keyedvectors.Vocab at 0x1bcde647358>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x1bcde6473c8>,
#  'leg': <gensim.models.keyedvectors.Vocab at 0x1bcde647438>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x1bcde6474a8>,
#  'abo': <gensim.models.keyedvectors.Vocab at 0x1bcde647518>,
#  'isoimmunisation': <gensim.models.keyedvectors.Vocab at 0x1bcde647550>,
#  'affecting': <gensim.models.keyedvectors.Vocab at 0x1bcde647588>,
#  'heteromanipulatory': <gensim.models.keyedvectors.Vocab at 0x1bcde6475c0>,
#  'vulvoclitoral': <gensim.models.keyedvectors.Vocab at 0x1bcde6475f8>,
#  'habituation': <gensim.models.keyedvectors.Vocab at 0x1bcde647630>,
#  'overdose': <gensim.models.keyedvectors.Vocab at 0x1bcde647668>,
#  'shallow': <gensim.models.keyedvectors.Vocab at 0x1bcde6476d8>,
#  'mentolabial': <gensim.models.keyedvectors.Vocab at 0x1bcde647710>,
#  'sulcus': <gensim.models.keyedvectors.Vocab at 0x1bcde647780>,
#  'pt1a': <gensim.models.keyedvectors.Vocab at 0x1bcde6477f0>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x1bcde647828>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x1bcde647898>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x1bcde647908>,
#  'iris': <gensim.models.keyedvectors.Vocab at 0x1bcde647978>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x1bcde6479b0>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x1bcde647a20>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x1bcde647a90>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x1bcde647b00>,
#  'clock': <gensim.models.keyedvectors.Vocab at 0x1bcde647b70>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x1bcde647be0>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x1bcde647c18>,
#  'uveal': <gensim.models.keyedvectors.Vocab at 0x1bcde647c88>,
#  'melanoma': <gensim.models.keyedvectors.Vocab at 0x1bcde647cc0>,
#  'hyperbilirubinaemia': <gensim.models.keyedvectors.Vocab at 0x1bcde647cf8>,
#  'conjugated': <gensim.models.keyedvectors.Vocab at 0x1bcde647d30>,
#  'bromobenzyl': <gensim.models.keyedvectors.Vocab at 0x1bcde647d68>,
#  'cyanide': <gensim.models.keyedvectors.Vocab at 0x1bcde647dd8>,
#  'sympathetic': <gensim.models.keyedvectors.Vocab at 0x1bcde647e10>,
#  'nerves': <gensim.models.keyedvectors.Vocab at 0x1bcde647e80>,
#  'submandibular': <gensim.models.keyedvectors.Vocab at 0x1bcde647eb8>,
#  'swelling': <gensim.models.keyedvectors.Vocab at 0x1bcde647ef0>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x1bcde647f60>,
#  'pulse': <gensim.models.keyedvectors.Vocab at 0x1bcde647fd0>,
#  'volume': <gensim.models.keyedvectors.Vocab at 0x1bcde64d080>,
#  'extraintestinal': <gensim.models.keyedvectors.Vocab at 0x1bcde64d0b8>,
#  'entamoeba': <gensim.models.keyedvectors.Vocab at 0x1bcde64d0f0>,
#  'severe': <gensim.models.keyedvectors.Vocab at 0x1bcde64d160>,
#  'acquired': <gensim.models.keyedvectors.Vocab at 0x1bcde64d198>,
#  'hearing': <gensim.models.keyedvectors.Vocab at 0x1bcde64d208>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x1bcde64d278>,
#  'curry': <gensim.models.keyedvectors.Vocab at 0x1bcde64d2e8>,
#  'jones': <gensim.models.keyedvectors.Vocab at 0x1bcde64d358>,
#  'panophthalmitis': <gensim.models.keyedvectors.Vocab at 0x1bcde64d390>,
#  'endometriosis': <gensim.models.keyedvectors.Vocab at 0x1bcde64d3c8>,
#  'perfume': <gensim.models.keyedvectors.Vocab at 0x1bcde64d438>,
#  'contact': <gensim.models.keyedvectors.Vocab at 0x1bcde64d4a8>,
#  'secondary': <gensim.models.keyedvectors.Vocab at 0x1bcde64d4e0>,
#  'dentin': <gensim.models.keyedvectors.Vocab at 0x1bcde64d550>,
#  'failed': <gensim.models.keyedvectors.Vocab at 0x1bcde64d5c0>,
#  'attempted': <gensim.models.keyedvectors.Vocab at 0x1bcde64d5f8>,
#  'genital': <gensim.models.keyedvectors.Vocab at 0x1bcde64d668>,
#  'tract': <gensim.models.keyedvectors.Vocab at 0x1bcde64d6d8>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x1bcde64d748>,
#  'pelvic': <gensim.models.keyedvectors.Vocab at 0x1bcde64d7b8>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x1bcde64d828>,
#  'dome': <gensim.models.keyedvectors.Vocab at 0x1bcde64d898>,
#  'cyst': <gensim.models.keyedvectors.Vocab at 0x1bcde64d908>,
#  'pneumoparotid': <gensim.models.keyedvectors.Vocab at 0x1bcde64d940>,
#  'tracheal': <gensim.models.keyedvectors.Vocab at 0x1bcde64d978>,
#  'intubation': <gensim.models.keyedvectors.Vocab at 0x1bcde64d9b0>,
#  'morbidity': <gensim.models.keyedvectors.Vocab at 0x1bcde64d9e8>,
#  'urtica': <gensim.models.keyedvectors.Vocab at 0x1bcde64da58>,
#  'incisa': <gensim.models.keyedvectors.Vocab at 0x1bcde64dac8>,
#  'n2': <gensim.models.keyedvectors.Vocab at 0x1bcde64db38>,
#  '7-15': <gensim.models.keyedvectors.Vocab at 0x1bcde64dba8>,
#  'perigastric': <gensim.models.keyedvectors.Vocab at 0x1bcde64dbe0>,
#  'nodes': <gensim.models.keyedvectors.Vocab at 0x1bcde64dc50>,
#  'pseudohypoaldosteronism': <gensim.models.keyedvectors.Vocab at 0x1bcde64dc88>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x1bcde64dcc0>,
#  'recessive': <gensim.models.keyedvectors.Vocab at 0x1bcde64dcf8>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x1bcde64dd68>,
#  'understanding': <gensim.models.keyedvectors.Vocab at 0x1bcde64dda0>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x1bcde64de10>,
#  'instructions': <gensim.models.keyedvectors.Vocab at 0x1bcde64de48>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x1bcde64de80>,
#  'division': <gensim.models.keyedvectors.Vocab at 0x1bcde64deb8>,
#  'extensor': <gensim.models.keyedvectors.Vocab at 0x1bcde64def0>,
#  'tendon': <gensim.models.keyedvectors.Vocab at 0x1bcde64df60>,
#  'dystonic': <gensim.models.keyedvectors.Vocab at 0x1bcde64df98>,
#  'tremor': <gensim.models.keyedvectors.Vocab at 0x1bcde652048>,
#  'idiopathic': <gensim.models.keyedvectors.Vocab at 0x1bcde652080>,
#  'osteoporosis': <gensim.models.keyedvectors.Vocab at 0x1bcde6520b8>,
#  'acetazolamide': <gensim.models.keyedvectors.Vocab at 0x1bcde6520f0>,
#  'undetermined': <gensim.models.keyedvectors.Vocab at 0x1bcde652128>,
#  'intent': <gensim.models.keyedvectors.Vocab at 0x1bcde652198>,
#  'aspiration': <gensim.models.keyedvectors.Vocab at 0x1bcde6521d0>,
#  'adult': <gensim.models.keyedvectors.Vocab at 0x1bcde652240>,
#  'oculodento-osseous': <gensim.models.keyedvectors.Vocab at 0x1bcde652278>,
#  'dysplasia': <gensim.models.keyedvectors.Vocab at 0x1bcde6522b0>,
#  'straddling': <gensim.models.keyedvectors.Vocab at 0x1bcde6522e8>,
#  'blood': <gensim.models.keyedvectors.Vocab at 0x1bcde652358>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x1bcde6523c8>,
#  '>': <gensim.models.keyedvectors.Vocab at 0x1bcde652400>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x1bcde652438>,
#  '<': <gensim.models.keyedvectors.Vocab at 0x1bcde652470>,
#  'fimbriated': <gensim.models.keyedvectors.Vocab at 0x1bcde6524a8>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x1bcde652518>,
#  'fallopian': <gensim.models.keyedvectors.Vocab at 0x1bcde652550>,
#  'tube': <gensim.models.keyedvectors.Vocab at 0x1bcde6525c0>,
#  'closed': <gensim.models.keyedvectors.Vocab at 0x1bcde652630>,
#  'flexural': <gensim.models.keyedvectors.Vocab at 0x1bcde652668>,
#  'lichen': <gensim.models.keyedvectors.Vocab at 0x1bcde6526d8>,
#  'planus': <gensim.models.keyedvectors.Vocab at 0x1bcde652748>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x1bcde6527b8>,
#  'carcinoma': <gensim.models.keyedvectors.Vocab at 0x1bcde6527f0>,
#  'colon': <gensim.models.keyedvectors.Vocab at 0x1bcde652860>,
#  'ii': <gensim.models.keyedvectors.Vocab at 0x1bcde6528d0>,
#  'stricture': <gensim.models.keyedvectors.Vocab at 0x1bcde652908>,
#  'ureteropelvic': <gensim.models.keyedvectors.Vocab at 0x1bcde652940>,
#  'junction': <gensim.models.keyedvectors.Vocab at 0x1bcde652978>,
#  'eccrine': <gensim.models.keyedvectors.Vocab at 0x1bcde6529e8>,
#  'azapropazone': <gensim.models.keyedvectors.Vocab at 0x1bcde652a20>,
#  'helicobacter': <gensim.models.keyedvectors.Vocab at 0x1bcde652a58>,
#  'serology': <gensim.models.keyedvectors.Vocab at 0x1bcde652a90>,
#  'negative': <gensim.models.keyedvectors.Vocab at 0x1bcde652ac8>,
#  'prosthetic': <gensim.models.keyedvectors.Vocab at 0x1bcde652b00>,
#  'aortic': <gensim.models.keyedvectors.Vocab at 0x1bcde652b70>,
#  'requiring': <gensim.models.keyedvectors.Vocab at 0x1bcde652ba8>,
#  'replacement': <gensim.models.keyedvectors.Vocab at 0x1bcde652be0>,
#  'nutrition': <gensim.models.keyedvectors.Vocab at 0x1bcde652c18>,
#  'impaired': <gensim.models.keyedvectors.Vocab at 0x1bcde652c50>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x1bcde652cc0>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x1bcde652d30>,
#  'supplies': <gensim.models.keyedvectors.Vocab at 0x1bcde652d68>,
#  'cartilage': <gensim.models.keyedvectors.Vocab at 0x1bcde652da0>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x1bcde652e10>,
#  'pitt': <gensim.models.keyedvectors.Vocab at 0x1bcde652e80>,
#  'hopkins-like': <gensim.models.keyedvectors.Vocab at 0x1bcde652eb8>,
#  'inadequate': <gensim.models.keyedvectors.Vocab at 0x1bcde652ef0>,
#  'healthcare': <gensim.models.keyedvectors.Vocab at 0x1bcde652f28>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x1bcde652f98>,
#  'compliance': <gensim.models.keyedvectors.Vocab at 0x1bcde652fd0>,
#  'bladder': <gensim.models.keyedvectors.Vocab at 0x1bcde65a080>,
#  't3': <gensim.models.keyedvectors.Vocab at 0x1bcde65a0f0>,
#  'aerodigestive': <gensim.models.keyedvectors.Vocab at 0x1bcde65a128>,
#  'larynx': <gensim.models.keyedvectors.Vocab at 0x1bcde65a198>,
#  'vocal': <gensim.models.keyedvectors.Vocab at 0x1bcde65a208>,
#  'fixation': <gensim.models.keyedvectors.Vocab at 0x1bcde65a240>,
#  'catarrhal': <gensim.models.keyedvectors.Vocab at 0x1bcde65a278>,
#  'bronchitis': <gensim.models.keyedvectors.Vocab at 0x1bcde65a2b0>,
#  'aseptic': <gensim.models.keyedvectors.Vocab at 0x1bcde65a320>,
#  'femoral': <gensim.models.keyedvectors.Vocab at 0x1bcde65a390>,
#  'condyle': <gensim.models.keyedvectors.Vocab at 0x1bcde65a400>,
#  'brudzinski': <gensim.models.keyedvectors.Vocab at 0x1bcde65a438>,
#  'oesophagostomum': <gensim.models.keyedvectors.Vocab at 0x1bcde65a470>,
#  'dentatum': <gensim.models.keyedvectors.Vocab at 0x1bcde65a4a8>,
#  'arrest': <gensim.models.keyedvectors.Vocab at 0x1bcde65a518>,
#  'electrocution': <gensim.models.keyedvectors.Vocab at 0x1bcde65a550>,
#  'anticholinesterase': <gensim.models.keyedvectors.Vocab at 0x1bcde65a588>,
#  'propofol': <gensim.models.keyedvectors.Vocab at 0x1bcde65a5c0>,
#  'deficiency': <gensim.models.keyedvectors.Vocab at 0x1bcde65a5f8>,
#  'phospholipase': <gensim.models.keyedvectors.Vocab at 0x1bcde65a630>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x1bcde65a668>,
#  'depressive': <gensim.models.keyedvectors.Vocab at 0x1bcde65a6a0>,
#  'delusion': <gensim.models.keyedvectors.Vocab at 0x1bcde65a6d8>,
#  'poverty': <gensim.models.keyedvectors.Vocab at 0x1bcde65a748>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x1bcde65a7b8>,
#  'daily': <gensim.models.keyedvectors.Vocab at 0x1bcde65a828>,
#  'persistent': <gensim.models.keyedvectors.Vocab at 0x1bcde65a860>,
#  'headache': <gensim.models.keyedvectors.Vocab at 0x1bcde65a898>,
#  'cystinuria': <gensim.models.keyedvectors.Vocab at 0x1bcde65a8d0>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x1bcde65a940>,
#  'infectious': <gensim.models.keyedvectors.Vocab at 0x1bcde65a978>,
#  'diseases': <gensim.models.keyedvectors.Vocab at 0x1bcde65a9b0>,
#  'physician': <gensim.models.keyedvectors.Vocab at 0x1bcde65a9e8>,
#  'breast': <gensim.models.keyedvectors.Vocab at 0x1bcde65aa58>,
#  'lack': <gensim.models.keyedvectors.Vocab at 0x1bcde65aac8>,
#  'awareness': <gensim.models.keyedvectors.Vocab at 0x1bcde65ab00>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x1bcde65ab70>,
#  'hexosaminidase': <gensim.models.keyedvectors.Vocab at 0x1bcde65aba8>,
#  'familial': <gensim.models.keyedvectors.Vocab at 0x1bcde65abe0>,
#  'osteodysplasia': <gensim.models.keyedvectors.Vocab at 0x1bcde65ac18>,
#  'anderson': <gensim.models.keyedvectors.Vocab at 0x1bcde65ac50>,
#  'coronary': <gensim.models.keyedvectors.Vocab at 0x1bcde65ac88>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x1bcde65acf8>,
#  'monitoring': <gensim.models.keyedvectors.Vocab at 0x1bcde65ad30>,
#  'deleted': <gensim.models.keyedvectors.Vocab at 0x1bcde65ada0>,
#  'hypermelanosis': <gensim.models.keyedvectors.Vocab at 0x1bcde65add8>,
#  'hodgkin': <gensim.models.keyedvectors.Vocab at 0x1bcde65ae48>,
#  'muscular': <gensim.models.keyedvectors.Vocab at 0x1bcde65ae80>,
#  'dystrophy': <gensim.models.keyedvectors.Vocab at 0x1bcde65aeb8>,
#  'divided': <gensim.models.keyedvectors.Vocab at 0x1bcde65af28>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x1bcde65af98>,
#  'atrium': <gensim.models.keyedvectors.Vocab at 0x1bcde660048>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x1bcde6600b8>,
#  'veins': <gensim.models.keyedvectors.Vocab at 0x1bcde660128>,
#  'proximal': <gensim.models.keyedvectors.Vocab at 0x1bcde660160>,
#  'communication': <gensim.models.keyedvectors.Vocab at 0x1bcde660198>,
#  'dislocation': <gensim.models.keyedvectors.Vocab at 0x1bcde6601d0>,
#  'tibia': <gensim.models.keyedvectors.Vocab at 0x1bcde660240>,
#  'rhinophyma': <gensim.models.keyedvectors.Vocab at 0x1bcde660278>,
#  'regular': <gensim.models.keyedvectors.Vocab at 0x1bcde6602e8>,
#  'astigmatism': <gensim.models.keyedvectors.Vocab at 0x1bcde660320>,
#  'corneal': <gensim.models.keyedvectors.Vocab at 0x1bcde660390>,
#  'carpometacarpal': <gensim.models.keyedvectors.Vocab at 0x1bcde6603c8>,
#  'consent': <gensim.models.keyedvectors.Vocab at 0x1bcde660438>,
#  'postmortem': <gensim.models.keyedvectors.Vocab at 0x1bcde660470>,
#  'declined': <gensim.models.keyedvectors.Vocab at 0x1bcde6604a8>,
#  'organic': <gensim.models.keyedvectors.Vocab at 0x1bcde660518>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x1bcde660588>,
#  'cramp': <gensim.models.keyedvectors.Vocab at 0x1bcde6605f8>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x1bcde660668>,
#  'post-stroke': <gensim.models.keyedvectors.Vocab at 0x1bcde6606a0>,
#  'cystic': <gensim.models.keyedvectors.Vocab at 0x1bcde660710>,
#  'duct': <gensim.models.keyedvectors.Vocab at 0x1bcde660780>,
#  'o/e-': <gensim.models.keyedvectors.Vocab at 0x1bcde6607f0>,
#  'visual': <gensim.models.keyedvectors.Vocab at 0x1bcde660860>,
#  'acuity': <gensim.models.keyedvectors.Vocab at 0x1bcde6608d0>,
#  'r-eye': <gensim.models.keyedvectors.Vocab at 0x1bcde660940>,
#  '=6/15': <gensim.models.keyedvectors.Vocab at 0x1bcde6609b0>,
#  'extensive': <gensim.models.keyedvectors.Vocab at 0x1bcde6609e8>,
#  'lipodermatosclerosis': <gensim.models.keyedvectors.Vocab at 0x1bcde660a20>,
#  'fucosidosis': <gensim.models.keyedvectors.Vocab at 0x1bcde660a58>,
#  'finger': <gensim.models.keyedvectors.Vocab at 0x1bcde660ac8>,
#  'feeding': <gensim.models.keyedvectors.Vocab at 0x1bcde660b38>,
#  'onychomycosis': <gensim.models.keyedvectors.Vocab at 0x1bcde660b70>,
#  'trichophyton': <gensim.models.keyedvectors.Vocab at 0x1bcde660ba8>,
#  'tonsurans': <gensim.models.keyedvectors.Vocab at 0x1bcde660be0>,
#  'st': <gensim.models.keyedvectors.Vocab at 0x1bcde660c50>,
#  'interval': <gensim.models.keyedvectors.Vocab at 0x1bcde660c88>,
#  'words': <gensim.models.keyedvectors.Vocab at 0x1bcde660cf8>,
#  'localised': <gensim.models.keyedvectors.Vocab at 0x1bcde660d30>,
#  'amyloid': <gensim.models.keyedvectors.Vocab at 0x1bcde660da0>,
#  'deposit': <gensim.models.keyedvectors.Vocab at 0x1bcde660e10>,
#  'recreation': <gensim.models.keyedvectors.Vocab at 0x1bcde660e48>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x1bcde660eb8>,
#  'myxoid': <gensim.models.keyedvectors.Vocab at 0x1bcde660f28>,
#  'dermatofibrosarcoma': <gensim.models.keyedvectors.Vocab at 0x1bcde660f60>,
#  'protuberans': <gensim.models.keyedvectors.Vocab at 0x1bcde660f98>,
#  'epithelial': <gensim.models.keyedvectors.Vocab at 0x1bcde660fd0>,
#  'figo': <gensim.models.keyedvectors.Vocab at 0x1bcde667080>,
#  'ivb': <gensim.models.keyedvectors.Vocab at 0x1bcde6670f0>,
#  'metacarpophalangeal': <gensim.models.keyedvectors.Vocab at 0x1bcde667128>,
#  'hypermobility': <gensim.models.keyedvectors.Vocab at 0x1bcde667160>,
#  'hyperactive': <gensim.models.keyedvectors.Vocab at 0x1bcde667198>,
#  'bilateral': <gensim.models.keyedvectors.Vocab at 0x1bcde6671d0>,
#  'labyrinthine': <gensim.models.keyedvectors.Vocab at 0x1bcde667208>,
#  'dysfunction': <gensim.models.keyedvectors.Vocab at 0x1bcde667240>,
#  'hypo-osmolality': <gensim.models.keyedvectors.Vocab at 0x1bcde667278>,
#  'hyponatraemia': <gensim.models.keyedvectors.Vocab at 0x1bcde6672b0>,
#  'pyloric': <gensim.models.keyedvectors.Vocab at 0x1bcde667320>,
#  'antrum': <gensim.models.keyedvectors.Vocab at 0x1bcde667390>,
#  'trisomy': <gensim.models.keyedvectors.Vocab at 0x1bcde667400>,
#  '10p': <gensim.models.keyedvectors.Vocab at 0x1bcde667470>,
#  'amidophosphoribosyltransferase': <gensim.models.keyedvectors.Vocab at 0x1bcde6674a8>,
#  'gds': <gensim.models.keyedvectors.Vocab at 0x1bcde667518>,
#  'cognitive': <gensim.models.keyedvectors.Vocab at 0x1bcde667550>,
#  'decline': <gensim.models.keyedvectors.Vocab at 0x1bcde6675c0>,
#  'nanophyetus': <gensim.models.keyedvectors.Vocab at 0x1bcde6675f8>,
#  'salmincola': <gensim.models.keyedvectors.Vocab at 0x1bcde667630>,
#  'metacarpal': <gensim.models.keyedvectors.Vocab at 0x1bcde667668>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x1bcde6676d8>,
#  'intra-articular': <gensim.models.keyedvectors.Vocab at 0x1bcde667710>,
#  'rolando': <gensim.models.keyedvectors.Vocab at 0x1bcde667780>,
#  'implantation': <gensim.models.keyedvectors.Vocab at 0x1bcde6677b8>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x1bcde667828>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x1bcde667898>,
#  'tower': <gensim.models.keyedvectors.Vocab at 0x1bcde667908>,
#  'ureteric': <gensim.models.keyedvectors.Vocab at 0x1bcde667940>,
#  'stent': <gensim.models.keyedvectors.Vocab at 0x1bcde6679b0>,
#  'fetal': <gensim.models.keyedvectors.Vocab at 0x1bcde667a20>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x1bcde667a90>,
#  'conspicuous': <gensim.models.keyedvectors.Vocab at 0x1bcde667ac8>,
#  'donor': <gensim.models.keyedvectors.Vocab at 0x1bcde667b38>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x1bcde667ba8>,
#  'erectile': <gensim.models.keyedvectors.Vocab at 0x1bcde667be0>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x1bcde667c18>,
#  'radical': <gensim.models.keyedvectors.Vocab at 0x1bcde667c88>,
#  'cystectomy': <gensim.models.keyedvectors.Vocab at 0x1bcde667cc0>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x1bcde667d30>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x1bcde667da0>,
#  'bath': <gensim.models.keyedvectors.Vocab at 0x1bcde667e10>,
#  'flucytosine': <gensim.models.keyedvectors.Vocab at 0x1bcde667e48>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x1bcde667e80>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x1bcde667ef0>,
#  'gestation': <gensim.models.keyedvectors.Vocab at 0x1bcde667f28>,
#  'period': <gensim.models.keyedvectors.Vocab at 0x1bcde667f98>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x1bcde667fd0>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x1bcde66d080>,
#  'nephrotic': <gensim.models.keyedvectors.Vocab at 0x1bcde66d0b8>,
#  'malaria': <gensim.models.keyedvectors.Vocab at 0x1bcde66d128>,
#  'homozygous': <gensim.models.keyedvectors.Vocab at 0x1bcde66d160>,
#  'beta': <gensim.models.keyedvectors.Vocab at 0x1bcde66d1d0>,
#  'thalassaemia': <gensim.models.keyedvectors.Vocab at 0x1bcde66d208>,
#  'purulent': <gensim.models.keyedvectors.Vocab at 0x1bcde66d240>,
#  'pericarditis': <gensim.models.keyedvectors.Vocab at 0x1bcde66d278>,
#  'florid': <gensim.models.keyedvectors.Vocab at 0x1bcde66d2e8>,
#  'reactive': <gensim.models.keyedvectors.Vocab at 0x1bcde66d320>,
#  'periostitis': <gensim.models.keyedvectors.Vocab at 0x1bcde66d358>,
#  'dermatosis': <gensim.models.keyedvectors.Vocab at 0x1bcde66d390>,
#  'spider': <gensim.models.keyedvectors.Vocab at 0x1bcde66d400>,
#  'thin': <gensim.models.keyedvectors.Vocab at 0x1bcde66d470>,
#  'sputum': <gensim.models.keyedvectors.Vocab at 0x1bcde66d4e0>,
#  'lesion': <gensim.models.keyedvectors.Vocab at 0x1bcde66d550>,
#  'moderate': <gensim.models.keyedvectors.Vocab at 0x1bcde66d588>,
#  'receptive': <gensim.models.keyedvectors.Vocab at 0x1bcde66d5c0>,
#  'language': <gensim.models.keyedvectors.Vocab at 0x1bcde66d5f8>,
#  'delay': <gensim.models.keyedvectors.Vocab at 0x1bcde66d668>,
#  'and/or': <gensim.models.keyedvectors.Vocab at 0x1bcde66d6d8>,
#  'recurrent': <gensim.models.keyedvectors.Vocab at 0x1bcde66d710>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x1bcde66d780>,
#  'osteoarthritis': <gensim.models.keyedvectors.Vocab at 0x1bcde66d7b8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x1bcde66d828>,
#  'metatarsophalangeal': <gensim.models.keyedvectors.Vocab at 0x1bcde66d860>,
#  'inflammatory': <gensim.models.keyedvectors.Vocab at 0x1bcde66d898>,
#  'arthritis': <gensim.models.keyedvectors.Vocab at 0x1bcde66d8d0>,
#  'waldenstrom': <gensim.models.keyedvectors.Vocab at 0x1bcde66d908>,
#  'hypergammaglobulinaemic': <gensim.models.keyedvectors.Vocab at 0x1bcde66d940>,
#  'purpura': <gensim.models.keyedvectors.Vocab at 0x1bcde66d9b0>,
#  'atresia': <gensim.models.keyedvectors.Vocab at 0x1bcde66da20>,
#  'atrophy': <gensim.models.keyedvectors.Vocab at 0x1bcde66da90>,
#  'vas': <gensim.models.keyedvectors.Vocab at 0x1bcde66db00>,
#  'deferens': <gensim.models.keyedvectors.Vocab at 0x1bcde66db38>,
#  'axillary': <gensim.models.keyedvectors.Vocab at 0x1bcde66db70>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x1bcde66dbe0>,
#  'tanner': <gensim.models.keyedvectors.Vocab at 0x1bcde66dc50>,
#  'wasp': <gensim.models.keyedvectors.Vocab at 0x1bcde66dcc0>,
#  'sting-induced': <gensim.models.keyedvectors.Vocab at 0x1bcde66dcf8>,
#  'anaphylaxis': <gensim.models.keyedvectors.Vocab at 0x1bcde66dd30>,
#  'ascites': <gensim.models.keyedvectors.Vocab at 0x1bcde66dda0>,
#  'prelogical': <gensim.models.keyedvectors.Vocab at 0x1bcde66ddd8>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x1bcde66de10>,
#  'celatum': <gensim.models.keyedvectors.Vocab at 0x1bcde66de80>,
#  'frotteurism': <gensim.models.keyedvectors.Vocab at 0x1bcde66deb8>,
#  'aneurysm': <gensim.models.keyedvectors.Vocab at 0x1bcde66def0>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x1bcde66df60>,
#  'cerebral': <gensim.models.keyedvectors.Vocab at 0x1bcde66df98>,
#  'requires': <gensim.models.keyedvectors.Vocab at 0x1bcde66dfd0>,
#  'varicella': <gensim.models.keyedvectors.Vocab at 0x1bcde674048>,
#  'vaccination': <gensim.models.keyedvectors.Vocab at 0x1bcde674080>,
# ...
#  'acceptance': <gensim.models.keyedvectors.Vocab at 0x1bcde674b70>,
#  'grief': <gensim.models.keyedvectors.Vocab at 0x1bcde674be0>,
#  't2': <gensim.models.keyedvectors.Vocab at 0x1bcde674c50>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x1bcde674c88>,
#  'cm': <gensim.models.keyedvectors.Vocab at 0x1bcde674cf8>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x1bcde674d30>,
#  'dimension': <gensim.models.keyedvectors.Vocab at 0x1bcde674d68>,
#  'extraparenchymal': <gensim.models.keyedvectors.Vocab at 0x1bcde674da0>,
#  'ceftizoxime': <gensim.models.keyedvectors.Vocab at 0x1bcde674dd8>,
#  'painful': <gensim.models.keyedvectors.Vocab at 0x1bcde674e48>,
#  'gastric': <gensim.models.keyedvectors.Vocab at 0x1bcde674eb8>,
#  'emptying': <gensim.models.keyedvectors.Vocab at 0x1bcde674ef0>,
#  'fractured': <gensim.models.keyedvectors.Vocab at 0x1bcde674f28>,
#  'dental': <gensim.models.keyedvectors.Vocab at 0x1bcde674f98>,
#  'veneer': <gensim.models.keyedvectors.Vocab at 0x1bcde67a048>,
#  'gastromenia': <gensim.models.keyedvectors.Vocab at 0x1bcde67a080>,
#  'perioperative': <gensim.models.keyedvectors.Vocab at 0x1bcde67a0b8>,
#  'isophane': <gensim.models.keyedvectors.Vocab at 0x1bcde67a0f0>,
#  'insulin': <gensim.models.keyedvectors.Vocab at 0x1bcde67a160>,
#  'peroneal': <gensim.models.keyedvectors.Vocab at 0x1bcde67a198>,
#  'tendinitis': <gensim.models.keyedvectors.Vocab at 0x1bcde67a1d0>,
#  'cutis': <gensim.models.keyedvectors.Vocab at 0x1bcde67a240>,
#  'laxa': <gensim.models.keyedvectors.Vocab at 0x1bcde67a2b0>,
#  'faecal': <gensim.models.keyedvectors.Vocab at 0x1bcde67a320>,
#  'peritonitis': <gensim.models.keyedvectors.Vocab at 0x1bcde67a358>,
#  'incipient': <gensim.models.keyedvectors.Vocab at 0x1bcde67a390>,
#  'clean': <gensim.models.keyedvectors.Vocab at 0x1bcde67a400>,
#  'windows': <gensim.models.keyedvectors.Vocab at 0x1bcde67a470>,
#  'functional': <gensim.models.keyedvectors.Vocab at 0x1bcde67a4a8>,
#  'proteinuria': <gensim.models.keyedvectors.Vocab at 0x1bcde67a4e0>,
#  'infestation': <gensim.models.keyedvectors.Vocab at 0x1bcde67a518>,
#  'oedemagena': <gensim.models.keyedvectors.Vocab at 0x1bcde67a550>,
#  'coordinate': <gensim.models.keyedvectors.Vocab at 0x1bcde67a588>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x1bcde67a5c0>,
#  'plans': <gensim.models.keyedvectors.Vocab at 0x1bcde67a630>,
#  'strain': <gensim.models.keyedvectors.Vocab at 0x1bcde67a6a0>,
#  'muscle': <gensim.models.keyedvectors.Vocab at 0x1bcde67a710>,
#  'ear': <gensim.models.keyedvectors.Vocab at 0x1bcde67a780>,
#  'ring': <gensim.models.keyedvectors.Vocab at 0x1bcde67a7f0>,
#  'chromosome': <gensim.models.keyedvectors.Vocab at 0x1bcde67a828>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x1bcde67a898>,
#  'vallecular': <gensim.models.keyedvectors.Vocab at 0x1bcde67a8d0>,
#  'focal': <gensim.models.keyedvectors.Vocab at 0x1bcde67a940>,
#  'injuries': <gensim.models.keyedvectors.Vocab at 0x1bcde67a978>,
#  'cerebellum': <gensim.models.keyedvectors.Vocab at 0x1bcde67a9b0>,
#  'beta-galactosidase': <gensim.models.keyedvectors.Vocab at 0x1bcde67a9e8>,
#  'increased': <gensim.models.keyedvectors.Vocab at 0x1bcde67aa20>,
#  'passive': <gensim.models.keyedvectors.Vocab at 0x1bcde67aa90>,
#  'ovary': <gensim.models.keyedvectors.Vocab at 0x1bcde67ab00>,
#  'toxic': <gensim.models.keyedvectors.Vocab at 0x1bcde67ab70>,
#  'myocarditis': <gensim.models.keyedvectors.Vocab at 0x1bcde67aba8>,
#  'resting': <gensim.models.keyedvectors.Vocab at 0x1bcde67ac18>,
#  'ischaemia': <gensim.models.keyedvectors.Vocab at 0x1bcde67ac50>,
#  'co-occurrent': <gensim.models.keyedvectors.Vocab at 0x1bcde67ac88>,
#  'ischaemic': <gensim.models.keyedvectors.Vocab at 0x1bcde67acc0>,
#  'outpatient': <gensim.models.keyedvectors.Vocab at 0x1bcde67acf8>,
#  'appointment': <gensim.models.keyedvectors.Vocab at 0x1bcde67ad30>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x1bcde67ada0>,
#  'footwear': <gensim.models.keyedvectors.Vocab at 0x1bcde67add8>,
#  'showing': <gensim.models.keyedvectors.Vocab at 0x1bcde67ae48>,
#  'signs': <gensim.models.keyedvectors.Vocab at 0x1bcde67aeb8>,
#  'construction': <gensim.models.keyedvectors.Vocab at 0x1bcde67aef0>,
#  'carmustine': <gensim.models.keyedvectors.Vocab at 0x1bcde67af28>,
#  'temporal': <gensim.models.keyedvectors.Vocab at 0x1bcde67af60>,
#  'lobar': <gensim.models.keyedvectors.Vocab at 0x1bcde67afd0>,
#  'radial': <gensim.models.keyedvectors.Vocab at 0x1bcde67f080>,
#  'polydactyly': <gensim.models.keyedvectors.Vocab at 0x1bcde67f0b8>,
#  'wassel': <gensim.models.keyedvectors.Vocab at 0x1bcde67f128>,
#  'amianthium': <gensim.models.keyedvectors.Vocab at 0x1bcde67f160>,
#  'muscaetoxicum': <gensim.models.keyedvectors.Vocab at 0x1bcde67f198>,
#  'fibrosis': <gensim.models.keyedvectors.Vocab at 0x1bcde67f1d0>,
#  'hermansky-pudlak': <gensim.models.keyedvectors.Vocab at 0x1bcde67f208>,
#  'postpancreatectomy': <gensim.models.keyedvectors.Vocab at 0x1bcde67f240>,
#  'hyperglycaemia': <gensim.models.keyedvectors.Vocab at 0x1bcde67f278>,
#  'pneumococcal': <gensim.models.keyedvectors.Vocab at 0x1bcde67f2b0>,
#  'return': <gensim.models.keyedvectors.Vocab at 0x1bcde67f320>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x1bcde67f390>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x1bcde67f400>,
#  'necessary': <gensim.models.keyedvectors.Vocab at 0x1bcde67f438>,
#  'entire': <gensim.models.keyedvectors.Vocab at 0x1bcde67f4a8>,
#  'pyrroline-2-carboxylate': <gensim.models.keyedvectors.Vocab at 0x1bcde67f4e0>,
#  'reductase': <gensim.models.keyedvectors.Vocab at 0x1bcde67f518>,
#  'leakage': <gensim.models.keyedvectors.Vocab at 0x1bcde67f588>,
#  'pyloroplasty': <gensim.models.keyedvectors.Vocab at 0x1bcde67f5c0>,
#  'growth': <gensim.models.keyedvectors.Vocab at 0x1bcde67f630>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x1bcde67f668>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x1bcde67f6d8>,
#  'difficult': <gensim.models.keyedvectors.Vocab at 0x1bcde67f710>,
#  'establish': <gensim.models.keyedvectors.Vocab at 0x1bcde67f748>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x1bcde67f780>,
#  'deaf': <gensim.models.keyedvectors.Vocab at 0x1bcde67f7f0>,
#  'epilepsy': <gensim.models.keyedvectors.Vocab at 0x1bcde67f828>,
#  'eyelid': <gensim.models.keyedvectors.Vocab at 0x1bcde67f898>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x1bcde67f8d0>,
#  'canthus': <gensim.models.keyedvectors.Vocab at 0x1bcde67f940>,
#  'combined': <gensim.models.keyedvectors.Vocab at 0x1bcde67f978>,
#  'immunodeficiency': <gensim.models.keyedvectors.Vocab at 0x1bcde67f9b0>,
#  'zap70': <gensim.models.keyedvectors.Vocab at 0x1bcde67fa20>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x1bcde67fa90>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x1bcde67fb00>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x1bcde67fb70>,
#  'strangulation': <gensim.models.keyedvectors.Vocab at 0x1bcde67fba8>,
#  'slow': <gensim.models.keyedvectors.Vocab at 0x1bcde67fc18>,
#  'acetylator': <gensim.models.keyedvectors.Vocab at 0x1bcde67fc50>,
#  'n-acetyltransferase': <gensim.models.keyedvectors.Vocab at 0x1bcde67fc88>,
#  'enzyme': <gensim.models.keyedvectors.Vocab at 0x1bcde67fcf8>,
#  'variant': <gensim.models.keyedvectors.Vocab at 0x1bcde67fd68>,
#  'intracellular': <gensim.models.keyedvectors.Vocab at 0x1bcde67fda0>,
#  'elementary': <gensim.models.keyedvectors.Vocab at 0x1bcde67fdd8>,
#  'bodies': <gensim.models.keyedvectors.Vocab at 0x1bcde67fe48>,
#  'detected': <gensim.models.keyedvectors.Vocab at 0x1bcde67fe80>,
#  'diffuse': <gensim.models.keyedvectors.Vocab at 0x1bcde67fef0>,
#  'neurofibroma': <gensim.models.keyedvectors.Vocab at 0x1bcde67ff28>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x1bcde67ff60>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x1bcde67ffd0>,
#  'sinus': <gensim.models.keyedvectors.Vocab at 0x1bcde686080>,
#  'surgical': <gensim.models.keyedvectors.Vocab at 0x1bcde6860b8>,
#  'procedure': <gensim.models.keyedvectors.Vocab at 0x1bcde6860f0>,
#  'echo': <gensim.models.keyedvectors.Vocab at 0x1bcde686160>,
#  'razoxane': <gensim.models.keyedvectors.Vocab at 0x1bcde686198>,
#  'privacy': <gensim.models.keyedvectors.Vocab at 0x1bcde686208>,
#  'maintained': <gensim.models.keyedvectors.Vocab at 0x1bcde686240>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x1bcde6862b0>,
#  'sperm': <gensim.models.keyedvectors.Vocab at 0x1bcde686320>,
#  'morphology': <gensim.models.keyedvectors.Vocab at 0x1bcde686358>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x1bcde6863c8>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x1bcde686438>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x1bcde6864a8>,
#  '%': <gensim.models.keyedvectors.Vocab at 0x1bcde6864e0>,
#  'tension': <gensim.models.keyedvectors.Vocab at 0x1bcde686550>,
#  'pneumothorax': <gensim.models.keyedvectors.Vocab at 0x1bcde686588>,
#  'gallbladder': <gensim.models.keyedvectors.Vocab at 0x1bcde6865c0>,
#  'palpated': <gensim.models.keyedvectors.Vocab at 0x1bcde6865f8>,
#  'osteosclerotic': <gensim.models.keyedvectors.Vocab at 0x1bcde686630>,
#  'myeloma': <gensim.models.keyedvectors.Vocab at 0x1bcde6866a0>,
#  'patellofemoral': <gensim.models.keyedvectors.Vocab at 0x1bcde6866d8>,
#  'maltracking': <gensim.models.keyedvectors.Vocab at 0x1bcde686710>,
#  'transplanted': <gensim.models.keyedvectors.Vocab at 0x1bcde686748>,
#  'pt3': <gensim.models.keyedvectors.Vocab at 0x1bcde6867b8>,
#  'directly': <gensim.models.keyedvectors.Vocab at 0x1bcde6867f0>,
#  'invades': <gensim.models.keyedvectors.Vocab at 0x1bcde686860>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x1bcde6868d0>,
#  'chest': <gensim.models.keyedvectors.Vocab at 0x1bcde686940>,
#  'diaphragm': <gensim.models.keyedvectors.Vocab at 0x1bcde686978>,
#  'mediastinal': <gensim.models.keyedvectors.Vocab at 0x1bcde6869b0>,
#  'pleura': <gensim.models.keyedvectors.Vocab at 0x1bcde686a20>,
#  'parietal': <gensim.models.keyedvectors.Vocab at 0x1bcde686a58>,
#  'pericardium': <gensim.models.keyedvectors.Vocab at 0x1bcde686a90>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x1bcde686ac8>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x1bcde686b38>,
#  'bronchus': <gensim.models.keyedvectors.Vocab at 0x1bcde686b70>,
#  'distal': <gensim.models.keyedvectors.Vocab at 0x1bcde686be0>,
#  'carina': <gensim.models.keyedvectors.Vocab at 0x1bcde686c50>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x1bcde686cc0>,
#  'assoc': <gensim.models.keyedvectors.Vocab at 0x1bcde686d30>,
#  'atelectasis': <gensim.models.keyedvectors.Vocab at 0x1bcde686d68>,
#  'obstructive': <gensim.models.keyedvectors.Vocab at 0x1bcde686da0>,
#  'pneumonitis': <gensim.models.keyedvectors.Vocab at 0x1bcde686dd8>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x1bcde686e48>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x1bcde686eb8>,
#  'cheek': <gensim.models.keyedvectors.Vocab at 0x1bcde686f28>,
#  'suprasellar': <gensim.models.keyedvectors.Vocab at 0x1bcde686f60>,
#  'pituitary': <gensim.models.keyedvectors.Vocab at 0x1bcde686f98>,
#  'adenoma': <gensim.models.keyedvectors.Vocab at 0x1bcde68d048>,
#  'colour': <gensim.models.keyedvectors.Vocab at 0x1bcde68d0b8>,
#  'tympanic': <gensim.models.keyedvectors.Vocab at 0x1bcde68d0f0>,
#  'membrane': <gensim.models.keyedvectors.Vocab at 0x1bcde68d128>,
#  'glandular': <gensim.models.keyedvectors.Vocab at 0x1bcde68d160>,
#  'neurilemmoma': <gensim.models.keyedvectors.Vocab at 0x1bcde68d198>,
#  'aminophylline': <gensim.models.keyedvectors.Vocab at 0x1bcde68d1d0>,
#  'terbufos': <gensim.models.keyedvectors.Vocab at 0x1bcde68d208>,
#  'susceptibility': <gensim.models.keyedvectors.Vocab at 0x1bcde68d240>,
#  'infections': <gensim.models.keyedvectors.Vocab at 0x1bcde68d278>,
#  'apnoea': <gensim.models.keyedvectors.Vocab at 0x1bcde68d2e8>,
#  'newborn': <gensim.models.keyedvectors.Vocab at 0x1bcde68d358>,
#  'chondrocalcinosis': <gensim.models.keyedvectors.Vocab at 0x1bcde68d390>,
#  'anomalous': <gensim.models.keyedvectors.Vocab at 0x1bcde68d3c8>,
#  'origin': <gensim.models.keyedvectors.Vocab at 0x1bcde68d438>,
#  'arterial': <gensim.models.keyedvectors.Vocab at 0x1bcde68d470>,
#  'subclavian': <gensim.models.keyedvectors.Vocab at 0x1bcde68d4a8>,
#  'rolling': <gensim.models.keyedvectors.Vocab at 0x1bcde68d518>,
#  'hiatus': <gensim.models.keyedvectors.Vocab at 0x1bcde68d588>,
#  'hernia': <gensim.models.keyedvectors.Vocab at 0x1bcde68d5f8>,
#  'volvulus': <gensim.models.keyedvectors.Vocab at 0x1bcde68d630>,
#  'pustular': <gensim.models.keyedvectors.Vocab at 0x1bcde68d668>,
#  'chilblain': <gensim.models.keyedvectors.Vocab at 0x1bcde68d6a0>,
#  'kalanchoe': <gensim.models.keyedvectors.Vocab at 0x1bcde68d6d8>,
#  'species': <gensim.models.keyedvectors.Vocab at 0x1bcde68d748>,
#  'benign': <gensim.models.keyedvectors.Vocab at 0x1bcde68d7b8>,
#  'vessel': <gensim.models.keyedvectors.Vocab at 0x1bcde68d828>,
#  'thorax': <gensim.models.keyedvectors.Vocab at 0x1bcde68d898>,
#  'aspirate': <gensim.models.keyedvectors.Vocab at 0x1bcde68d8d0>,
#  'applicable': <gensim.models.keyedvectors.Vocab at 0x1bcde68d908>,
#  'pelvis': <gensim.models.keyedvectors.Vocab at 0x1bcde68d978>,
#  'pure': <gensim.models.keyedvectors.Vocab at 0x1bcde68d9e8>,
#  'hyperglyceridaemia': <gensim.models.keyedvectors.Vocab at 0x1bcde68da20>,
#  'ctg': <gensim.models.keyedvectors.Vocab at 0x1bcde68da90>,
#  'tracing': <gensim.models.keyedvectors.Vocab at 0x1bcde68db00>,
#  'vaginal': <gensim.models.keyedvectors.Vocab at 0x1bcde68db70>,
#  'secretions': <gensim.models.keyedvectors.Vocab at 0x1bcde68dba8>,
#  'manifest-latent': <gensim.models.keyedvectors.Vocab at 0x1bcde68dbe0>,
#  'gross': <gensim.models.keyedvectors.Vocab at 0x1bcde68dc50>,
#  'inspection': <gensim.models.keyedvectors.Vocab at 0x1bcde68dc88>,
#  'evaluation': <gensim.models.keyedvectors.Vocab at 0x1bcde68dcc0>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x1bcde68dcf8>,
#  'perioral': <gensim.models.keyedvectors.Vocab at 0x1bcde68dd30>,
#  'periocular': <gensim.models.keyedvectors.Vocab at 0x1bcde68dd68>,
#  'klebsiella': <gensim.models.keyedvectors.Vocab at 0x1bcde68dda0>,
#  'cystitis': <gensim.models.keyedvectors.Vocab at 0x1bcde68ddd8>,
#  'binge': <gensim.models.keyedvectors.Vocab at 0x1bcde68de48>,
#  'obstruction': <gensim.models.keyedvectors.Vocab at 0x1bcde68de80>,
#  'client': <gensim.models.keyedvectors.Vocab at 0x1bcde68def0>,
#  'requests': <gensim.models.keyedvectors.Vocab at 0x1bcde68df28>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x1bcde68df98>,
#  'personal': <gensim.models.keyedvectors.Vocab at 0x1bcde68dfd0>,
#  'records': <gensim.models.keyedvectors.Vocab at 0x1bcde694080>,
#  'tyrosinaemia': <gensim.models.keyedvectors.Vocab at 0x1bcde6940b8>,
#  'haemolytic': <gensim.models.keyedvectors.Vocab at 0x1bcde6940f0>,
#  'anaemia': <gensim.models.keyedvectors.Vocab at 0x1bcde694160>,
#  'hyperbaric': <gensim.models.keyedvectors.Vocab at 0x1bcde694198>,
#  'oxygen': <gensim.models.keyedvectors.Vocab at 0x1bcde694208>,
#  'limbal': <gensim.models.keyedvectors.Vocab at 0x1bcde694278>,
#  'guttering': <gensim.models.keyedvectors.Vocab at 0x1bcde6942b0>,
#  'descending': <gensim.models.keyedvectors.Vocab at 0x1bcde6942e8>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x1bcde694358>,
#  'abdominal': <gensim.models.keyedvectors.Vocab at 0x1bcde694390>,
#  'cavity': <gensim.models.keyedvectors.Vocab at 0x1bcde694400>,
#  'macrosquare-wave': <gensim.models.keyedvectors.Vocab at 0x1bcde694438>,
#  'jerks': <gensim.models.keyedvectors.Vocab at 0x1bcde6944a8>,
#  'transient': <gensim.models.keyedvectors.Vocab at 0x1bcde6944e0>,
#  'tachypnoea': <gensim.models.keyedvectors.Vocab at 0x1bcde694518>,
#  'prescription': <gensim.models.keyedvectors.Vocab at 0x1bcde694550>,
#  'collected': <gensim.models.keyedvectors.Vocab at 0x1bcde694588>,
#  'patient': <gensim.models.keyedvectors.Vocab at 0x1bcde6945f8>,
#  'presence': <gensim.models.keyedvectors.Vocab at 0x1bcde694630>,
#  'muscularis': <gensim.models.keyedvectors.Vocab at 0x1bcde694668>,
#  'propria': <gensim.models.keyedvectors.Vocab at 0x1bcde6946d8>,
#  'specimen': <gensim.models.keyedvectors.Vocab at 0x1bcde694710>,
#  'indeterminate': <gensim.models.keyedvectors.Vocab at 0x1bcde694748>,
#  'pott': <gensim.models.keyedvectors.Vocab at 0x1bcde6947b8>,
#  'curvature': <gensim.models.keyedvectors.Vocab at 0x1bcde6947f0>,
#  'stress': <gensim.models.keyedvectors.Vocab at 0x1bcde694860>,
#  ...}

# %% [markdown]
# ## Testing the model

# %%
data_frame.head()
try:
    data_frame.set_index("code", inplace=True)
except KeyError:
    pass
data_frame.head()
# Out:
#                                                            display
# code
# 303921000119109  Chronic tophaceous gout of hand due to renal i...
# 450309001        Major systemic to pulmonary collateral artery ...
# 428799009               Rotatory subluxation of atlantoaxial joint
# 93936002               Primary malignant neoplasm of palatine bone
# 164510000                               O/E - elbow joint abnormal

# %%
for _ in range(2):
    test_doc = word_tokenize("I think you are sufferring from major systematic to Pulmonary collateral artery supplyiing right lung".lower())
    print(model.docvecs.most_similar(positive=[model.infer_vector(test_doc)],topn=5))
    best_result = model.docvecs.most_similar(positive=[model.infer_vector(test_doc)],topn=1)
    print(list(data_frame.loc[int(best_result[0][0]), "display"]))
    print("Best Result: ",best_result[0][0])
    print("Sureity percntage: ",best_result[0][1])
# Out:
# [('719098007', 0.11558675020933151), ('707467004', 0.10146358609199524), ('369881000', 0.09773489832878113), ('450309001', 0.08361873030662537), ('707530009', 0.0750858336687088)]
# ['Primary salivary gland type carcinoma of lung', 'Primary salivary gland type carcinoma lung ']
# Best Result:  707467004
# Sureity percntage:  0.2959973216056824
# [('450309001', 0.2442864179611206), ('719098007', 0.2084171324968338), ('450308009', 0.19240570068359375), ('697910001', 0.19021475315093994), ('450307004', 0.1856318563222885)]
# ['Major systemic to pulmonary collateral artery supplying part of right lung', 'Major pulmonary collateral artery right lung ']
# Best Result:  450309001
# Sureity percntage:  0.18912406265735626

# %% [markdown]
# Thank you

# %%
test_doc = word_tokenize("major systematic to Pulmonary collateral artery supplying right lung".lower())
tokenized_Doc = []
id_results=[]
for _ in range(2):
    model.docvecs.most_similar(positive=[model.infer_vector(test_doc)],topn=5)
    best_result = model.docvecs.most_similar(positive=[model.infer_vector(test_doc)],topn=1)
    most_similar = data_frame.loc[int(best_result[0][0]), "display"]
    lst = list(most_similar)
    print(lst)
    id_results.append(best_result[0][0])
    tokenized_Doc.append(word_tokenize(lst[0]))
    print("Best Result: ",best_result[0][0])
    print("Sureity percntage: ",best_result[0][1])
i = 0
j = 0
for _ in test_doc:
    if _ in tokenized_Doc[0]:
        i+=1
    if _ in tokenized_Doc[1]:
        j+=1
print(i, j)
print(id_results)
print(tokenized_Doc, test_doc)
# Out:
# ['Primary salivary gland type carcinoma of lung', 'Primary salivary gland type carcinoma lung ']
# Best Result:  707467004
# Sureity percntage:  0.6447983980178833
# ['Major systemic to pulmonary collateral artery supplying part of right lung', 'Major pulmonary collateral artery right lung ']
# Best Result:  450309001
# Sureity percntage:  0.6174723505973816
# 1 7
# ['707467004', '450309001']
# [['Primary', 'salivary', 'gland', 'type', 'carcinoma', 'of', 'lung'], ['Major', 'systemic', 'to', 'pulmonary', 'collateral', 'artery', 'supplying', 'part', 'of', 'right', 'lung']] ['major', 'systematic', 'to', 'pulmonary', 'collateral', 'artery', 'supplying', 'right', 'lung']

# %%
minimum_len = min(len(tokenized_Doc[0]),len(tokenized_Doc[1]), len(test_doc))
if minimum_len >3:
    if i >=3 or j >= 3:
        if i >= j: 
            print(id_results[0])
        else: print(id_results[1])
            
    else:
        print("true")
else:
    if i>=2 or j>=2:
        if i >= j: print(id_results[0])
        else: print(id_results[1])
    else:
        print("true")
# Out:
# 450309001
