# %% [markdown]
# # AI Model Notebook

# %% [markdown]
# ## Imports

# %%
import numpy as np
from spacy.lang.en import English
import pandas as pd
import os
os.chdir('../')

# %% [markdown]
# ## Data Processing

# %%
data = "./data/main_data.csv"
read_csv = pd.read_csv(data)
read_csv
# Out:
#                    code                                            display
# 0       303921000119109  Chronic tophaceous gout of hand due to renal i...
# 1             450309001  Major systemic to pulmonary collateral artery ...
# 2             428799009         Rotatory subluxation of atlantoaxial joint
# 3              93936002        Primary malignant neoplasm of palatine bone
# 4             164510000                         O/E - elbow joint abnormal
# 5             200370007  Obstetric nipple infection with postnatal comp...
# 6             247002006       Anterior chamber pseudo-exfoliation deposits
# 7             280948003                           Normal sense of identity
# 8             288642003                         Does initiate conversation
# 9             783619003  DYRK1A-related intellectual disability syndrom...
# 10             95469008                           Abnormal plantar creases
# 11            173599005     Acute necrotising ulcerative gingivostomatitis
# 12             75697004      Term birth of identical twins, both stillborn
# 13            237138004                          Menopause ovarian failure
# 14            170561004                     Chronic disease - poor control
# 15            294695007                                  Cortisone allergy
# 16            282626003                            Able to roll on to side
# 17             64787009  Displacement of thoracic intervertebral disc w...
# 18            424629004  Transportation barrier impedes ability to use ...
# 19            239826001  Chronic infantile neurological, cutaneous and ...
# 20            253595004                           Pulmonary valve prolapse
# 21            240022008                        Posterior ankle impingement
# 22      135001000119100  Acute deep venous thrombosis of internal jugul...
# 23              6224002                      Decreased hormonal resistance
# 24            263170006                       Fracture of supraorbital rim
# 25            277850002                                  Diogenes syndrome
# 26            164641005                            O/E - sign - ankle/foot
# 27            447777009  Spontaneous closure of ventricular component o...
# 28            719254001                     Spinocerebellar ataxia type 32
# 29            161818003                                  Vulval irritation
# ...                 ...                                                ...
# 221402        234119001                         Congenital anomaly artery
# 221403        359557001                                   Disorder artery
# 221404        762250009                   Congenital anomaly great vessel
# 221405        400159008                  Congenital vascular malformation
# 221406        399982001                      Congenital vascular disorder
# 221407          9904008          Congenital anomaly cardiovascular system
# 221408        762228008                Congenital cardiovascular disorder
# 221409         39785005                    Disorder pulmonary circulation
# 221410        373434004                     Disorder blood vessels thorax
# 221411         27550009                                 Vascular disorder
# 221412         19660004                              Disorder soft tissue
# 221413         49601007                            Cardiovascular disease
# 221414         49483002                              Disorder mediastinum
# 221415        702612001                           Congenital aplasia lung
# 221416         47147007                           Congenital anomaly lung
# 221417        123654008       Congenital anomaly lower respiratory system
# 221418        275260000             Congenital anomaly respiratory system
# 221419         19829001                                 Pulmonary disease
# 221420        128272009                 Disorder lower respiratory system
# 221421         50043002                               Respiratory disease
# 221422        362965005                              Disorder body system
# 221423        363035006                         Congenital anomaly thorax
# 221424        363037003                    Congenital anomaly upper trunk
# 221425         78626001                          Congenital anomaly trunk
# 221426        276654001                                Congenital anomaly
# 221427         66091009                                Congenital disease
# 221428          5294002                            Developmental disorder
# 221429        118946009                                   Disorder thorax
# 221430        609622007                           Disorder thoracic trunk
# 221431        128121009                                    Disorder trunk
#
# [221432 rows x 2 columns]

# %%
data_frame = pd.DataFrame(read_csv)
data_frame.head()
# Out:
#               code                                            display
# 0  303921000119109  Chronic tophaceous gout of hand due to renal i...
# 1        450309001  Major systemic to pulmonary collateral artery ...
# 2        428799009         Rotatory subluxation of atlantoaxial joint
# 3         93936002        Primary malignant neoplasm of palatine bone
# 4        164510000                         O/E - elbow joint abnormal

# %%
feature = data_frame["display"]
feature.head()
# Out:
# 0    Chronic tophaceous gout of hand due to renal i...
# 1    Major systemic to pulmonary collateral artery ...
# 2           Rotatory subluxation of atlantoaxial joint
# 3          Primary malignant neoplasm of palatine bone
# 4                           O/E - elbow joint abnormal
# Name: display, dtype: object

# %%
X_train = data_frame["display"]
Y_train = data_frame["code"]

# %% [markdown]
# ## NLP Imports

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import nltk
from nltk.tokenize import word_tokenize
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# ## Word Tokenizing

# %%
tokenized_doc = []
doc = X_train.values.tolist()
for d in doc:
    d = str(d)
    tokenized_doc.append(word_tokenize(d.lower()))
print(tokenized_doc[:10])
# Out:
# [['chronic', 'tophaceous', 'gout', 'of', 'hand', 'due', 'to', 'renal', 'impairment'], ['major', 'systemic', 'to', 'pulmonary', 'collateral', 'artery', 'supplying', 'part', 'of', 'right', 'lung'], ['rotatory', 'subluxation', 'of', 'atlantoaxial', 'joint'], ['primary', 'malignant', 'neoplasm', 'of', 'palatine', 'bone'], ['o/e', '-', 'elbow', 'joint', 'abnormal'], ['obstetric', 'nipple', 'infection', 'with', 'postnatal', 'complication'], ['anterior', 'chamber', 'pseudo-exfoliation', 'deposits'], ['normal', 'sense', 'of', 'identity'], ['does', 'initiate', 'conversation'], ['dyrk1a-related', 'intellectual', 'disability', 'syndrome', 'due', 'to', '21q22.13q22.2', 'microdeletion']]

# %% [markdown]
# ## Converting to Tagged Documents

# %%
features = Y_train.values.tolist()
tagged_data = []
for value in range(len(doc)):
    feature = features[value]
    tokenized_sent = tokenized_doc[value]
    aj = TaggedDocument(tokenized_sent, [str(feature)])
    tagged_data.append(aj)
print(tagged_data[:100])
tagged_data_mini = tagged_data[3:5]
print(len(tagged_data_mini))
# Out:
# [TaggedDocument(words=['chronic', 'tophaceous', 'gout', 'of', 'hand', 'due', 'to', 'renal', 'impairment'], tags=['303921000119109']), TaggedDocument(words=['major', 'systemic', 'to', 'pulmonary', 'collateral', 'artery', 'supplying', 'part', 'of', 'right', 'lung'], tags=['450309001']), TaggedDocument(words=['rotatory', 'subluxation', 'of', 'atlantoaxial', 'joint'], tags=['428799009']), TaggedDocument(words=['primary', 'malignant', 'neoplasm', 'of', 'palatine', 'bone'], tags=['93936002']), TaggedDocument(words=['o/e', '-', 'elbow', 'joint', 'abnormal'], tags=['164510000']), TaggedDocument(words=['obstetric', 'nipple', 'infection', 'with', 'postnatal', 'complication'], tags=['200370007']), TaggedDocument(words=['anterior', 'chamber', 'pseudo-exfoliation', 'deposits'], tags=['247002006']), TaggedDocument(words=['normal', 'sense', 'of', 'identity'], tags=['280948003']), TaggedDocument(words=['does', 'initiate', 'conversation'], tags=['288642003']), TaggedDocument(words=['dyrk1a-related', 'intellectual', 'disability', 'syndrome', 'due', 'to', '21q22.13q22.2', 'microdeletion'], tags=['783619003']), TaggedDocument(words=['abnormal', 'plantar', 'creases'], tags=['95469008']), TaggedDocument(words=['acute', 'necrotising', 'ulcerative', 'gingivostomatitis'], tags=['173599005']), TaggedDocument(words=['term', 'birth', 'of', 'identical', 'twins', ',', 'both', 'stillborn'], tags=['75697004']), TaggedDocument(words=['menopause', 'ovarian', 'failure'], tags=['237138004']), TaggedDocument(words=['chronic', 'disease', '-', 'poor', 'control'], tags=['170561004']), TaggedDocument(words=['cortisone', 'allergy'], tags=['294695007']), TaggedDocument(words=['able', 'to', 'roll', 'on', 'to', 'side'], tags=['282626003']), TaggedDocument(words=['displacement', 'of', 'thoracic', 'intervertebral', 'disc', 'without', 'myelopathy'], tags=['64787009']), TaggedDocument(words=['transportation', 'barrier', 'impedes', 'ability', 'to', 'use', 'community', 'resources'], tags=['424629004']), TaggedDocument(words=['chronic', 'infantile', 'neurological', ',', 'cutaneous', 'and', 'articular', 'syndrome'], tags=['239826001']), TaggedDocument(words=['pulmonary', 'valve', 'prolapse'], tags=['253595004']), TaggedDocument(words=['posterior', 'ankle', 'impingement'], tags=['240022008']), TaggedDocument(words=['acute', 'deep', 'venous', 'thrombosis', 'of', 'internal', 'jugular', 'vein'], tags=['135001000119100']), TaggedDocument(words=['decreased', 'hormonal', 'resistance'], tags=['6224002']), TaggedDocument(words=['fracture', 'of', 'supraorbital', 'rim'], tags=['263170006']), TaggedDocument(words=['diogenes', 'syndrome'], tags=['277850002']), TaggedDocument(words=['o/e', '-', 'sign', '-', 'ankle/foot'], tags=['164641005']), TaggedDocument(words=['spontaneous', 'closure', 'of', 'ventricular', 'component', 'of', 'atrioventricular', 'septal', 'defect'], tags=['447777009']), TaggedDocument(words=['spinocerebellar', 'ataxia', 'type', '32'], tags=['719254001']), TaggedDocument(words=['vulval', 'irritation'], tags=['161818003']), TaggedDocument(words=['medial', 'epicondylitis'], tags=['53286005']), TaggedDocument(words=['injury', 'in', 'water', 'transport', 'caused', 'by', 'galley', 'machinery', ',', 'swimmer', 'injured'], tags=['215713006']), TaggedDocument(words=['intentional', 'cyclosporin', 'poisoning'], tags=['290776004']), TaggedDocument(words=['hypoplastic', 'lymph', 'node'], tags=['234089008']), TaggedDocument(words=['cervical', 'spine', 'crepitus', 'audible'], tags=['298481006']), TaggedDocument(words=['congenital', 'talipes', 'calcaneovalgus'], tags=['205083002']), TaggedDocument(words=['complex', 'burn', 'of', 'hip'], tags=['762488008']), TaggedDocument(words=['severely', 'compromised', 'location', 'and', 'extent', 'of', 'edentulous', 'area'], tags=['709849005']), TaggedDocument(words=['sodium', 'fluoride', 'adverse', 'reaction'], tags=['293415007']), TaggedDocument(words=['carbuncle', 'of', 'tunica', 'vaginalis'], tags=['28004004']), TaggedDocument(words=['autoimmune', ...
# 2

# %% [markdown]
# ## Building The Model

# %%
max_epochs = 30
vec_size = 20
alpha = 0.025

model = Doc2Vec(vec_size=vec_size,
                alpha=alpha, 
                min_alpha=0.00025,
                min_count=1,
                dm =1)
print("trainings started")
model.build_vocab(tagged_data)
print("build end")
for epoch in range(max_epochs):
    print('iteration {0}'.format(epoch))
    model.train(tagged_data,
                total_examples=model.corpus_count,
                epochs=model.iter)
    # decrease the learning rate
    model.alpha -= 0.0002
    # fix the learning rate, no decay
    model.min_alpha = model.alpha

model.save("test_doc2vec.model")
print("Model Saved")
# Out:
# trainings started
# build end
# iteration 0
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# Model Saved

# %% [markdown]
# ## Loading the Model

# %%
model= Doc2Vec.load("test_doc2vec.model")
## Print model vocabulary
model.wv.vocab
# Out:
# {'chronic': <gensim.models.keyedvectors.Vocab at 0x140a4c02908>,
#  'tophaceous': <gensim.models.keyedvectors.Vocab at 0x140be9baf60>,
#  'gout': <gensim.models.keyedvectors.Vocab at 0x140bd02f5f8>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x140bd02f6d8>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x140bd02f748>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x140bd02f5c0>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x140bd02f7b8>,
#  'renal': <gensim.models.keyedvectors.Vocab at 0x140bd02f7f0>,
#  'impairment': <gensim.models.keyedvectors.Vocab at 0x140bd02f828>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x140bd02f940>,
#  'systemic': <gensim.models.keyedvectors.Vocab at 0x140bd02f978>,
#  'pulmonary': <gensim.models.keyedvectors.Vocab at 0x140bd02f8d0>,
#  'collateral': <gensim.models.keyedvectors.Vocab at 0x140bd02f908>,
#  'artery': <gensim.models.keyedvectors.Vocab at 0x140bd02f9e8>,
#  'supplying': <gensim.models.keyedvectors.Vocab at 0x140bd02fa90>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x140bd02fa58>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x140bd02fb00>,
#  'lung': <gensim.models.keyedvectors.Vocab at 0x140bd02fb38>,
#  'rotatory': <gensim.models.keyedvectors.Vocab at 0x140bd02fba8>,
#  'subluxation': <gensim.models.keyedvectors.Vocab at 0x140acf3b4a8>,
#  'atlantoaxial': <gensim.models.keyedvectors.Vocab at 0x140acf3b518>,
#  'joint': <gensim.models.keyedvectors.Vocab at 0x140beaa0240>,
#  'primary': <gensim.models.keyedvectors.Vocab at 0x140beaa00f0>,
#  'malignant': <gensim.models.keyedvectors.Vocab at 0x140beaa0278>,
#  'neoplasm': <gensim.models.keyedvectors.Vocab at 0x140beaa0080>,
#  'palatine': <gensim.models.keyedvectors.Vocab at 0x140beaa02b0>,
#  'bone': <gensim.models.keyedvectors.Vocab at 0x140beaa04e0>,
#  'o/e': <gensim.models.keyedvectors.Vocab at 0x140beaa0518>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x140beaa0550>,
#  'elbow': <gensim.models.keyedvectors.Vocab at 0x140beaa05c0>,
#  'abnormal': <gensim.models.keyedvectors.Vocab at 0x140beaa05f8>,
#  'obstetric': <gensim.models.keyedvectors.Vocab at 0x140beaa0630>,
#  'nipple': <gensim.models.keyedvectors.Vocab at 0x140beaa06a0>,
#  'infection': <gensim.models.keyedvectors.Vocab at 0x140beaa06d8>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x140beaa0748>,
#  'postnatal': <gensim.models.keyedvectors.Vocab at 0x140beaa0780>,
#  'complication': <gensim.models.keyedvectors.Vocab at 0x140beaa07b8>,
#  'anterior': <gensim.models.keyedvectors.Vocab at 0x140beaa07f0>,
#  'chamber': <gensim.models.keyedvectors.Vocab at 0x140beaa0860>,
#  'pseudo-exfoliation': <gensim.models.keyedvectors.Vocab at 0x140beaa0898>,
#  'deposits': <gensim.models.keyedvectors.Vocab at 0x140beaa08d0>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x140beaa0940>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x140beaa09b0>,
#  'identity': <gensim.models.keyedvectors.Vocab at 0x140beaa09e8>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x140beaa0a58>,
#  'initiate': <gensim.models.keyedvectors.Vocab at 0x140beaa0a90>,
#  'conversation': <gensim.models.keyedvectors.Vocab at 0x140beaa0ac8>,
#  'dyrk1a-related': <gensim.models.keyedvectors.Vocab at 0x140beaa0b00>,
#  'intellectual': <gensim.models.keyedvectors.Vocab at 0x140beaa0b38>,
#  'disability': <gensim.models.keyedvectors.Vocab at 0x140beaa0b70>,
#  'syndrome': <gensim.models.keyedvectors.Vocab at 0x140beaa0ba8>,
#  '21q22.13q22.2': <gensim.models.keyedvectors.Vocab at 0x140beaa0be0>,
#  'microdeletion': <gensim.models.keyedvectors.Vocab at 0x140beaa0c18>,
#  'plantar': <gensim.models.keyedvectors.Vocab at 0x140beaa0c88>,
#  'creases': <gensim.models.keyedvectors.Vocab at 0x140beaa0cf8>,
#  'acute': <gensim.models.keyedvectors.Vocab at 0x140beaa0d68>,
#  'necrotising': <gensim.models.keyedvectors.Vocab at 0x140beaa0da0>,
#  'ulcerative': <gensim.models.keyedvectors.Vocab at 0x140beaa0dd8>,
#  'gingivostomatitis': <gensim.models.keyedvectors.Vocab at 0x140beaa0e10>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x140beaa0e80>,
#  'birth': <gensim.models.keyedvectors.Vocab at 0x140beaa0ef0>,
#  'identical': <gensim.models.keyedvectors.Vocab at 0x140beaa0f28>,
#  'twins': <gensim.models.keyedvectors.Vocab at 0x140beaa0f98>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x140beaa0fd0>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x140beaad080>,
#  'stillborn': <gensim.models.keyedvectors.Vocab at 0x140beaad0b8>,
#  'menopause': <gensim.models.keyedvectors.Vocab at 0x140beaad0f0>,
#  'ovarian': <gensim.models.keyedvectors.Vocab at 0x140beaad160>,
#  'failure': <gensim.models.keyedvectors.Vocab at 0x140beaad1d0>,
#  'disease': <gensim.models.keyedvectors.Vocab at 0x140beaad240>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x140beaad2b0>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x140beaad320>,
#  'cortisone': <gensim.models.keyedvectors.Vocab at 0x140beaad358>,
#  'allergy': <gensim.models.keyedvectors.Vocab at 0x140beaad3c8>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x140beaad438>,
#  'roll': <gensim.models.keyedvectors.Vocab at 0x140beaad4a8>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x140beaad518>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x140beaad588>,
#  'displacement': <gensim.models.keyedvectors.Vocab at 0x140beaad5c0>,
#  'thoracic': <gensim.models.keyedvectors.Vocab at 0x140beaad5f8>,
#  'intervertebral': <gensim.models.keyedvectors.Vocab at 0x140beaad630>,
#  'disc': <gensim.models.keyedvectors.Vocab at 0x140beaad6a0>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x140beaad710>,
#  'myelopathy': <gensim.models.keyedvectors.Vocab at 0x140beaad748>,
#  'transportation': <gensim.models.keyedvectors.Vocab at 0x140beaad780>,
#  'barrier': <gensim.models.keyedvectors.Vocab at 0x140beaad7f0>,
#  'impedes': <gensim.models.keyedvectors.Vocab at 0x140beaad860>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x140beaad8d0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x140beaad940>,
#  'community': <gensim.models.keyedvectors.Vocab at 0x140beaad978>,
#  'resources': <gensim.models.keyedvectors.Vocab at 0x140beaad9b0>,
#  'infantile': <gensim.models.keyedvectors.Vocab at 0x140beaad9e8>,
#  'neurological': <gensim.models.keyedvectors.Vocab at 0x140beaada20>,
#  'cutaneous': <gensim.models.keyedvectors.Vocab at 0x140beaada58>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x140beaadac8>,
#  'articular': <gensim.models.keyedvectors.Vocab at 0x140beaadb00>,
#  'valve': <gensim.models.keyedvectors.Vocab at 0x140beaadb70>,
#  'prolapse': <gensim.models.keyedvectors.Vocab at 0x140beaadba8>,
#  'posterior': <gensim.models.keyedvectors.Vocab at 0x140beaadbe0>,
#  'ankle': <gensim.models.keyedvectors.Vocab at 0x140beaadc50>,
#  'impingement': <gensim.models.keyedvectors.Vocab at 0x140beaadc88>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x140beaadcf8>,
#  'venous': <gensim.models.keyedvectors.Vocab at 0x140beaadd68>,
#  'thrombosis': <gensim.models.keyedvectors.Vocab at 0x140beaadda0>,
#  'internal': <gensim.models.keyedvectors.Vocab at 0x140beaaddd8>,
#  'jugular': <gensim.models.keyedvectors.Vocab at 0x140beaade48>,
#  'vein': <gensim.models.keyedvectors.Vocab at 0x140beaadeb8>,
#  'decreased': <gensim.models.keyedvectors.Vocab at 0x140beaadef0>,
#  'hormonal': <gensim.models.keyedvectors.Vocab at 0x140beaadf28>,
#  'resistance': <gensim.models.keyedvectors.Vocab at 0x140beaadf60>,
#  'fracture': <gensim.models.keyedvectors.Vocab at 0x140beaadf98>,
#  'supraorbital': <gensim.models.keyedvectors.Vocab at 0x140beaadfd0>,
#  'rim': <gensim.models.keyedvectors.Vocab at 0x140c52af080>,
#  'diogenes': <gensim.models.keyedvectors.Vocab at 0x140c52af0b8>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x140c52af128>,
#  'ankle/foot': <gensim.models.keyedvectors.Vocab at 0x140c52af160>,
#  'spontaneous': <gensim.models.keyedvectors.Vocab at 0x140c52af198>,
#  'closure': <gensim.models.keyedvectors.Vocab at 0x140c52af208>,
#  'ventricular': <gensim.models.keyedvectors.Vocab at 0x140c52af240>,
#  'component': <gensim.models.keyedvectors.Vocab at 0x140c52af278>,
#  'atrioventricular': <gensim.models.keyedvectors.Vocab at 0x140c52af2b0>,
#  'septal': <gensim.models.keyedvectors.Vocab at 0x140c52af320>,
#  'defect': <gensim.models.keyedvectors.Vocab at 0x140c52af390>,
#  'spinocerebellar': <gensim.models.keyedvectors.Vocab at 0x140c52af3c8>,
#  'ataxia': <gensim.models.keyedvectors.Vocab at 0x140c52af438>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x140c52af4a8>,
#  '32': <gensim.models.keyedvectors.Vocab at 0x140c52af518>,
#  'vulval': <gensim.models.keyedvectors.Vocab at 0x140c52af588>,
#  'irritation': <gensim.models.keyedvectors.Vocab at 0x140c52af5c0>,
#  'medial': <gensim.models.keyedvectors.Vocab at 0x140c52af630>,
#  'epicondylitis': <gensim.models.keyedvectors.Vocab at 0x140c52af668>,
#  'injury': <gensim.models.keyedvectors.Vocab at 0x140c52af6d8>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x140c52af748>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x140c52af7b8>,
#  'transport': <gensim.models.keyedvectors.Vocab at 0x140c52af7f0>,
#  'caused': <gensim.models.keyedvectors.Vocab at 0x140c52af860>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x140c52af8d0>,
#  'galley': <gensim.models.keyedvectors.Vocab at 0x140c52af940>,
#  'machinery': <gensim.models.keyedvectors.Vocab at 0x140c52af978>,
#  'swimmer': <gensim.models.keyedvectors.Vocab at 0x140c52af9e8>,
#  'injured': <gensim.models.keyedvectors.Vocab at 0x140c52afa58>,
#  'intentional': <gensim.models.keyedvectors.Vocab at 0x140c52afa90>,
#  'cyclosporin': <gensim.models.keyedvectors.Vocab at 0x140c52afac8>,
#  'poisoning': <gensim.models.keyedvectors.Vocab at 0x140c52afb00>,
#  'hypoplastic': <gensim.models.keyedvectors.Vocab at 0x140c52afb38>,
#  'lymph': <gensim.models.keyedvectors.Vocab at 0x140c52afba8>,
#  'node': <gensim.models.keyedvectors.Vocab at 0x140c52afc18>,
#  'cervical': <gensim.models.keyedvectors.Vocab at 0x140c52afc50>,
#  'spine': <gensim.models.keyedvectors.Vocab at 0x140c52afcc0>,
#  'crepitus': <gensim.models.keyedvectors.Vocab at 0x140c52afcf8>,
#  'audible': <gensim.models.keyedvectors.Vocab at 0x140c52afd68>,
#  'congenital': <gensim.models.keyedvectors.Vocab at 0x140c52afda0>,
#  'talipes': <gensim.models.keyedvectors.Vocab at 0x140c52afe10>,
#  'calcaneovalgus': <gensim.models.keyedvectors.Vocab at 0x140c52afe48>,
#  'complex': <gensim.models.keyedvectors.Vocab at 0x140c52afeb8>,
#  'burn': <gensim.models.keyedvectors.Vocab at 0x140c52aff28>,
#  'hip': <gensim.models.keyedvectors.Vocab at 0x140c52aff98>,
#  'severely': <gensim.models.keyedvectors.Vocab at 0x140c52affd0>,
#  'compromised': <gensim.models.keyedvectors.Vocab at 0x140c52b1048>,
#  'location': <gensim.models.keyedvectors.Vocab at 0x140c52b1080>,
#  'extent': <gensim.models.keyedvectors.Vocab at 0x140c52b10f0>,
#  'edentulous': <gensim.models.keyedvectors.Vocab at 0x140c52b1128>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x140c52b1198>,
#  'sodium': <gensim.models.keyedvectors.Vocab at 0x140c52b1208>,
#  'fluoride': <gensim.models.keyedvectors.Vocab at 0x140c52b1240>,
#  'adverse': <gensim.models.keyedvectors.Vocab at 0x140c52b12b0>,
#  'reaction': <gensim.models.keyedvectors.Vocab at 0x140c52b12e8>,
#  'carbuncle': <gensim.models.keyedvectors.Vocab at 0x140c52b1320>,
#  'tunica': <gensim.models.keyedvectors.Vocab at 0x140c52b1390>,
#  'vaginalis': <gensim.models.keyedvectors.Vocab at 0x140c52b13c8>,
#  'autoimmune': <gensim.models.keyedvectors.Vocab at 0x140c52b1400>,
#  'polyendocrine': <gensim.models.keyedvectors.Vocab at 0x140c52b1438>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x140c52b1470>,
#  'genetic': <gensim.models.keyedvectors.Vocab at 0x140c52b14e0>,
#  'linkage': <gensim.models.keyedvectors.Vocab at 0x140c52b1550>,
#  'disequilibrium': <gensim.models.keyedvectors.Vocab at 0x140c52b1588>,
#  'contusion': <gensim.models.keyedvectors.Vocab at 0x140c52b15c0>,
#  'caecum': <gensim.models.keyedvectors.Vocab at 0x140c52b1630>,
#  'placenta': <gensim.models.keyedvectors.Vocab at 0x140c52b1668>,
#  'mycobacterium': <gensim.models.keyedvectors.Vocab at 0x140c52b16a0>,
#  'tuberculosis': <gensim.models.keyedvectors.Vocab at 0x140c52b16d8>,
#  'adult-onset': <gensim.models.keyedvectors.Vocab at 0x140c52b1710>,
#  'progressive': <gensim.models.keyedvectors.Vocab at 0x140c52b1748>,
#  'external': <gensim.models.keyedvectors.Vocab at 0x140c52b1780>,
#  'ophthalmoplegia': <gensim.models.keyedvectors.Vocab at 0x140c52b17b8>,
#  'mitochondrial': <gensim.models.keyedvectors.Vocab at 0x140c52b17f0>,
#  'myopathy': <gensim.models.keyedvectors.Vocab at 0x140c52b1828>,
#  'inequality': <gensim.models.keyedvectors.Vocab at 0x140c52b1860>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x140c52b18d0>,
#  'kidneys': <gensim.models.keyedvectors.Vocab at 0x140c52b1940>,
#  'haemoglobin': <gensim.models.keyedvectors.Vocab at 0x140c52b1978>,
#  'sc': <gensim.models.keyedvectors.Vocab at 0x140c52b19e8>,
#  'crystals': <gensim.models.keyedvectors.Vocab at 0x140c52b1a20>,
#  'cortical': <gensim.models.keyedvectors.Vocab at 0x140c52b1a58>,
#  'dysgenesis': <gensim.models.keyedvectors.Vocab at 0x140c52b1a90>,
#  'pontocerebellar': <gensim.models.keyedvectors.Vocab at 0x140c52b1ac8>,
#  'hypoplasia': <gensim.models.keyedvectors.Vocab at 0x140c52b1b00>,
#  'tubb3': <gensim.models.keyedvectors.Vocab at 0x140c52b1b70>,
#  'mutation': <gensim.models.keyedvectors.Vocab at 0x140c52b1ba8>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x140c52b1c18>,
#  'myoclonus': <gensim.models.keyedvectors.Vocab at 0x140c52b1c50>,
#  'pigmented': <gensim.models.keyedvectors.Vocab at 0x140c52b1c88>,
#  'melanocytic': <gensim.models.keyedvectors.Vocab at 0x140c52b1cc0>,
#  'naevus': <gensim.models.keyedvectors.Vocab at 0x140c52b1d30>,
#  'skin': <gensim.models.keyedvectors.Vocab at 0x140c52b1da0>,
#  'lower': <gensim.models.keyedvectors.Vocab at 0x140c52b1e10>,
#  'limb': <gensim.models.keyedvectors.Vocab at 0x140c52b1e80>,
#  'partial': <gensim.models.keyedvectors.Vocab at 0x140c52b1ef0>,
#  'thickness': <gensim.models.keyedvectors.Vocab at 0x140c52b1f28>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x140c52b1f98>,
#  'lip': <gensim.models.keyedvectors.Vocab at 0x140c52b7048>,
#  'dysexecutive': <gensim.models.keyedvectors.Vocab at 0x140c52b7080>,
#  'facial': <gensim.models.keyedvectors.Vocab at 0x140c52b70f0>,
#  'milia': <gensim.models.keyedvectors.Vocab at 0x140c52b7160>,
#  'lobate': <gensim.models.keyedvectors.Vocab at 0x140c52b71d0>,
#  'tongue': <gensim.models.keyedvectors.Vocab at 0x140c52b7240>,
#  'lingual': <gensim.models.keyedvectors.Vocab at 0x140c52b72b0>,
#  'labial': <gensim.models.keyedvectors.Vocab at 0x140c52b7320>,
#  'frenula': <gensim.models.keyedvectors.Vocab at 0x140c52b7390>,
#  'hiccups': <gensim.models.keyedvectors.Vocab at 0x140c52b7400>,
#  'subneopulmonary': <gensim.models.keyedvectors.Vocab at 0x140c52b7438>,
#  'stenosis': <gensim.models.keyedvectors.Vocab at 0x140c52b7470>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x140c52b74e0>,
#  'attorney': <gensim.models.keyedvectors.Vocab at 0x140c52b7518>,
#  'held': <gensim.models.keyedvectors.Vocab at 0x140c52b7588>,
#  'follicular': <gensim.models.keyedvectors.Vocab at 0x140c52b75c0>,
#  'conjunctivitis': <gensim.models.keyedvectors.Vocab at 0x140c52b75f8>,
#  'drug': <gensim.models.keyedvectors.Vocab at 0x140c52b7668>,
#  'gait': <gensim.models.keyedvectors.Vocab at 0x140c52b76d8>,
#  'exhaustion': <gensim.models.keyedvectors.Vocab at 0x140c52b7710>,
#  'exposure': <gensim.models.keyedvectors.Vocab at 0x140c52b7748>,
#  'difficulty': <gensim.models.keyedvectors.Vocab at 0x140c52b7780>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x140c52b77f0>,
#  'illegal': <gensim.models.keyedvectors.Vocab at 0x140c52b7860>,
#  'termination': <gensim.models.keyedvectors.Vocab at 0x140c52b7898>,
#  'pregnancy': <gensim.models.keyedvectors.Vocab at 0x140c52b78d0>,
#  'perforation': <gensim.models.keyedvectors.Vocab at 0x140c52b7908>,
#  'broad': <gensim.models.keyedvectors.Vocab at 0x140c52b7978>,
#  'ligament': <gensim.models.keyedvectors.Vocab at 0x140c52b79b0>,
#  'unable': <gensim.models.keyedvectors.Vocab at 0x140c52b7a20>,
#  'grip': <gensim.models.keyedvectors.Vocab at 0x140c52b7a90>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x140c52b7b00>,
#  'opposition': <gensim.models.keyedvectors.Vocab at 0x140c52b7b38>,
#  'thumb': <gensim.models.keyedvectors.Vocab at 0x140c52b7ba8>,
#  'lobulated': <gensim.models.keyedvectors.Vocab at 0x140c52b7be0>,
#  'accidental': <gensim.models.keyedvectors.Vocab at 0x140c52b7c18>,
#  'alfentanil': <gensim.models.keyedvectors.Vocab at 0x140c52b7c50>,
#  'pityriasiform': <gensim.models.keyedvectors.Vocab at 0x140c52b7c88>,
#  'seborrhoeic': <gensim.models.keyedvectors.Vocab at 0x140c52b7cc0>,
#  'dermatitis': <gensim.models.keyedvectors.Vocab at 0x140c52b7cf8>,
#  'cellulitis': <gensim.models.keyedvectors.Vocab at 0x140c52b7d30>,
#  'scalp': <gensim.models.keyedvectors.Vocab at 0x140c52b7da0>,
#  'drug-related': <gensim.models.keyedvectors.Vocab at 0x140c52b7dd8>,
#  'myocardial': <gensim.models.keyedvectors.Vocab at 0x140c52b7e10>,
#  'necrosis': <gensim.models.keyedvectors.Vocab at 0x140c52b7e48>,
#  'extension': <gensim.models.keyedvectors.Vocab at 0x140c52b7e80>,
#  'stroke': <gensim.models.keyedvectors.Vocab at 0x140c52b7ef0>,
#  'granulomatous': <gensim.models.keyedvectors.Vocab at 0x140c52b7f28>,
#  'iii': <gensim.models.keyedvectors.Vocab at 0x140c52b7f98>,
#  'manic': <gensim.models.keyedvectors.Vocab at 0x140c52bd048>,
#  'mental': <gensim.models.keyedvectors.Vocab at 0x140c52bd0b8>,
#  'defence': <gensim.models.keyedvectors.Vocab at 0x140c52bd128>,
#  'mechanism': <gensim.models.keyedvectors.Vocab at 0x140c52bd160>,
#  'cord': <gensim.models.keyedvectors.Vocab at 0x140c52bd1d0>,
#  'spinal': <gensim.models.keyedvectors.Vocab at 0x140c52bd240>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x140c52bd2b0>,
#  'c8': <gensim.models.keyedvectors.Vocab at 0x140c52bd320>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x140c52bd390>,
#  'modified': <gensim.models.keyedvectors.Vocab at 0x140c52bd3c8>,
#  'dukes': <gensim.models.keyedvectors.Vocab at 0x140c52bd438>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x140c52bd4a8>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x140c52bd4e0>,
#  'phlegmonous': <gensim.models.keyedvectors.Vocab at 0x140c52bd518>,
#  'stomatitis': <gensim.models.keyedvectors.Vocab at 0x140c52bd550>,
#  'methane/propane': <gensim.models.keyedvectors.Vocab at 0x140c52bd588>,
#  'synthetic': <gensim.models.keyedvectors.Vocab at 0x140c52bd5c0>,
#  'cannabinoid': <gensim.models.keyedvectors.Vocab at 0x140c52bd5f8>,
#  'withdrawal': <gensim.models.keyedvectors.Vocab at 0x140c52bd630>,
#  'tumour': <gensim.models.keyedvectors.Vocab at 0x140c52bd6a0>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x140c52bd6d8>,
#  'uterine': <gensim.models.keyedvectors.Vocab at 0x140c52bd748>,
#  'corpus': <gensim.models.keyedvectors.Vocab at 0x140c52bd7b8>,
#  'separate': <gensim.models.keyedvectors.Vocab at 0x140c52bd7f0>,
#  'metastasis': <gensim.models.keyedvectors.Vocab at 0x140c52bd828>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x140c52bd898>,
#  'cervix': <gensim.models.keyedvectors.Vocab at 0x140c52bd908>,
#  'sepsis-related': <gensim.models.keyedvectors.Vocab at 0x140c52bd940>,
#  'gastrointestinal': <gensim.models.keyedvectors.Vocab at 0x140c52bd978>,
#  'ulceration': <gensim.models.keyedvectors.Vocab at 0x140c52bd9b0>,
#  'tends': <gensim.models.keyedvectors.Vocab at 0x140c52bda20>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x140c52bda90>,
#  'excessively': <gensim.models.keyedvectors.Vocab at 0x140c52bdac8>,
#  'self-sufficient': <gensim.models.keyedvectors.Vocab at 0x140c52bdb00>,
#  'blunted': <gensim.models.keyedvectors.Vocab at 0x140c52bdb70>,
#  'hypoxic': <gensim.models.keyedvectors.Vocab at 0x140c52bdbe0>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x140c52bdc50>,
#  'juvenile': <gensim.models.keyedvectors.Vocab at 0x140c52bdc88>,
#  'aponeurotic': <gensim.models.keyedvectors.Vocab at 0x140c52bdcc0>,
#  'fibroma': <gensim.models.keyedvectors.Vocab at 0x140c52bdd30>,
#  'medullary': <gensim.models.keyedvectors.Vocab at 0x140c52bdd68>,
#  'sponge': <gensim.models.keyedvectors.Vocab at 0x140c52bddd8>,
#  'kidney': <gensim.models.keyedvectors.Vocab at 0x140c52bde48>,
#  'nephrocalcinosis': <gensim.models.keyedvectors.Vocab at 0x140c52bde80>,
#  'divergence': <gensim.models.keyedvectors.Vocab at 0x140c52bdeb8>,
#  'retraction': <gensim.models.keyedvectors.Vocab at 0x140c52bdef0>,
#  'nystagmus': <gensim.models.keyedvectors.Vocab at 0x140c52bdf28>,
#  'isthmic': <gensim.models.keyedvectors.Vocab at 0x140c52bdf98>,
#  'spondylolisthesis': <gensim.models.keyedvectors.Vocab at 0x140c52bdfd0>,
#  'stopped': <gensim.models.keyedvectors.Vocab at 0x140c529d080>,
#  'drinking': <gensim.models.keyedvectors.Vocab at 0x140c529d0b8>,
#  'alcohol': <gensim.models.keyedvectors.Vocab at 0x140c529d128>,
#  'klumpke-dã©jerine': <gensim.models.keyedvectors.Vocab at 0x140c529d160>,
#  'paralysis': <gensim.models.keyedvectors.Vocab at 0x140c529d198>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x140c529d208>,
#  'trauma': <gensim.models.keyedvectors.Vocab at 0x140c529d278>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x140c529d2e8>,
#  'traumatic': <gensim.models.keyedvectors.Vocab at 0x140c529d320>,
#  'costochondral': <gensim.models.keyedvectors.Vocab at 0x140c529d358>,
#  'asymptomatic': <gensim.models.keyedvectors.Vocab at 0x140c529d390>,
#  'west': <gensim.models.keyedvectors.Vocab at 0x140c529d400>,
#  'nile': <gensim.models.keyedvectors.Vocab at 0x140c529d470>,
#  'virus': <gensim.models.keyedvectors.Vocab at 0x140c529d4e0>,
#  'mild': <gensim.models.keyedvectors.Vocab at 0x140c529d550>,
#  'hypokinesis': <gensim.models.keyedvectors.Vocab at 0x140c529d588>,
#  'cardiac': <gensim.models.keyedvectors.Vocab at 0x140c529d5f8>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x140c529d668>,
#  'thigh': <gensim.models.keyedvectors.Vocab at 0x140c529d6d8>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x140c529d748>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x140c529d780>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x140c529d7f0>,
#  'exam': <gensim.models.keyedvectors.Vocab at 0x140c529d860>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x140c529d8d0>,
#  'observation': <gensim.models.keyedvectors.Vocab at 0x140c529d908>,
#  'stab': <gensim.models.keyedvectors.Vocab at 0x140c529d978>,
#  'wound': <gensim.models.keyedvectors.Vocab at 0x140c529d9e8>,
#  'varicocele': <gensim.models.keyedvectors.Vocab at 0x140c529da20>,
#  'palpable': <gensim.models.keyedvectors.Vocab at 0x140c529da58>,
#  'valsalva': <gensim.models.keyedvectors.Vocab at 0x140c529da90>,
#  'manoeuvre': <gensim.models.keyedvectors.Vocab at 0x140c529dac8>,
#  'plain': <gensim.models.keyedvectors.Vocab at 0x140c529db38>,
#  'x-ray': <gensim.models.keyedvectors.Vocab at 0x140c529dba8>,
#  'toes': <gensim.models.keyedvectors.Vocab at 0x140c529dc18>,
#  'forearm': <gensim.models.keyedvectors.Vocab at 0x140c529dc88>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x140c529dcf8>,
#  'foot': <gensim.models.keyedvectors.Vocab at 0x140c529dd68>,
#  'involuntary': <gensim.models.keyedvectors.Vocab at 0x140c529dda0>,
#  'movement': <gensim.models.keyedvectors.Vocab at 0x140c529ddd8>,
#  'kinaesthetic': <gensim.models.keyedvectors.Vocab at 0x140c529de10>,
#  'alteration': <gensim.models.keyedvectors.Vocab at 0x140c529de48>,
#  'retained': <gensim.models.keyedvectors.Vocab at 0x140c529de80>,
#  'nuclear': <gensim.models.keyedvectors.Vocab at 0x140c529def0>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x140c529df28>,
#  'vitreous': <gensim.models.keyedvectors.Vocab at 0x140c529df60>,
#  'post-mastectomy': <gensim.models.keyedvectors.Vocab at 0x140c529df98>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x140c528b048>,
#  'cholecystitis': <gensim.models.keyedvectors.Vocab at 0x140c528b080>,
#  'calculus': <gensim.models.keyedvectors.Vocab at 0x140c528b0b8>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x140c528b128>,
#  'corpuscular': <gensim.models.keyedvectors.Vocab at 0x140c528b160>,
#  'concentration': <gensim.models.keyedvectors.Vocab at 0x140c528b198>,
#  'borderline': <gensim.models.keyedvectors.Vocab at 0x140c528b1d0>,
#  'raised': <gensim.models.keyedvectors.Vocab at 0x140c528b240>,
#  'kussmaul': <gensim.models.keyedvectors.Vocab at 0x140c528b278>,
#  "'s": <gensim.models.keyedvectors.Vocab at 0x140c528b2e8>,
#  'respiration': <gensim.models.keyedvectors.Vocab at 0x140c528b320>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x140c528b358>,
#  'sites': <gensim.models.keyedvectors.Vocab at 0x140c528b3c8>,
#  'arm': <gensim.models.keyedvectors.Vocab at 0x140c528b438>,
#  'uvular': <gensim.models.keyedvectors.Vocab at 0x140c528b4a8>,
#  'hypertrophy': <gensim.models.keyedvectors.Vocab at 0x140c528b4e0>,
#  'wood': <gensim.models.keyedvectors.Vocab at 0x140c528b550>,
#  'splinter': <gensim.models.keyedvectors.Vocab at 0x140c528b588>,
#  'confluent': <gensim.models.keyedvectors.Vocab at 0x140c528b5c0>,
#  'retinal': <gensim.models.keyedvectors.Vocab at 0x140c528b630>,
#  'haemorrhage': <gensim.models.keyedvectors.Vocab at 0x140c528b668>,
#  'rheumatology': <gensim.models.keyedvectors.Vocab at 0x140c528b6a0>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x140c528b710>,
#  'dementia': <gensim.models.keyedvectors.Vocab at 0x140c528b748>,
#  'multifocal': <gensim.models.keyedvectors.Vocab at 0x140c528b780>,
#  'leukoencephalopathy': <gensim.models.keyedvectors.Vocab at 0x140c528b7b8>,
#  'ignition': <gensim.models.keyedvectors.Vocab at 0x140c528b7f0>,
#  'clothing': <gensim.models.keyedvectors.Vocab at 0x140c528b828>,
#  'burning': <gensim.models.keyedvectors.Vocab at 0x140c528b898>,
#  'bedding': <gensim.models.keyedvectors.Vocab at 0x140c528b908>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x140c528b978>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x140c528b9e8>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x140c528ba58>,
#  'flexion': <gensim.models.keyedvectors.Vocab at 0x140c528bac8>,
#  'dens': <gensim.models.keyedvectors.Vocab at 0x140c528bb38>,
#  'evaginatus': <gensim.models.keyedvectors.Vocab at 0x140c528bb70>,
#  'female': <gensim.models.keyedvectors.Vocab at 0x140c528bbe0>,
#  'sterility': <gensim.models.keyedvectors.Vocab at 0x140c528bc18>,
#  'retrusion': <gensim.models.keyedvectors.Vocab at 0x140c528bc50>,
#  'superficial': <gensim.models.keyedvectors.Vocab at 0x140c528bc88>,
#  'foreign': <gensim.models.keyedvectors.Vocab at 0x140c528bcf8>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x140c528bd68>,
#  'leg': <gensim.models.keyedvectors.Vocab at 0x140c528bdd8>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x140c528be48>,
#  'abo': <gensim.models.keyedvectors.Vocab at 0x140c528beb8>,
#  'isoimmunisation': <gensim.models.keyedvectors.Vocab at 0x140c528bef0>,
#  'affecting': <gensim.models.keyedvectors.Vocab at 0x140c528bf28>,
#  'heteromanipulatory': <gensim.models.keyedvectors.Vocab at 0x140c528bf60>,
#  'vulvoclitoral': <gensim.models.keyedvectors.Vocab at 0x140c528bf98>,
#  'habituation': <gensim.models.keyedvectors.Vocab at 0x140c528bfd0>,
#  'overdose': <gensim.models.keyedvectors.Vocab at 0x140c5285048>,
#  'shallow': <gensim.models.keyedvectors.Vocab at 0x140c52850b8>,
#  'mentolabial': <gensim.models.keyedvectors.Vocab at 0x140c52850f0>,
#  'sulcus': <gensim.models.keyedvectors.Vocab at 0x140c5285160>,
#  'pt1a': <gensim.models.keyedvectors.Vocab at 0x140c52851d0>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x140c5285208>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x140c5285278>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x140c52852e8>,
#  'iris': <gensim.models.keyedvectors.Vocab at 0x140c5285358>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x140c5285390>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x140c5285400>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x140c5285470>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x140c52854e0>,
#  'clock': <gensim.models.keyedvectors.Vocab at 0x140c5285550>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x140c52855c0>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x140c52855f8>,
#  'uveal': <gensim.models.keyedvectors.Vocab at 0x140c5285668>,
#  'melanoma': <gensim.models.keyedvectors.Vocab at 0x140c52856a0>,
#  'hyperbilirubinaemia': <gensim.models.keyedvectors.Vocab at 0x140c52856d8>,
#  'conjugated': <gensim.models.keyedvectors.Vocab at 0x140c5285710>,
#  'bromobenzyl': <gensim.models.keyedvectors.Vocab at 0x140c5285748>,
#  'cyanide': <gensim.models.keyedvectors.Vocab at 0x140c52857b8>,
#  'sympathetic': <gensim.models.keyedvectors.Vocab at 0x140c52857f0>,
#  'nerves': <gensim.models.keyedvectors.Vocab at 0x140c5285860>,
#  'submandibular': <gensim.models.keyedvectors.Vocab at 0x140c5285898>,
#  'swelling': <gensim.models.keyedvectors.Vocab at 0x140c52858d0>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x140c5285940>,
#  'pulse': <gensim.models.keyedvectors.Vocab at 0x140c52859b0>,
#  'volume': <gensim.models.keyedvectors.Vocab at 0x140c5285a20>,
#  'extraintestinal': <gensim.models.keyedvectors.Vocab at 0x140c5285a58>,
#  'entamoeba': <gensim.models.keyedvectors.Vocab at 0x140c5285a90>,
#  'severe': <gensim.models.keyedvectors.Vocab at 0x140c5285b00>,
#  'acquired': <gensim.models.keyedvectors.Vocab at 0x140c5285b38>,
#  'hearing': <gensim.models.keyedvectors.Vocab at 0x140c5285ba8>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x140c5285c18>,
#  'curry': <gensim.models.keyedvectors.Vocab at 0x140c5285c88>,
#  'jones': <gensim.models.keyedvectors.Vocab at 0x140c5285cf8>,
#  'panophthalmitis': <gensim.models.keyedvectors.Vocab at 0x140c5285d30>,
#  'endometriosis': <gensim.models.keyedvectors.Vocab at 0x140c5285d68>,
#  'perfume': <gensim.models.keyedvectors.Vocab at 0x140c5285dd8>,
#  'contact': <gensim.models.keyedvectors.Vocab at 0x140c5285e48>,
#  'secondary': <gensim.models.keyedvectors.Vocab at 0x140c5285e80>,
#  'dentin': <gensim.models.keyedvectors.Vocab at 0x140c5285ef0>,
#  'failed': <gensim.models.keyedvectors.Vocab at 0x140c5285f60>,
#  'attempted': <gensim.models.keyedvectors.Vocab at 0x140c5285f98>,
#  'genital': <gensim.models.keyedvectors.Vocab at 0x140c528a048>,
#  'tract': <gensim.models.keyedvectors.Vocab at 0x140c528a0b8>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x140c528a128>,
#  'pelvic': <gensim.models.keyedvectors.Vocab at 0x140c528a198>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x140c528a208>,
#  'dome': <gensim.models.keyedvectors.Vocab at 0x140c528a278>,
#  'cyst': <gensim.models.keyedvectors.Vocab at 0x140c528a2e8>,
#  'pneumoparotid': <gensim.models.keyedvectors.Vocab at 0x140c528a320>,
#  'tracheal': <gensim.models.keyedvectors.Vocab at 0x140c528a358>,
#  'intubation': <gensim.models.keyedvectors.Vocab at 0x140c528a390>,
#  'morbidity': <gensim.models.keyedvectors.Vocab at 0x140c528a3c8>,
#  'urtica': <gensim.models.keyedvectors.Vocab at 0x140c528a438>,
#  'incisa': <gensim.models.keyedvectors.Vocab at 0x140c528a4a8>,
#  'n2': <gensim.models.keyedvectors.Vocab at 0x140c528a518>,
#  '7-15': <gensim.models.keyedvectors.Vocab at 0x140c528a588>,
#  'perigastric': <gensim.models.keyedvectors.Vocab at 0x140c528a5c0>,
#  'nodes': <gensim.models.keyedvectors.Vocab at 0x140c528a630>,
#  'pseudohypoaldosteronism': <gensim.models.keyedvectors.Vocab at 0x140c528a668>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x140c528a6a0>,
#  'recessive': <gensim.models.keyedvectors.Vocab at 0x140c528a6d8>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x140c528a748>,
#  'understanding': <gensim.models.keyedvectors.Vocab at 0x140c528a780>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x140c528a7f0>,
#  'instructions': <gensim.models.keyedvectors.Vocab at 0x140c528a828>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x140c528a860>,
#  'division': <gensim.models.keyedvectors.Vocab at 0x140c528a898>,
#  'extensor': <gensim.models.keyedvectors.Vocab at 0x140c528a8d0>,
#  'tendon': <gensim.models.keyedvectors.Vocab at 0x140c528a940>,
#  'dystonic': <gensim.models.keyedvectors.Vocab at 0x140c528a978>,
#  'tremor': <gensim.models.keyedvectors.Vocab at 0x140c528a9e8>,
#  'idiopathic': <gensim.models.keyedvectors.Vocab at 0x140c528aa20>,
#  'osteoporosis': <gensim.models.keyedvectors.Vocab at 0x140c528aa58>,
#  'acetazolamide': <gensim.models.keyedvectors.Vocab at 0x140c528aa90>,
#  'undetermined': <gensim.models.keyedvectors.Vocab at 0x140c528aac8>,
#  'intent': <gensim.models.keyedvectors.Vocab at 0x140c528ab38>,
#  'aspiration': <gensim.models.keyedvectors.Vocab at 0x140c528ab70>,
#  'adult': <gensim.models.keyedvectors.Vocab at 0x140c528abe0>,
#  'oculodento-osseous': <gensim.models.keyedvectors.Vocab at 0x140c528ac18>,
#  'dysplasia': <gensim.models.keyedvectors.Vocab at 0x140c528ac50>,
#  'straddling': <gensim.models.keyedvectors.Vocab at 0x140c528ac88>,
#  'blood': <gensim.models.keyedvectors.Vocab at 0x140c528acf8>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x140c528ad68>,
#  '>': <gensim.models.keyedvectors.Vocab at 0x140c528ada0>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x140c528add8>,
#  '<': <gensim.models.keyedvectors.Vocab at 0x140c528ae10>,
#  'fimbriated': <gensim.models.keyedvectors.Vocab at 0x140c528ae48>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x140c528aeb8>,
#  'fallopian': <gensim.models.keyedvectors.Vocab at 0x140c528aef0>,
#  'tube': <gensim.models.keyedvectors.Vocab at 0x140c528af60>,
#  'closed': <gensim.models.keyedvectors.Vocab at 0x140c528afd0>,
#  'flexural': <gensim.models.keyedvectors.Vocab at 0x140c5290048>,
#  'lichen': <gensim.models.keyedvectors.Vocab at 0x140c52900b8>,
#  'planus': <gensim.models.keyedvectors.Vocab at 0x140c5290128>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x140c5290198>,
#  'carcinoma': <gensim.models.keyedvectors.Vocab at 0x140c52901d0>,
#  'colon': <gensim.models.keyedvectors.Vocab at 0x140c5290240>,
#  'ii': <gensim.models.keyedvectors.Vocab at 0x140c52902b0>,
#  'stricture': <gensim.models.keyedvectors.Vocab at 0x140c52902e8>,
#  'ureteropelvic': <gensim.models.keyedvectors.Vocab at 0x140c5290320>,
#  'junction': <gensim.models.keyedvectors.Vocab at 0x140c5290358>,
#  'eccrine': <gensim.models.keyedvectors.Vocab at 0x140c52903c8>,
#  'azapropazone': <gensim.models.keyedvectors.Vocab at 0x140c5290400>,
#  'helicobacter': <gensim.models.keyedvectors.Vocab at 0x140c5290438>,
#  'serology': <gensim.models.keyedvectors.Vocab at 0x140c5290470>,
#  'negative': <gensim.models.keyedvectors.Vocab at 0x140c52904a8>,
#  'prosthetic': <gensim.models.keyedvectors.Vocab at 0x140c52904e0>,
#  'aortic': <gensim.models.keyedvectors.Vocab at 0x140c5290550>,
#  'requiring': <gensim.models.keyedvectors.Vocab at 0x140c5290588>,
#  'replacement': <gensim.models.keyedvectors.Vocab at 0x140c52905c0>,
#  'nutrition': <gensim.models.keyedvectors.Vocab at 0x140c52905f8>,
#  'impaired': <gensim.models.keyedvectors.Vocab at 0x140c5290630>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x140c52906a0>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x140c5290710>,
#  'supplies': <gensim.models.keyedvectors.Vocab at 0x140c5290748>,
#  'cartilage': <gensim.models.keyedvectors.Vocab at 0x140c5290780>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x140c52907f0>,
#  'pitt': <gensim.models.keyedvectors.Vocab at 0x140c5290860>,
#  'hopkins-like': <gensim.models.keyedvectors.Vocab at 0x140c5290898>,
#  'inadequate': <gensim.models.keyedvectors.Vocab at 0x140c52908d0>,
#  'healthcare': <gensim.models.keyedvectors.Vocab at 0x140c5290908>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x140c5290978>,
#  'compliance': <gensim.models.keyedvectors.Vocab at 0x140c52909b0>,
#  'bladder': <gensim.models.keyedvectors.Vocab at 0x140c5290a20>,
#  't3': <gensim.models.keyedvectors.Vocab at 0x140c5290a90>,
#  'aerodigestive': <gensim.models.keyedvectors.Vocab at 0x140c5290ac8>,
#  'larynx': <gensim.models.keyedvectors.Vocab at 0x140c5290b38>,
#  'vocal': <gensim.models.keyedvectors.Vocab at 0x140c5290ba8>,
#  'fixation': <gensim.models.keyedvectors.Vocab at 0x140c5290be0>,
#  'catarrhal': <gensim.models.keyedvectors.Vocab at 0x140c5290c18>,
#  'bronchitis': <gensim.models.keyedvectors.Vocab at 0x140c5290c50>,
#  'aseptic': <gensim.models.keyedvectors.Vocab at 0x140c5290cc0>,
#  'femoral': <gensim.models.keyedvectors.Vocab at 0x140c5290d30>,
#  'condyle': <gensim.models.keyedvectors.Vocab at 0x140c5290da0>,
#  'brudzinski': <gensim.models.keyedvectors.Vocab at 0x140c5290dd8>,
#  'oesophagostomum': <gensim.models.keyedvectors.Vocab at 0x140c5290e10>,
#  'dentatum': <gensim.models.keyedvectors.Vocab at 0x140c5290e48>,
#  'arrest': <gensim.models.keyedvectors.Vocab at 0x140c5290eb8>,
#  'electrocution': <gensim.models.keyedvectors.Vocab at 0x140c5290ef0>,
#  'anticholinesterase': <gensim.models.keyedvectors.Vocab at 0x140c5290f28>,
#  'propofol': <gensim.models.keyedvectors.Vocab at 0x140c5290f60>,
#  'deficiency': <gensim.models.keyedvectors.Vocab at 0x140c5290f98>,
#  'phospholipase': <gensim.models.keyedvectors.Vocab at 0x140c5290fd0>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x140c8532048>,
#  'depressive': <gensim.models.keyedvectors.Vocab at 0x140c8532080>,
#  'delusion': <gensim.models.keyedvectors.Vocab at 0x140c85320b8>,
#  'poverty': <gensim.models.keyedvectors.Vocab at 0x140c8532128>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x140c8532198>,
#  'daily': <gensim.models.keyedvectors.Vocab at 0x140c8532208>,
#  'persistent': <gensim.models.keyedvectors.Vocab at 0x140c8532240>,
#  'headache': <gensim.models.keyedvectors.Vocab at 0x140c8532278>,
#  'cystinuria': <gensim.models.keyedvectors.Vocab at 0x140c85322b0>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x140c8532320>,
#  'infectious': <gensim.models.keyedvectors.Vocab at 0x140c8532358>,
#  'diseases': <gensim.models.keyedvectors.Vocab at 0x140c8532390>,
#  'physician': <gensim.models.keyedvectors.Vocab at 0x140c85323c8>,
#  'breast': <gensim.models.keyedvectors.Vocab at 0x140c8532438>,
#  'lack': <gensim.models.keyedvectors.Vocab at 0x140c85324a8>,
#  'awareness': <gensim.models.keyedvectors.Vocab at 0x140c85324e0>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x140c8532550>,
#  'hexosaminidase': <gensim.models.keyedvectors.Vocab at 0x140c8532588>,
#  'familial': <gensim.models.keyedvectors.Vocab at 0x140c85325c0>,
#  'osteodysplasia': <gensim.models.keyedvectors.Vocab at 0x140c85325f8>,
#  'anderson': <gensim.models.keyedvectors.Vocab at 0x140c8532630>,
#  'coronary': <gensim.models.keyedvectors.Vocab at 0x140c8532668>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x140c85326d8>,
#  'monitoring': <gensim.models.keyedvectors.Vocab at 0x140c8532710>,
#  'deleted': <gensim.models.keyedvectors.Vocab at 0x140c8532780>,
#  'hypermelanosis': <gensim.models.keyedvectors.Vocab at 0x140c85327b8>,
#  'hodgkin': <gensim.models.keyedvectors.Vocab at 0x140c8532828>,
#  'muscular': <gensim.models.keyedvectors.Vocab at 0x140c8532860>,
#  'dystrophy': <gensim.models.keyedvectors.Vocab at 0x140c8532898>,
#  'divided': <gensim.models.keyedvectors.Vocab at 0x140c8532908>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x140c8532978>,
#  'atrium': <gensim.models.keyedvectors.Vocab at 0x140c85329e8>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x140c8532a58>,
#  'veins': <gensim.models.keyedvectors.Vocab at 0x140c8532ac8>,
#  'proximal': <gensim.models.keyedvectors.Vocab at 0x140c8532b00>,
#  'communication': <gensim.models.keyedvectors.Vocab at 0x140c8532b38>,
#  'dislocation': <gensim.models.keyedvectors.Vocab at 0x140c8532b70>,
#  'tibia': <gensim.models.keyedvectors.Vocab at 0x140c8532be0>,
#  'rhinophyma': <gensim.models.keyedvectors.Vocab at 0x140c8532c18>,
#  'regular': <gensim.models.keyedvectors.Vocab at 0x140c8532c88>,
#  'astigmatism': <gensim.models.keyedvectors.Vocab at 0x140c8532cc0>,
#  'corneal': <gensim.models.keyedvectors.Vocab at 0x140c8532d30>,
#  'carpometacarpal': <gensim.models.keyedvectors.Vocab at 0x140c8532d68>,
#  'consent': <gensim.models.keyedvectors.Vocab at 0x140c8532dd8>,
#  'postmortem': <gensim.models.keyedvectors.Vocab at 0x140c8532e10>,
#  'declined': <gensim.models.keyedvectors.Vocab at 0x140c8532e48>,
#  'organic': <gensim.models.keyedvectors.Vocab at 0x140c8532eb8>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x140c8532f28>,
#  'cramp': <gensim.models.keyedvectors.Vocab at 0x140c8532f98>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x140c8534048>,
#  'post-stroke': <gensim.models.keyedvectors.Vocab at 0x140c8534080>,
#  'cystic': <gensim.models.keyedvectors.Vocab at 0x140c85340f0>,
#  'duct': <gensim.models.keyedvectors.Vocab at 0x140c8534160>,
#  'o/e-': <gensim.models.keyedvectors.Vocab at 0x140c85341d0>,
#  'visual': <gensim.models.keyedvectors.Vocab at 0x140c8534240>,
#  'acuity': <gensim.models.keyedvectors.Vocab at 0x140c85342b0>,
#  'r-eye': <gensim.models.keyedvectors.Vocab at 0x140c8534320>,
#  '=6/15': <gensim.models.keyedvectors.Vocab at 0x140c8534390>,
#  'extensive': <gensim.models.keyedvectors.Vocab at 0x140c85343c8>,
#  'lipodermatosclerosis': <gensim.models.keyedvectors.Vocab at 0x140c8534400>,
#  'fucosidosis': <gensim.models.keyedvectors.Vocab at 0x140c8534438>,
#  'finger': <gensim.models.keyedvectors.Vocab at 0x140c85344a8>,
#  'feeding': <gensim.models.keyedvectors.Vocab at 0x140c8534518>,
#  'onychomycosis': <gensim.models.keyedvectors.Vocab at 0x140c8534550>,
#  'trichophyton': <gensim.models.keyedvectors.Vocab at 0x140c8534588>,
#  'tonsurans': <gensim.models.keyedvectors.Vocab at 0x140c85345c0>,
#  'st': <gensim.models.keyedvectors.Vocab at 0x140c8534630>,
#  'interval': <gensim.models.keyedvectors.Vocab at 0x140c8534668>,
#  'words': <gensim.models.keyedvectors.Vocab at 0x140c85346d8>,
#  'localised': <gensim.models.keyedvectors.Vocab at 0x140c8534710>,
#  'amyloid': <gensim.models.keyedvectors.Vocab at 0x140c8534780>,
#  'deposit': <gensim.models.keyedvectors.Vocab at 0x140c85347f0>,
#  'recreation': <gensim.models.keyedvectors.Vocab at 0x140c8534828>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x140c8534898>,
#  'myxoid': <gensim.models.keyedvectors.Vocab at 0x140c8534908>,
#  'dermatofibrosarcoma': <gensim.models.keyedvectors.Vocab at 0x140c8534940>,
#  'protuberans': <gensim.models.keyedvectors.Vocab at 0x140c8534978>,
#  'epithelial': <gensim.models.keyedvectors.Vocab at 0x140c85349b0>,
#  'figo': <gensim.models.keyedvectors.Vocab at 0x140c8534a20>,
#  'ivb': <gensim.models.keyedvectors.Vocab at 0x140c8534a90>,
#  'metacarpophalangeal': <gensim.models.keyedvectors.Vocab at 0x140c8534ac8>,
#  'hypermobility': <gensim.models.keyedvectors.Vocab at 0x140c8534b00>,
#  'hyperactive': <gensim.models.keyedvectors.Vocab at 0x140c8534b38>,
#  'bilateral': <gensim.models.keyedvectors.Vocab at 0x140c8534b70>,
#  'labyrinthine': <gensim.models.keyedvectors.Vocab at 0x140c8534ba8>,
#  'dysfunction': <gensim.models.keyedvectors.Vocab at 0x140c8534be0>,
#  'hypo-osmolality': <gensim.models.keyedvectors.Vocab at 0x140c8534c18>,
#  'hyponatraemia': <gensim.models.keyedvectors.Vocab at 0x140c8534c50>,
#  'pyloric': <gensim.models.keyedvectors.Vocab at 0x140c8534cc0>,
#  'antrum': <gensim.models.keyedvectors.Vocab at 0x140c8534d30>,
#  'trisomy': <gensim.models.keyedvectors.Vocab at 0x140c8534da0>,
#  '10p': <gensim.models.keyedvectors.Vocab at 0x140c8534e10>,
#  'amidophosphoribosyltransferase': <gensim.models.keyedvectors.Vocab at 0x140c8534e48>,
#  'gds': <gensim.models.keyedvectors.Vocab at 0x140c8534eb8>,
#  'cognitive': <gensim.models.keyedvectors.Vocab at 0x140c8534ef0>,
#  'decline': <gensim.models.keyedvectors.Vocab at 0x140c8534f60>,
#  'nanophyetus': <gensim.models.keyedvectors.Vocab at 0x140c8534f98>,
#  'salmincola': <gensim.models.keyedvectors.Vocab at 0x140c8534fd0>,
#  'metacarpal': <gensim.models.keyedvectors.Vocab at 0x140c8536048>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x140c85360b8>,
#  'intra-articular': <gensim.models.keyedvectors.Vocab at 0x140c85360f0>,
#  'rolando': <gensim.models.keyedvectors.Vocab at 0x140c8536160>,
#  'implantation': <gensim.models.keyedvectors.Vocab at 0x140c8536198>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x140c8536208>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x140c8536278>,
#  'tower': <gensim.models.keyedvectors.Vocab at 0x140c85362e8>,
#  'ureteric': <gensim.models.keyedvectors.Vocab at 0x140c8536320>,
#  'stent': <gensim.models.keyedvectors.Vocab at 0x140c8536390>,
#  'fetal': <gensim.models.keyedvectors.Vocab at 0x140c8536400>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x140c8536470>,
#  'conspicuous': <gensim.models.keyedvectors.Vocab at 0x140c85364a8>,
#  'donor': <gensim.models.keyedvectors.Vocab at 0x140c8536518>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x140c8536588>,
#  'erectile': <gensim.models.keyedvectors.Vocab at 0x140c85365c0>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x140c85365f8>,
#  'radical': <gensim.models.keyedvectors.Vocab at 0x140c8536668>,
#  'cystectomy': <gensim.models.keyedvectors.Vocab at 0x140c85366a0>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x140c8536710>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x140c8536780>,
#  'bath': <gensim.models.keyedvectors.Vocab at 0x140c85367f0>,
#  'flucytosine': <gensim.models.keyedvectors.Vocab at 0x140c8536828>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x140c8536860>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x140c85368d0>,
#  'gestation': <gensim.models.keyedvectors.Vocab at 0x140c8536908>,
#  'period': <gensim.models.keyedvectors.Vocab at 0x140c8536978>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x140c85369b0>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x140c8536a20>,
#  'nephrotic': <gensim.models.keyedvectors.Vocab at 0x140c8536a58>,
#  'malaria': <gensim.models.keyedvectors.Vocab at 0x140c8536ac8>,
#  'homozygous': <gensim.models.keyedvectors.Vocab at 0x140c8536b00>,
#  'beta': <gensim.models.keyedvectors.Vocab at 0x140c8536b70>,
#  'thalassaemia': <gensim.models.keyedvectors.Vocab at 0x140c8536ba8>,
#  'purulent': <gensim.models.keyedvectors.Vocab at 0x140c8536be0>,
#  'pericarditis': <gensim.models.keyedvectors.Vocab at 0x140c8536c18>,
#  'florid': <gensim.models.keyedvectors.Vocab at 0x140c8536c88>,
#  'reactive': <gensim.models.keyedvectors.Vocab at 0x140c8536cc0>,
#  'periostitis': <gensim.models.keyedvectors.Vocab at 0x140c8536cf8>,
#  'dermatosis': <gensim.models.keyedvectors.Vocab at 0x140c8536d30>,
#  'spider': <gensim.models.keyedvectors.Vocab at 0x140c8536da0>,
#  'thin': <gensim.models.keyedvectors.Vocab at 0x140c8536e10>,
#  'sputum': <gensim.models.keyedvectors.Vocab at 0x140c8536e80>,
#  'lesion': <gensim.models.keyedvectors.Vocab at 0x140c8536ef0>,
#  'moderate': <gensim.models.keyedvectors.Vocab at 0x140c8536f28>,
#  'receptive': <gensim.models.keyedvectors.Vocab at 0x140c8536f60>,
#  'language': <gensim.models.keyedvectors.Vocab at 0x140c8536f98>,
#  'delay': <gensim.models.keyedvectors.Vocab at 0x140c854a048>,
#  'and/or': <gensim.models.keyedvectors.Vocab at 0x140c854a0b8>,
#  'recurrent': <gensim.models.keyedvectors.Vocab at 0x140c854a0f0>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x140c854a160>,
#  'osteoarthritis': <gensim.models.keyedvectors.Vocab at 0x140c854a198>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x140c854a208>,
#  'metatarsophalangeal': <gensim.models.keyedvectors.Vocab at 0x140c854a240>,
#  'inflammatory': <gensim.models.keyedvectors.Vocab at 0x140c854a278>,
#  'arthritis': <gensim.models.keyedvectors.Vocab at 0x140c854a2b0>,
#  'waldenstrom': <gensim.models.keyedvectors.Vocab at 0x140c854a2e8>,
#  'hypergammaglobulinaemic': <gensim.models.keyedvectors.Vocab at 0x140c854a320>,
#  'purpura': <gensim.models.keyedvectors.Vocab at 0x140c854a390>,
#  'atresia': <gensim.models.keyedvectors.Vocab at 0x140c854a400>,
#  'atrophy': <gensim.models.keyedvectors.Vocab at 0x140c854a470>,
#  'vas': <gensim.models.keyedvectors.Vocab at 0x140c854a4e0>,
#  'deferens': <gensim.models.keyedvectors.Vocab at 0x140c854a518>,
#  'axillary': <gensim.models.keyedvectors.Vocab at 0x140c854a550>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x140c854a5c0>,
#  'tanner': <gensim.models.keyedvectors.Vocab at 0x140c854a630>,
#  'wasp': <gensim.models.keyedvectors.Vocab at 0x140c854a6a0>,
#  'sting-induced': <gensim.models.keyedvectors.Vocab at 0x140c854a6d8>,
#  'anaphylaxis': <gensim.models.keyedvectors.Vocab at 0x140c854a710>,
#  'ascites': <gensim.models.keyedvectors.Vocab at 0x140c854a780>,
#  'prelogical': <gensim.models.keyedvectors.Vocab at 0x140c854a7b8>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x140c854a7f0>,
#  'celatum': <gensim.models.keyedvectors.Vocab at 0x140c854a860>,
#  'frotteurism': <gensim.models.keyedvectors.Vocab at 0x140c854a898>,
#  'aneurysm': <gensim.models.keyedvectors.Vocab at 0x140c854a8d0>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x140c854a940>,
#  'cerebral': <gensim.models.keyedvectors.Vocab at 0x140c854a978>,
#  'requires': <gensim.models.keyedvectors.Vocab at 0x140c854a9b0>,
#  'varicella': <gensim.models.keyedvectors.Vocab at 0x140c854a9e8>,
#  'vaccination': <gensim.models.keyedvectors.Vocab at 0x140c854aa20>,
# ...
#  'acceptance': <gensim.models.keyedvectors.Vocab at 0x140c853d550>,
#  'grief': <gensim.models.keyedvectors.Vocab at 0x140c853d5c0>,
#  't2': <gensim.models.keyedvectors.Vocab at 0x140c853d630>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x140c853d668>,
#  'cm': <gensim.models.keyedvectors.Vocab at 0x140c853d6d8>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x140c853d710>,
#  'dimension': <gensim.models.keyedvectors.Vocab at 0x140c853d748>,
#  'extraparenchymal': <gensim.models.keyedvectors.Vocab at 0x140c853d780>,
#  'ceftizoxime': <gensim.models.keyedvectors.Vocab at 0x140c853d7b8>,
#  'painful': <gensim.models.keyedvectors.Vocab at 0x140c853d828>,
#  'gastric': <gensim.models.keyedvectors.Vocab at 0x140c853d898>,
#  'emptying': <gensim.models.keyedvectors.Vocab at 0x140c853d8d0>,
#  'fractured': <gensim.models.keyedvectors.Vocab at 0x140c853d908>,
#  'dental': <gensim.models.keyedvectors.Vocab at 0x140c853d978>,
#  'veneer': <gensim.models.keyedvectors.Vocab at 0x140c853d9e8>,
#  'gastromenia': <gensim.models.keyedvectors.Vocab at 0x140c853da20>,
#  'perioperative': <gensim.models.keyedvectors.Vocab at 0x140c853da58>,
#  'isophane': <gensim.models.keyedvectors.Vocab at 0x140c853da90>,
#  'insulin': <gensim.models.keyedvectors.Vocab at 0x140c853db00>,
#  'peroneal': <gensim.models.keyedvectors.Vocab at 0x140c853db38>,
#  'tendinitis': <gensim.models.keyedvectors.Vocab at 0x140c853db70>,
#  'cutis': <gensim.models.keyedvectors.Vocab at 0x140c853dbe0>,
#  'laxa': <gensim.models.keyedvectors.Vocab at 0x140c853dc50>,
#  'faecal': <gensim.models.keyedvectors.Vocab at 0x140c853dcc0>,
#  'peritonitis': <gensim.models.keyedvectors.Vocab at 0x140c853dcf8>,
#  'incipient': <gensim.models.keyedvectors.Vocab at 0x140c853dd30>,
#  'clean': <gensim.models.keyedvectors.Vocab at 0x140c853dda0>,
#  'windows': <gensim.models.keyedvectors.Vocab at 0x140c853de10>,
#  'functional': <gensim.models.keyedvectors.Vocab at 0x140c853de48>,
#  'proteinuria': <gensim.models.keyedvectors.Vocab at 0x140c853de80>,
#  'infestation': <gensim.models.keyedvectors.Vocab at 0x140c853deb8>,
#  'oedemagena': <gensim.models.keyedvectors.Vocab at 0x140c853def0>,
#  'coordinate': <gensim.models.keyedvectors.Vocab at 0x140c853df28>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x140c853df60>,
#  'plans': <gensim.models.keyedvectors.Vocab at 0x140c853dfd0>,
#  'strain': <gensim.models.keyedvectors.Vocab at 0x140c854e080>,
#  'muscle': <gensim.models.keyedvectors.Vocab at 0x140c854e0f0>,
#  'ear': <gensim.models.keyedvectors.Vocab at 0x140c854e160>,
#  'ring': <gensim.models.keyedvectors.Vocab at 0x140c854e1d0>,
#  'chromosome': <gensim.models.keyedvectors.Vocab at 0x140c854e208>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x140c854e278>,
#  'vallecular': <gensim.models.keyedvectors.Vocab at 0x140c854e2b0>,
#  'focal': <gensim.models.keyedvectors.Vocab at 0x140c854e320>,
#  'injuries': <gensim.models.keyedvectors.Vocab at 0x140c854e358>,
#  'cerebellum': <gensim.models.keyedvectors.Vocab at 0x140c854e390>,
#  'beta-galactosidase': <gensim.models.keyedvectors.Vocab at 0x140c854e3c8>,
#  'increased': <gensim.models.keyedvectors.Vocab at 0x140c854e400>,
#  'passive': <gensim.models.keyedvectors.Vocab at 0x140c854e470>,
#  'ovary': <gensim.models.keyedvectors.Vocab at 0x140c854e4e0>,
#  'toxic': <gensim.models.keyedvectors.Vocab at 0x140c854e550>,
#  'myocarditis': <gensim.models.keyedvectors.Vocab at 0x140c854e588>,
#  'resting': <gensim.models.keyedvectors.Vocab at 0x140c854e5f8>,
#  'ischaemia': <gensim.models.keyedvectors.Vocab at 0x140c854e630>,
#  'co-occurrent': <gensim.models.keyedvectors.Vocab at 0x140c854e668>,
#  'ischaemic': <gensim.models.keyedvectors.Vocab at 0x140c854e6a0>,
#  'outpatient': <gensim.models.keyedvectors.Vocab at 0x140c854e6d8>,
#  'appointment': <gensim.models.keyedvectors.Vocab at 0x140c854e710>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x140c854e780>,
#  'footwear': <gensim.models.keyedvectors.Vocab at 0x140c854e7b8>,
#  'showing': <gensim.models.keyedvectors.Vocab at 0x140c854e828>,
#  'signs': <gensim.models.keyedvectors.Vocab at 0x140c854e898>,
#  'construction': <gensim.models.keyedvectors.Vocab at 0x140c854e8d0>,
#  'carmustine': <gensim.models.keyedvectors.Vocab at 0x140c854e908>,
#  'temporal': <gensim.models.keyedvectors.Vocab at 0x140c854e940>,
#  'lobar': <gensim.models.keyedvectors.Vocab at 0x140c854e9b0>,
#  'radial': <gensim.models.keyedvectors.Vocab at 0x140c854ea20>,
#  'polydactyly': <gensim.models.keyedvectors.Vocab at 0x140c854ea58>,
#  'wassel': <gensim.models.keyedvectors.Vocab at 0x140c854eac8>,
#  'amianthium': <gensim.models.keyedvectors.Vocab at 0x140c854eb00>,
#  'muscaetoxicum': <gensim.models.keyedvectors.Vocab at 0x140c854eb38>,
#  'fibrosis': <gensim.models.keyedvectors.Vocab at 0x140c854eb70>,
#  'hermansky-pudlak': <gensim.models.keyedvectors.Vocab at 0x140c854eba8>,
#  'postpancreatectomy': <gensim.models.keyedvectors.Vocab at 0x140c854ebe0>,
#  'hyperglycaemia': <gensim.models.keyedvectors.Vocab at 0x140c854ec18>,
#  'pneumococcal': <gensim.models.keyedvectors.Vocab at 0x140c854ec50>,
#  'return': <gensim.models.keyedvectors.Vocab at 0x140c854ecc0>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x140c854ed30>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x140c854eda0>,
#  'necessary': <gensim.models.keyedvectors.Vocab at 0x140c854edd8>,
#  'entire': <gensim.models.keyedvectors.Vocab at 0x140c854ee48>,
#  'pyrroline-2-carboxylate': <gensim.models.keyedvectors.Vocab at 0x140c854ee80>,
#  'reductase': <gensim.models.keyedvectors.Vocab at 0x140c854eeb8>,
#  'leakage': <gensim.models.keyedvectors.Vocab at 0x140c854ef28>,
#  'pyloroplasty': <gensim.models.keyedvectors.Vocab at 0x140c854ef60>,
#  'growth': <gensim.models.keyedvectors.Vocab at 0x140c854efd0>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x140c8560048>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x140c85600b8>,
#  'difficult': <gensim.models.keyedvectors.Vocab at 0x140c85600f0>,
#  'establish': <gensim.models.keyedvectors.Vocab at 0x140c8560128>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x140c8560160>,
#  'deaf': <gensim.models.keyedvectors.Vocab at 0x140c85601d0>,
#  'epilepsy': <gensim.models.keyedvectors.Vocab at 0x140c8560208>,
#  'eyelid': <gensim.models.keyedvectors.Vocab at 0x140c8560278>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x140c85602b0>,
#  'canthus': <gensim.models.keyedvectors.Vocab at 0x140c8560320>,
#  'combined': <gensim.models.keyedvectors.Vocab at 0x140c8560358>,
#  'immunodeficiency': <gensim.models.keyedvectors.Vocab at 0x140c8560390>,
#  'zap70': <gensim.models.keyedvectors.Vocab at 0x140c8560400>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x140c8560470>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x140c85604e0>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x140c8560550>,
#  'strangulation': <gensim.models.keyedvectors.Vocab at 0x140c8560588>,
#  'slow': <gensim.models.keyedvectors.Vocab at 0x140c85605f8>,
#  'acetylator': <gensim.models.keyedvectors.Vocab at 0x140c8560630>,
#  'n-acetyltransferase': <gensim.models.keyedvectors.Vocab at 0x140c8560668>,
#  'enzyme': <gensim.models.keyedvectors.Vocab at 0x140c85606d8>,
#  'variant': <gensim.models.keyedvectors.Vocab at 0x140c8560748>,
#  'intracellular': <gensim.models.keyedvectors.Vocab at 0x140c8560780>,
#  'elementary': <gensim.models.keyedvectors.Vocab at 0x140c85607b8>,
#  'bodies': <gensim.models.keyedvectors.Vocab at 0x140c8560828>,
#  'detected': <gensim.models.keyedvectors.Vocab at 0x140c8560860>,
#  'diffuse': <gensim.models.keyedvectors.Vocab at 0x140c85608d0>,
#  'neurofibroma': <gensim.models.keyedvectors.Vocab at 0x140c8560908>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x140c8560940>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x140c85609b0>,
#  'sinus': <gensim.models.keyedvectors.Vocab at 0x140c8560a20>,
#  'surgical': <gensim.models.keyedvectors.Vocab at 0x140c8560a58>,
#  'procedure': <gensim.models.keyedvectors.Vocab at 0x140c8560a90>,
#  'echo': <gensim.models.keyedvectors.Vocab at 0x140c8560b00>,
#  'razoxane': <gensim.models.keyedvectors.Vocab at 0x140c8560b38>,
#  'privacy': <gensim.models.keyedvectors.Vocab at 0x140c8560ba8>,
#  'maintained': <gensim.models.keyedvectors.Vocab at 0x140c8560be0>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x140c8560c50>,
#  'sperm': <gensim.models.keyedvectors.Vocab at 0x140c8560cc0>,
#  'morphology': <gensim.models.keyedvectors.Vocab at 0x140c8560cf8>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x140c8560d68>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x140c8560dd8>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x140c8560e48>,
#  '%': <gensim.models.keyedvectors.Vocab at 0x140c8560e80>,
#  'tension': <gensim.models.keyedvectors.Vocab at 0x140c8560ef0>,
#  'pneumothorax': <gensim.models.keyedvectors.Vocab at 0x140c8560f28>,
#  'gallbladder': <gensim.models.keyedvectors.Vocab at 0x140c8560f60>,
#  'palpated': <gensim.models.keyedvectors.Vocab at 0x140c8560f98>,
#  'osteosclerotic': <gensim.models.keyedvectors.Vocab at 0x140c8560fd0>,
#  'myeloma': <gensim.models.keyedvectors.Vocab at 0x140c8564080>,
#  'patellofemoral': <gensim.models.keyedvectors.Vocab at 0x140c85640b8>,
#  'maltracking': <gensim.models.keyedvectors.Vocab at 0x140c85640f0>,
#  'transplanted': <gensim.models.keyedvectors.Vocab at 0x140c8564128>,
#  'pt3': <gensim.models.keyedvectors.Vocab at 0x140c8564198>,
#  'directly': <gensim.models.keyedvectors.Vocab at 0x140c85641d0>,
#  'invades': <gensim.models.keyedvectors.Vocab at 0x140c8564240>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x140c85642b0>,
#  'chest': <gensim.models.keyedvectors.Vocab at 0x140c8564320>,
#  'diaphragm': <gensim.models.keyedvectors.Vocab at 0x140c8564358>,
#  'mediastinal': <gensim.models.keyedvectors.Vocab at 0x140c8564390>,
#  'pleura': <gensim.models.keyedvectors.Vocab at 0x140c8564400>,
#  'parietal': <gensim.models.keyedvectors.Vocab at 0x140c8564438>,
#  'pericardium': <gensim.models.keyedvectors.Vocab at 0x140c8564470>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x140c85644a8>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x140c8564518>,
#  'bronchus': <gensim.models.keyedvectors.Vocab at 0x140c8564550>,
#  'distal': <gensim.models.keyedvectors.Vocab at 0x140c85645c0>,
#  'carina': <gensim.models.keyedvectors.Vocab at 0x140c8564630>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x140c85646a0>,
#  'assoc': <gensim.models.keyedvectors.Vocab at 0x140c8564710>,
#  'atelectasis': <gensim.models.keyedvectors.Vocab at 0x140c8564748>,
#  'obstructive': <gensim.models.keyedvectors.Vocab at 0x140c8564780>,
#  'pneumonitis': <gensim.models.keyedvectors.Vocab at 0x140c85647b8>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x140c8564828>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x140c8564898>,
#  'cheek': <gensim.models.keyedvectors.Vocab at 0x140c8564908>,
#  'suprasellar': <gensim.models.keyedvectors.Vocab at 0x140c8564940>,
#  'pituitary': <gensim.models.keyedvectors.Vocab at 0x140c8564978>,
#  'adenoma': <gensim.models.keyedvectors.Vocab at 0x140c85649e8>,
#  'colour': <gensim.models.keyedvectors.Vocab at 0x140c8564a58>,
#  'tympanic': <gensim.models.keyedvectors.Vocab at 0x140c8564a90>,
#  'membrane': <gensim.models.keyedvectors.Vocab at 0x140c8564ac8>,
#  'glandular': <gensim.models.keyedvectors.Vocab at 0x140c8564b00>,
#  'neurilemmoma': <gensim.models.keyedvectors.Vocab at 0x140c8564b38>,
#  'aminophylline': <gensim.models.keyedvectors.Vocab at 0x140c8564b70>,
#  'terbufos': <gensim.models.keyedvectors.Vocab at 0x140c8564ba8>,
#  'susceptibility': <gensim.models.keyedvectors.Vocab at 0x140c8564be0>,
#  'infections': <gensim.models.keyedvectors.Vocab at 0x140c8564c18>,
#  'apnoea': <gensim.models.keyedvectors.Vocab at 0x140c8564c88>,
#  'newborn': <gensim.models.keyedvectors.Vocab at 0x140c8564cf8>,
#  'chondrocalcinosis': <gensim.models.keyedvectors.Vocab at 0x140c8564d30>,
#  'anomalous': <gensim.models.keyedvectors.Vocab at 0x140c8564d68>,
#  'origin': <gensim.models.keyedvectors.Vocab at 0x140c8564dd8>,
#  'arterial': <gensim.models.keyedvectors.Vocab at 0x140c8564e10>,
#  'subclavian': <gensim.models.keyedvectors.Vocab at 0x140c8564e48>,
#  'rolling': <gensim.models.keyedvectors.Vocab at 0x140c8564eb8>,
#  'hiatus': <gensim.models.keyedvectors.Vocab at 0x140c8564f28>,
#  'hernia': <gensim.models.keyedvectors.Vocab at 0x140c8564f98>,
#  'volvulus': <gensim.models.keyedvectors.Vocab at 0x140c8564fd0>,
#  'pustular': <gensim.models.keyedvectors.Vocab at 0x140c8569048>,
#  'chilblain': <gensim.models.keyedvectors.Vocab at 0x140c8569080>,
#  'kalanchoe': <gensim.models.keyedvectors.Vocab at 0x140c85690b8>,
#  'species': <gensim.models.keyedvectors.Vocab at 0x140c8569128>,
#  'benign': <gensim.models.keyedvectors.Vocab at 0x140c8569198>,
#  'vessel': <gensim.models.keyedvectors.Vocab at 0x140c8569208>,
#  'thorax': <gensim.models.keyedvectors.Vocab at 0x140c8569278>,
#  'aspirate': <gensim.models.keyedvectors.Vocab at 0x140c85692b0>,
#  'applicable': <gensim.models.keyedvectors.Vocab at 0x140c85692e8>,
#  'pelvis': <gensim.models.keyedvectors.Vocab at 0x140c8569358>,
#  'pure': <gensim.models.keyedvectors.Vocab at 0x140c85693c8>,
#  'hyperglyceridaemia': <gensim.models.keyedvectors.Vocab at 0x140c8569400>,
#  'ctg': <gensim.models.keyedvectors.Vocab at 0x140c8569470>,
#  'tracing': <gensim.models.keyedvectors.Vocab at 0x140c85694e0>,
#  'vaginal': <gensim.models.keyedvectors.Vocab at 0x140c8569550>,
#  'secretions': <gensim.models.keyedvectors.Vocab at 0x140c8569588>,
#  'manifest-latent': <gensim.models.keyedvectors.Vocab at 0x140c85695c0>,
#  'gross': <gensim.models.keyedvectors.Vocab at 0x140c8569630>,
#  'inspection': <gensim.models.keyedvectors.Vocab at 0x140c8569668>,
#  'evaluation': <gensim.models.keyedvectors.Vocab at 0x140c85696a0>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x140c85696d8>,
#  'perioral': <gensim.models.keyedvectors.Vocab at 0x140c8569710>,
#  'periocular': <gensim.models.keyedvectors.Vocab at 0x140c8569748>,
#  'klebsiella': <gensim.models.keyedvectors.Vocab at 0x140c8569780>,
#  'cystitis': <gensim.models.keyedvectors.Vocab at 0x140c85697b8>,
#  'binge': <gensim.models.keyedvectors.Vocab at 0x140c8569828>,
#  'obstruction': <gensim.models.keyedvectors.Vocab at 0x140c8569860>,
#  'client': <gensim.models.keyedvectors.Vocab at 0x140c85698d0>,
#  'requests': <gensim.models.keyedvectors.Vocab at 0x140c8569908>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x140c8569978>,
#  'personal': <gensim.models.keyedvectors.Vocab at 0x140c85699b0>,
#  'records': <gensim.models.keyedvectors.Vocab at 0x140c8569a20>,
#  'tyrosinaemia': <gensim.models.keyedvectors.Vocab at 0x140c8569a58>,
#  'haemolytic': <gensim.models.keyedvectors.Vocab at 0x140c8569a90>,
#  'anaemia': <gensim.models.keyedvectors.Vocab at 0x140c8569b00>,
#  'hyperbaric': <gensim.models.keyedvectors.Vocab at 0x140c8569b38>,
#  'oxygen': <gensim.models.keyedvectors.Vocab at 0x140c8569ba8>,
#  'limbal': <gensim.models.keyedvectors.Vocab at 0x140c8569c18>,
#  'guttering': <gensim.models.keyedvectors.Vocab at 0x140c8569c50>,
#  'descending': <gensim.models.keyedvectors.Vocab at 0x140c8569c88>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x140c8569cf8>,
#  'abdominal': <gensim.models.keyedvectors.Vocab at 0x140c8569d30>,
#  'cavity': <gensim.models.keyedvectors.Vocab at 0x140c8569da0>,
#  'macrosquare-wave': <gensim.models.keyedvectors.Vocab at 0x140c8569dd8>,
#  'jerks': <gensim.models.keyedvectors.Vocab at 0x140c8569e48>,
#  'transient': <gensim.models.keyedvectors.Vocab at 0x140c8569e80>,
#  'tachypnoea': <gensim.models.keyedvectors.Vocab at 0x140c8569eb8>,
#  'prescription': <gensim.models.keyedvectors.Vocab at 0x140c8569ef0>,
#  'collected': <gensim.models.keyedvectors.Vocab at 0x140c8569f28>,
#  'patient': <gensim.models.keyedvectors.Vocab at 0x140c8569f98>,
#  'presence': <gensim.models.keyedvectors.Vocab at 0x140c8569fd0>,
#  'muscularis': <gensim.models.keyedvectors.Vocab at 0x140c856d048>,
#  'propria': <gensim.models.keyedvectors.Vocab at 0x140c856d0b8>,
#  'specimen': <gensim.models.keyedvectors.Vocab at 0x140c856d0f0>,
#  'indeterminate': <gensim.models.keyedvectors.Vocab at 0x140c856d128>,
#  'pott': <gensim.models.keyedvectors.Vocab at 0x140c856d198>,
#  'curvature': <gensim.models.keyedvectors.Vocab at 0x140c856d1d0>,
#  'stress': <gensim.models.keyedvectors.Vocab at 0x140c856d240>,
#  ...}

# %% [markdown]
# ## Testing the model

# %%
test_doc = word_tokenize("I can understand he is suffering from Chronic tophaceous gout of hand due to renal impairment".lower())
model.docvecs.most_similar(positive=[model.infer_vector(test_doc)],topn=5)
best_result = model.docvecs.most_similar(positive=[model.infer_vector(test_doc)],topn=1)
print("Best Result: ",best_result[0][0])
print("Sureity percntage: ",best_result[0][1])
# Out:
# Best Result:  288371008
# Sureity percntage:  0.36000412702560425

# %% [markdown]
# Thank you
