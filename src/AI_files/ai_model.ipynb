# %%
import numpy as np
from spacy.lang.en import English
import pandas as pd
import os
os.chdir('../')

# %%
data = "./Medico/data/data.csv"
read_csv = pd.read_csv(data)
read_csv
# Out:
#                    code                                            display
# 0       303921000119109  Chronic tophaceous gout of hand due to renal i...
# 1             450309001  Major systemic to pulmonary collateral artery ...
# 2             428799009         Rotatory subluxation of atlantoaxial joint
# 3              93936002        Primary malignant neoplasm of palatine bone
# 4             164510000                         O/E - elbow joint abnormal
# 5             200370007  Obstetric nipple infection with postnatal comp...
# 6             247002006       Anterior chamber pseudo-exfoliation deposits
# 7             280948003                           Normal sense of identity
# 8             288642003                         Does initiate conversation
# 9             783619003  DYRK1A-related intellectual disability syndrom...
# 10             95469008                           Abnormal plantar creases
# 11            173599005     Acute necrotising ulcerative gingivostomatitis
# 12             75697004      Term birth of identical twins, both stillborn
# 13            237138004                          Menopause ovarian failure
# 14            170561004                     Chronic disease - poor control
# 15            294695007                                  Cortisone allergy
# 16            282626003                            Able to roll on to side
# 17             64787009  Displacement of thoracic intervertebral disc w...
# 18            424629004  Transportation barrier impedes ability to use ...
# 19            239826001  Chronic infantile neurological, cutaneous and ...
# 20            253595004                           Pulmonary valve prolapse
# 21            240022008                        Posterior ankle impingement
# 22      135001000119100  Acute deep venous thrombosis of internal jugul...
# 23              6224002                      Decreased hormonal resistance
# 24            263170006                       Fracture of supraorbital rim
# 25            277850002                                  Diogenes syndrome
# 26            164641005                            O/E - sign - ankle/foot
# 27            447777009  Spontaneous closure of ventricular component o...
# 28            719254001                     Spinocerebellar ataxia type 32
# 29            161818003                                  Vulval irritation
# ...                 ...                                                ...
# 110686        234119001                       Congenital anomaly of artery
# 110687        359557001                                 Disorder of artery
# 110688        762250009                 Congenital anomaly of great vessel
# 110689        400159008                   Congenital vascular malformation
# 110690        399982001                       Congenital vascular disorder
# 110691          9904008        Congenital anomaly of cardiovascular system
# 110692        762228008                 Congenital cardiovascular disorder
# 110693         39785005                  Disorder of pulmonary circulation
# 110694        373434004                Disorder of blood vessels of thorax
# 110695         27550009                                  Vascular disorder
# 110696         19660004                            Disorder of soft tissue
# 110697         49601007                             Cardiovascular disease
# 110698         49483002                            Disorder of mediastinum
# 110699        702612001                         Congenital aplasia of lung
# 110700         47147007                         Congenital anomaly of lung
# 110701        123654008     Congenital anomaly of lower respiratory system
# 110702        275260000       Congenital anomaly of the respiratory system
# 110703         19829001                                  Pulmonary disease
# 110704        128272009               Disorder of lower respiratory system
# 110705         50043002                                Respiratory disease
# 110706        362965005                            Disorder of body system
# 110707        363035006                       Congenital anomaly of thorax
# 110708        363037003                  Congenital anomaly of upper trunk
# 110709         78626001                        Congenital anomaly of trunk
# 110710        276654001                                 Congenital anomaly
# 110711         66091009                                 Congenital disease
# 110712          5294002                             Developmental disorder
# 110713        118946009                                 Disorder of thorax
# 110714        609622007              Disorder of thoracic segment of trunk
# 110715        128121009                                  Disorder of trunk
#
# [110716 rows x 2 columns]

# %%
data_frame = pd.DataFrame(read_csv)
data_frame.head()
# Out:
#               code                                            display
# 0  303921000119109  Chronic tophaceous gout of hand due to renal i...
# 1        450309001  Major systemic to pulmonary collateral artery ...
# 2        428799009         Rotatory subluxation of atlantoaxial joint
# 3         93936002        Primary malignant neoplasm of palatine bone
# 4        164510000                         O/E - elbow joint abnormal

# %%
feature = data_frame["display"]
feature.head()
# Out:
# 0    Chronic tophaceous gout of hand due to renal i...
# 1    Major systemic to pulmonary collateral artery ...
# 2           Rotatory subluxation of atlantoaxial joint
# 3          Primary malignant neoplasm of palatine bone
# 4                           O/E - elbow joint abnormal
# Name: display, dtype: object

# %%
nlp = English()
head = list(feature)
from spacy.lang.en.stop_words import STOP_WORDS
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
#Implementation of stop words:
def spacy_tokenizer(sentence):
    filtered_sent=[]


    # filtering stop words
    for line in head:
        sentence = ""
        doc = nlp(line)
        for word in doc:
            if word.is_stop==False:
                sentence = sentence + " " + str(word)
        filtered_sent.append(sentence)
    return filtered_sent

bow_vector = CountVectorizer(tokenizer = spacy_tokenizer, ngram_range=(1,1))
tfidf_vector = TfidfVectorizer(tokenizer = spacy_tokenizer)

# %%
class predictors():
    def transform(self, X, **transform_params):
        # Cleaning Text
        return [clean_text(text) for text in X]

    def fit(self, X, y=None, **fit_params):
        return self

    def get_params(self, deep=True):
        return {}

# Basic function to clean the text
def clean_text(text):
    # Removing spaces and converting text into lowercase
    return text.strip().lower()

# %%
X_train = data_frame["display"]
Y_train = data_frame["code"]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
classifier = LogisticRegression()

# Create pipeline using Bag of Words
pipe = Pipeline([("cleaner", predictors()),
                 ('vectorizer', bow_vector),
                 ('classifier', classifier)])

# model generation
pipe.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-7cb170c3ff91> in <module>
#       9
#      10 # model generation
# ---> 11 pipe.fit(X_train,Y_train)
#
# D:\anaconda\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     263             This estimator
#     264         """
# --> 265         Xt, fit_params = self._fit(X, y, **fit_params)
#     266         if self._final_estimator is not None:
#     267             self._final_estimator.fit(Xt, y, **fit_params)
#
# D:\anaconda\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params)
#     228                 Xt, fitted_transformer = fit_transform_one_cached(
#     229                     cloned_transformer, Xt, y, None,
# --> 230                     **fit_params_steps[name])
#     231                 # Replace the transformer of the step with the fitted
#     232                 # transformer. This is necessary when loading the transformer
#
# D:\anaconda\lib\site-packages\sklearn\externals\joblib\memory.py in __call__(self, *args, **kwargs)
#     340
#     341     def __call__(self, *args, **kwargs):
# --> 342         return self.func(*args, **kwargs)
#     343
#     344     def call_and_shelve(self, *args, **kwargs):
#
# D:\anaconda\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, **fit_params)
#     612 def _fit_transform_one(transformer, X, y, weight, **fit_params):
#     613     if hasattr(transformer, 'fit_transform'):
# --> 614         res = transformer.fit_transform(X, y, **fit_params)
#     615     else:
#     616         res = transformer.fit(X, y, **fit_params).transform(X)
#
# D:\anaconda\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1029
#    1030         vocabulary, X = self._count_vocab(raw_documents,
# -> 1031                                           self.fixed_vocabulary_)
#    1032
#    1033         if self.binary:
#
# D:\anaconda\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     941         for doc in raw_documents:
#     942             feature_counter = {}
# --> 943             for feature in analyze(doc):
#     944                 try:
#     945                     feature_idx = vocabulary[feature]
#
# D:\anaconda\lib\site-packages\sklearn\feature_extraction\text.py in <lambda>(doc)
#     327                                                tokenize)
#     328             return lambda doc: self._word_ngrams(
# --> 329                 tokenize(preprocess(self.decode(doc))), stop_words)
#     330
#     331         else:
#
# <ipython-input-76-94e4cd7d7325> in spacy_tokenizer(sentence)
#      15         for word in doc:
#      16             if word.is_stop==False:
# ---> 17                 sentence = sentence + " " + str(word)
#      18         filtered_sent.append(sentence)
#      19     return filtered_sent
#
# KeyboardInterrupt:

# %%
from sklearn import metrics
# Predicting with a test dataset
X_test = "Primary malignant neoplasm of palatine bone"
predicted = pipe.predict(X_test)

y_test = 93936002
# Model Accuracy
print("Logistic Regression Accuracy:",metrics.accuracy_score(y_test, predicted))
print("Logistic Regression Precision:",metrics.precision_score(y_test, predicted))
print("Logistic Regression Recall:",metrics.recall_score(y_test, predicted))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-82-77d5a227df98> in <module>
#       2 # Predicting with a test dataset
#       3 X_test = "Primary malignant neoplasm of palatine bone"
# ----> 4 predicted = pipe.predict(X_test)
#       5
#       6 y_test = 93936002
#
# D:\anaconda\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     116
#     117         # lambda, but not partial, allows help() to work with update_wrapper
# --> 118         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     119         # update the docstring of the returned function
#     120         update_wrapper(out, self.fn)
#
# D:\anaconda\lib\site-packages\sklearn\pipeline.py in predict(self, X, **predict_params)
#     329         for name, transform in self.steps[:-1]:
#     330             if transform is not None:
# --> 331                 Xt = transform.transform(Xt)
#     332         return self.steps[-1][-1].predict(Xt, **predict_params)
#     333
#
# D:\anaconda\lib\site-packages\sklearn\feature_extraction\text.py in transform(self, raw_documents)
#    1080             self._validate_vocabulary()
#    1081
# -> 1082         self._check_vocabulary()
#    1083
#    1084         # use the same matrix-building strategy as fit_transform
#
# D:\anaconda\lib\site-packages\sklearn\feature_extraction\text.py in _check_vocabulary(self)
#     364         """Check if vocabulary is empty or missing (not fit-ed)"""
#     365         msg = "%(name)s - Vocabulary wasn't fitted."
# --> 366         check_is_fitted(self, 'vocabulary_', msg=msg),
#     367
#     368         if len(self.vocabulary_) == 0:
#
# D:\anaconda\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     949
#     950     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 951         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     952
#     953
#
# NotFittedError: CountVectorizer - Vocabulary wasn't fitted.

# %%
import numpy as np
from spacy.lang.en import English
import pandas as pd
import os
os.chdir('../')

# %%
data = "./data/data.csv"
read_csv = pd.read_csv(data)
read_csv
# Out:
#                    code                                            display
# 0       303921000119109  Chronic tophaceous gout of hand due to renal i...
# 1             450309001  Major systemic to pulmonary collateral artery ...
# 2             428799009         Rotatory subluxation of atlantoaxial joint
# 3              93936002        Primary malignant neoplasm of palatine bone
# 4             164510000                         O/E - elbow joint abnormal
# 5             200370007  Obstetric nipple infection with postnatal comp...
# 6             247002006       Anterior chamber pseudo-exfoliation deposits
# 7             280948003                           Normal sense of identity
# 8             288642003                         Does initiate conversation
# 9             783619003  DYRK1A-related intellectual disability syndrom...
# 10             95469008                           Abnormal plantar creases
# 11            173599005     Acute necrotising ulcerative gingivostomatitis
# 12             75697004      Term birth of identical twins, both stillborn
# 13            237138004                          Menopause ovarian failure
# 14            170561004                     Chronic disease - poor control
# 15            294695007                                  Cortisone allergy
# 16            282626003                            Able to roll on to side
# 17             64787009  Displacement of thoracic intervertebral disc w...
# 18            424629004  Transportation barrier impedes ability to use ...
# 19            239826001  Chronic infantile neurological, cutaneous and ...
# 20            253595004                           Pulmonary valve prolapse
# 21            240022008                        Posterior ankle impingement
# 22      135001000119100  Acute deep venous thrombosis of internal jugul...
# 23              6224002                      Decreased hormonal resistance
# 24            263170006                       Fracture of supraorbital rim
# 25            277850002                                  Diogenes syndrome
# 26            164641005                            O/E - sign - ankle/foot
# 27            447777009  Spontaneous closure of ventricular component o...
# 28            719254001                     Spinocerebellar ataxia type 32
# 29            161818003                                  Vulval irritation
# ...                 ...                                                ...
# 110686        234119001                       Congenital anomaly of artery
# 110687        359557001                                 Disorder of artery
# 110688        762250009                 Congenital anomaly of great vessel
# 110689        400159008                   Congenital vascular malformation
# 110690        399982001                       Congenital vascular disorder
# 110691          9904008        Congenital anomaly of cardiovascular system
# 110692        762228008                 Congenital cardiovascular disorder
# 110693         39785005                  Disorder of pulmonary circulation
# 110694        373434004                Disorder of blood vessels of thorax
# 110695         27550009                                  Vascular disorder
# 110696         19660004                            Disorder of soft tissue
# 110697         49601007                             Cardiovascular disease
# 110698         49483002                            Disorder of mediastinum
# 110699        702612001                         Congenital aplasia of lung
# 110700         47147007                         Congenital anomaly of lung
# 110701        123654008     Congenital anomaly of lower respiratory system
# 110702        275260000       Congenital anomaly of the respiratory system
# 110703         19829001                                  Pulmonary disease
# 110704        128272009               Disorder of lower respiratory system
# 110705         50043002                                Respiratory disease
# 110706        362965005                            Disorder of body system
# 110707        363035006                       Congenital anomaly of thorax
# 110708        363037003                  Congenital anomaly of upper trunk
# 110709         78626001                        Congenital anomaly of trunk
# 110710        276654001                                 Congenital anomaly
# 110711         66091009                                 Congenital disease
# 110712          5294002                             Developmental disorder
# 110713        118946009                                 Disorder of thorax
# 110714        609622007              Disorder of thoracic segment of trunk
# 110715        128121009                                  Disorder of trunk
#
# [110716 rows x 2 columns]

# %%
data_frame = pd.DataFrame(read_csv)
data_frame.head()
# Out:
#               code                                            display
# 0  303921000119109  Chronic tophaceous gout of hand due to renal i...
# 1        450309001  Major systemic to pulmonary collateral artery ...
# 2        428799009         Rotatory subluxation of atlantoaxial joint
# 3         93936002        Primary malignant neoplasm of palatine bone
# 4        164510000                         O/E - elbow joint abnormal

# %%
feature = data_frame["display"]
feature.head()
# Out:
# 0    Chronic tophaceous gout of hand due to renal i...
# 1    Major systemic to pulmonary collateral artery ...
# 2           Rotatory subluxation of atlantoaxial joint
# 3          Primary malignant neoplasm of palatine bone
# 4                           O/E - elbow joint abnormal
# Name: display, dtype: object
